# %%
import pandas as pd

# %% [markdown]
# # Pumpkin Dataset Exploratory Data Analysis

# %%
pumpkins_raw = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-10-19/pumpkins.csv")

# %%
pumpkins_raw
# Out:
#            id                                              place  \
# 0      2013-F                                                  1
# 1      2013-F                                                  2
# 2      2013-F                                                  3
# 3      2013-F                                                  4
# 4      2013-F                                                  5
# ...       ...                                                ...
# 28060  2021-W                                                DMG
# 28061  2021-W                                                DMG
# 28062  2021-W                                                DMG
# 28063  2021-W                                                DMG
# 28064  2021-W  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               weight_lbs  \
# 0                                                 154.50
# 1                                                 146.50
# 2                                                 145.00
# 3                                                 140.80
# 4                                                 139.00
# ...                                                  ...
# 28060                                             159.50
# 28061                                             141.00
# 28062                                             116.50
# 28063                                              16.30
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                              grower_name  \
# 0                            Ellenbecker, Todd & Sequoia
# 1                                            Razo, Steve
# 2                            Ellenbecker, Todd & Sequoia
# 3                                Martin, Margaret & Glen
# 4                                           Barlow, John
# ...                                                  ...
# 28060                                     Huber, Brandon
# 28061                                      Vester, Danny
# 28062                                   bradley, jeffrey
# 28063                                         Kyro, Anni
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                     city  \
# 0                                                Gleason
# 1                                         New Middletown
# 2                                                Glenson
# 3                                         Combined Locks
# 4                                                    NaN
# ...                                                  ...
# 28060                                            Raleigh
# 28061                                        Spring Hope
# 28062                                        rocky mount
# 28063                                         Orimattila
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               state_prov  \
# 0                                              Wisconsin
# 1                                                   Ohio
# 2                                              Wisconsin
# 3                                              Wisconsin
# 4                                              Wisconsin
# ...                                                  ...
# 28060                                     North Carolina
# 28061                                     North Carolina
# 28062                                     North Carolina
# 28063                                  Paijanne Tavastia
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                  country  \
# 0                                          United States
# 1                                          United States
# 2                                          United States
# 3                                          United States
# 4                                          United States
# ...                                                  ...
# 28060                                      United States
# 28061                                      United States
# 28062                                      United States
# 28063                                            Finland
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                 gpc_site  \
# 0                             Nekoosa Giant Pumpkin Fest
# 1            Ohio Valley Giant Pumpkin Growers Weigh-off
# 2                                  Mishicot Pumpkin Fest
# 3                    Cedarburg Wine and Harvest Festival
# 4                                 Stillwater Harvestfest
# ...                                                  ...
# 28060                    Yadkin Valley Pumpkin Weigh-off
# 28061                              Tennessee Valley Fair
# 28062              Spring Hope National Pumpkin Festival
# 28063                                  Finnish Weigh-off
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                              seed_mother  \
# 0                                             209 Werner
# 1                                           150.5 Snyder
# 2                                             209 Werner
# 3                                         109 Martin '12
# 4                                         130.5 McKinnon
# ...                                                  ...
# 28060                                           330 Vial
# 28061                                           305 Vial
# 28062                                             unknow
# 28063                            var. Carolina Cross -20
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                        pollinator_father  \
# 0                                                   Self
# 1                                                    NaN
# 2                                          103 Mackinnon
# 3                                         209 Werner '12
# 4                                                   open
# ...                                                  ...
# 28060                                                NaN
# 28061                                                NaN
# 28062                                                NaN
# 28063                                                NaN
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                      ott  \
# 0                                                  184.0
# 1                                                  194.0
# 2                                                  177.0
# 3                                                  194.0
# 4                                                    0.0
# ...                                                  ...
# 28060                                              175.0
# 28061                                              169.0
# 28062                                              159.0
# 28063                                                0.0
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               est_weight  \
# 0                                                 129.00
# 1                                                 151.00
# 2                                                 115.00
# 3                                                 151.00
# 4                                                   0.00
# ...                                                  ...
# 28060                                             152.00
# 28061                                             139.00
# 28062                                             116.00
# 28063                                               0.00
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                pct_chart variety
# 0                                                   20.0     NaN
# 1                                                   -3.0     NaN
# 2                                                   26.0     NaN
# 3                                                   -7.0     NaN
# 4                                                    0.0     NaN
# ...                                                  ...     ...
# 28060                                                5.0     NaN
# 28061                                                1.0     NaN
# 28062                                                0.0     NaN
# 28063                                                0.0     NaN
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...     NaN
#
# [28065 rows x 14 columns]

# %%
pumpkins_raw.shape
# Out:
# (28065, 14)

# %%
pumpkins_raw.columns
# Out:
# Index(['id', 'place', 'weight_lbs', 'grower_name', 'city', 'state_prov',
#        'country', 'gpc_site', 'seed_mother', 'pollinator_father', 'ott',
#        'est_weight', 'pct_chart', 'variety'],
#       dtype='object')

# %%
pumpkins = pumpkins_raw.drop([
    "place",
    "grower_name",
    "gpc_site",
    "seed_mother",
    "pollinator_father",
    "pct_chart",
    "variety"
], axis=1)

pumpkins
# Out:
#            id                                         weight_lbs  \
# 0      2013-F                                             154.50
# 1      2013-F                                             146.50
# 2      2013-F                                             145.00
# 3      2013-F                                             140.80
# 4      2013-F                                             139.00
# ...       ...                                                ...
# 28060  2021-W                                             159.50
# 28061  2021-W                                             141.00
# 28062  2021-W                                             116.50
# 28063  2021-W                                              16.30
# 28064  2021-W  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                     city  \
# 0                                                Gleason
# 1                                         New Middletown
# 2                                                Glenson
# 3                                         Combined Locks
# 4                                                    NaN
# ...                                                  ...
# 28060                                            Raleigh
# 28061                                        Spring Hope
# 28062                                        rocky mount
# 28063                                         Orimattila
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               state_prov  \
# 0                                              Wisconsin
# 1                                                   Ohio
# 2                                              Wisconsin
# 3                                              Wisconsin
# 4                                              Wisconsin
# ...                                                  ...
# 28060                                     North Carolina
# 28061                                     North Carolina
# 28062                                     North Carolina
# 28063                                  Paijanne Tavastia
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                  country  \
# 0                                          United States
# 1                                          United States
# 2                                          United States
# 3                                          United States
# 4                                          United States
# ...                                                  ...
# 28060                                      United States
# 28061                                      United States
# 28062                                      United States
# 28063                                            Finland
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                      ott  \
# 0                                                  184.0
# 1                                                  194.0
# 2                                                  177.0
# 3                                                  194.0
# 4                                                    0.0
# ...                                                  ...
# 28060                                              175.0
# 28061                                              169.0
# 28062                                              159.0
# 28063                                                0.0
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               est_weight
# 0                                                 129.00
# 1                                                 151.00
# 2                                                 115.00
# 3                                                 151.00
# 4                                                   0.00
# ...                                                  ...
# 28060                                             152.00
# 28061                                             139.00
# 28062                                             116.00
# 28063                                               0.00
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
# [28065 rows x 7 columns]

# %%
pumpkins[pumpkins.country == "United States"].state_prov.value_counts()
# Out:
# Wisconsin         1910
# California        1211
# Ohio              1190
# Michigan          1128
# Washington        1117
# Pennsylvania       992
# Oregon             873
# New York           802
# Minnesota          708
# Indiana            674
# Colorado           604
# Iowa               599
# Utah               518
# Connecticut        459
# North Carolina     427
# Massachusetts      415
# Vermont            381
# Kentucky           345
# Maine              332
# Rhode Island       308
# Tennessee          251
# New Hampshire      219
# South Dakota       201
# Illinois           192
# Missouri           165
# Virginia           145
# Arkansas           131
# West Virginia       89
# Wyoming             85
# Kansas              78
# Alabama             75
# Nebraska            69
# Alaska              61
# Oklahoma            61
# North Dakota        42
# Idaho               42
# Montana             35
# Georgia             29
# Louisiana           25
# New Jersey          22
# Arizona             12
# Texas               10
# South Carolina       9
# Maryland             7
# Nevada               7
# Delaware             5
# New Mexico           3
# Hawaii               3
# Mississippi          3
# Florida              1
# Name: state_prov, dtype: int64

# %%
us_pumpkins = pumpkins[pumpkins.country == "United States"]
us_pumpkins.index = range(len(us_pumpkins))
us_pumpkins.city = us_pumpkins.city.str.title()
us_pumpkins.state_prov = us_pumpkins.state_prov.str.title()

us_pumpkins
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#            id weight_lbs            city      state_prov        country  \
# 0      2013-F     154.50         Gleason       Wisconsin  United States
# 1      2013-F     146.50  New Middletown            Ohio  United States
# 2      2013-F     145.00         Glenson       Wisconsin  United States
# 3      2013-F     140.80  Combined Locks       Wisconsin  United States
# 4      2013-F     139.00             NaN       Wisconsin  United States
# ...       ...        ...             ...             ...            ...
# 17065  2021-W       2.50          Garner  North Carolina  United States
# 17066  2021-W     181.00          Bailey  North Carolina  United States
# 17067  2021-W     159.50         Raleigh  North Carolina  United States
# 17068  2021-W     141.00     Spring Hope  North Carolina  United States
# 17069  2021-W     116.50     Rocky Mount  North Carolina  United States
#
#          ott est_weight
# 0      184.0     129.00
# 1      194.0     151.00
# 2      177.0     115.00
# 3      194.0     151.00
# 4        0.0       0.00
# ...      ...        ...
# 17065   42.0       0.00
# 17066  185.0     180.00
# 17067  175.0     152.00
# 17068  169.0     139.00
# 17069  159.0     116.00
#
# [17070 rows x 7 columns]

# %%
us_pumpkins.weight_lbs = pd.to_numeric(us_pumpkins.weight_lbs, errors='coerce')
us_pumpkins[us_pumpkins.weight_lbs.isna()]
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#            id  weight_lbs         city  state_prov        country    ott  \
# 313    2013-P         NaN         Napa  California  United States  475.0
# 314    2013-P         NaN         Napa  California  United States  453.0
# 315    2013-P         NaN         Napa  California  United States  445.0
# 316    2013-P         NaN         Napa  California  United States  436.0
# 317    2013-P         NaN       Sumner  Washington  United States  431.0
# ...       ...         ...          ...         ...            ...    ...
# 16609  2021-S         NaN       Marion     Indiana  United States  363.0
# 16610  2021-S         NaN  Suttons Bay    Michigan  United States  351.0
# 16611  2021-S         NaN   Brownstown    Michigan  United States  378.0
# 16612  2021-S         NaN    Nobleboro       Maine  United States    0.0
# 16663  2021-S         NaN        Edgar   Wisconsin  United States    0.0
#
#       est_weight
# 313     2,000.00
# 314     1,809.00
# 315     1,745.00
# 316     1,667.00
# 317     1,619.00
# ...          ...
# 16609   1,085.00
# 16610     982.00
# 16611   1,213.00
# 16612     970.00
# 16663       0.00
#
# [3771 rows x 7 columns]

# %%
us_pumpkins_clean = us_pumpkins.loc[pd.notnull(us_pumpkins.weight_lbs)]
us_pumpkins_clean.index = range(len(us_pumpkins_clean))
us_pumpkins_clean
# Out:
#            id  weight_lbs            city      state_prov        country  \
# 0      2013-F       154.5         Gleason       Wisconsin  United States
# 1      2013-F       146.5  New Middletown            Ohio  United States
# 2      2013-F       145.0         Glenson       Wisconsin  United States
# 3      2013-F       140.8  Combined Locks       Wisconsin  United States
# 4      2013-F       139.0             NaN       Wisconsin  United States
# ...       ...         ...             ...             ...            ...
# 13294  2021-W         2.5          Garner  North Carolina  United States
# 13295  2021-W       181.0          Bailey  North Carolina  United States
# 13296  2021-W       159.5         Raleigh  North Carolina  United States
# 13297  2021-W       141.0     Spring Hope  North Carolina  United States
# 13298  2021-W       116.5     Rocky Mount  North Carolina  United States
#
#          ott est_weight
# 0      184.0     129.00
# 1      194.0     151.00
# 2      177.0     115.00
# 3      194.0     151.00
# 4        0.0       0.00
# ...      ...        ...
# 13294   42.0       0.00
# 13295  185.0     180.00
# 13296  175.0     152.00
# 13297  169.0     139.00
# 13298  159.0     116.00
#
# [13299 rows x 7 columns]

# %%
# Percent lost due to eroneous weight_lbs data

3771/17070
# Out:
# 0.22091388400702988

# %%
us_pumpkins_clean.id.unique()
# Out:
# array(['2013-F', '2013-L', '2013-P', '2013-S', '2013-T', '2013-W',
#        '2014-F', '2014-L', '2014-P', '2014-S', '2014-T', '2014-W',
#        '2015-F', '2015-L', '2015-P', '2015-S', '2015-T', '2015-W',
#        '2016-F', '2016-L', '2016-P', '2016-S', '2016-T', '2016-W',
#        '2017-F', '2017-L', '2017-P', '2017-S', '2017-T', '2017-W',
#        '2018-F', '2018-L', '2018-P', '2018-S', '2018-T', '2018-W',
#        '2019-F', '2019-L', '2019-P', '2019-S', '2019-T', '2019-W',
#        '2020-F', '2020-L', '2020-P', '2020-S', '2020-T', '2020-W',
#        '2021-F', '2021-L', '2021-P', '2021-S', '2021-T', '2021-W'],
#       dtype=object)

# %%
us_pumpkins_clean.loc[:,"year"] = us_pumpkins_clean.loc[:,"id"].str[:4]
us_pumpkins_clean.year.unique()
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# array(['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021'], dtype=object)

# %%
us_pumpkins_clean.loc[:,"type"] = us_pumpkins_clean.loc[:,"id"].str[-1]
us_pumpkins_clean.type.unique()
# Out:
# array(['F', 'L', 'P', 'S', 'T', 'W'], dtype=object)

# %%
types = {
    "F" : "Field Pumpkin",
    "P" : "Giant Pumpkin", 
    "S" : "Giant Squash", 
    "W" : "Giant Watermelon", 
    "L" : "Long Gourd", #(length in inches, not weight in pounds) 
    "T" : "Tomato"
}

# %%
us_pumpkins_clean["type"] = us_pumpkins_clean["type"].map(types)
us_pumpkins_clean
# Out:
# <ipython-input-16-46d51ff88a9c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_pumpkins_clean["type"] = us_pumpkins_clean["type"].map(types)
#            id  weight_lbs            city      state_prov        country  \
# 0      2013-F       154.5         Gleason       Wisconsin  United States
# 1      2013-F       146.5  New Middletown            Ohio  United States
# 2      2013-F       145.0         Glenson       Wisconsin  United States
# 3      2013-F       140.8  Combined Locks       Wisconsin  United States
# 4      2013-F       139.0             NaN       Wisconsin  United States
# ...       ...         ...             ...             ...            ...
# 13294  2021-W         2.5          Garner  North Carolina  United States
# 13295  2021-W       181.0          Bailey  North Carolina  United States
# 13296  2021-W       159.5         Raleigh  North Carolina  United States
# 13297  2021-W       141.0     Spring Hope  North Carolina  United States
# 13298  2021-W       116.5     Rocky Mount  North Carolina  United States
#
#          ott est_weight  year              type
# 0      184.0     129.00  2013     Field Pumpkin
# 1      194.0     151.00  2013     Field Pumpkin
# 2      177.0     115.00  2013     Field Pumpkin
# 3      194.0     151.00  2013     Field Pumpkin
# 4        0.0       0.00  2013     Field Pumpkin
# ...      ...        ...   ...               ...
# 13294   42.0       0.00  2021  Giant Watermelon
# 13295  185.0     180.00  2021  Giant Watermelon
# 13296  175.0     152.00  2021  Giant Watermelon
# 13297  169.0     139.00  2021  Giant Watermelon
# 13298  159.0     116.00  2021  Giant Watermelon
#
# [13299 rows x 9 columns]

# %%
# filter out Long Gourd's

us_pumpkins_clean = us_pumpkins_clean[us_pumpkins_clean.type != "Long Gourd"]
us_pumpkins_clean.index = range(len(us_pumpkins_clean))
us_pumpkins_clean
# Out:
#            id  weight_lbs            city      state_prov        country  \
# 0      2013-F       154.5         Gleason       Wisconsin  United States
# 1      2013-F       146.5  New Middletown            Ohio  United States
# 2      2013-F       145.0         Glenson       Wisconsin  United States
# 3      2013-F       140.8  Combined Locks       Wisconsin  United States
# 4      2013-F       139.0             NaN       Wisconsin  United States
# ...       ...         ...             ...             ...            ...
# 12237  2021-W         2.5          Garner  North Carolina  United States
# 12238  2021-W       181.0          Bailey  North Carolina  United States
# 12239  2021-W       159.5         Raleigh  North Carolina  United States
# 12240  2021-W       141.0     Spring Hope  North Carolina  United States
# 12241  2021-W       116.5     Rocky Mount  North Carolina  United States
#
#          ott est_weight  year              type
# 0      184.0     129.00  2013     Field Pumpkin
# 1      194.0     151.00  2013     Field Pumpkin
# 2      177.0     115.00  2013     Field Pumpkin
# 3      194.0     151.00  2013     Field Pumpkin
# 4        0.0       0.00  2013     Field Pumpkin
# ...      ...        ...   ...               ...
# 12237   42.0       0.00  2021  Giant Watermelon
# 12238  185.0     180.00  2021  Giant Watermelon
# 12239  175.0     152.00  2021  Giant Watermelon
# 12240  169.0     139.00  2021  Giant Watermelon
# 12241  159.0     116.00  2021  Giant Watermelon
#
# [12242 rows x 9 columns]

# %%
us_pumpkins_clean.state_prov.unique()
# Out:
# array(['Wisconsin', 'Ohio', 'Pennsylvania', 'Oregon', 'Washington',
#        'New York', 'Colorado', 'Michigan', 'Indiana', 'Minnesota',
#        'Vermont', 'Connecticut', 'Massachusetts', 'Iowa', 'Idaho',
#        'Kentucky', 'Utah', 'Montana', 'South Dakota', 'New Hampshire',
#        'California', 'Rhode Island', 'Illinois', 'Maine', 'Alaska',
#        'Maryland', 'Wyoming', 'Tennessee', 'Alabama', 'North Dakota',
#        'North Carolina', 'Virginia', 'South Carolina', 'Missouri',
#        'Georgia', 'Mississippi', 'Arkansas', 'Louisiana', 'Nebraska',
#        'New Jersey', 'Delaware', 'Kansas', 'Nevada', 'Oklahoma',
#        'New Mexico', 'Hawaii', 'Texas', 'West Virginia', 'Arizona',
#        'Florida'], dtype=object)

# %% [markdown]
# # Import, Format, and Filter Weather Data

# %%
# Read in weather data for years 2013 - 2021

weather_2013 = pd.read_csv("source_data/weather/2013.csv.gz", header=None)
weather_2014 = pd.read_csv("source_data/weather/2014.csv.gz", header=None)
weather_2015 = pd.read_csv("source_data/weather/2015.csv.gz", header=None)
weather_2016 = pd.read_csv("source_data/weather/2016.csv.gz", header=None)
weather_2017 = pd.read_csv("source_data/weather/2017.csv.gz", header=None)
weather_2018 = pd.read_csv("source_data/weather/2018.csv.gz", header=None)
weather_2019 = pd.read_csv("source_data/weather/2019.csv.gz", header=None)
weather_2020 = pd.read_csv("source_data/weather/2020.csv.gz", header=None)
weather_2021 = pd.read_csv("source_data/weather/2021.csv.gz", header=None)

# %%
# Confirm csv files were correctly loaded

print(weather_2013.head(),"\n")
print(weather_2014.head(),"\n")
print(weather_2015.head(),"\n")
print(weather_2016.head(),"\n")
print(weather_2017.head(),"\n")
print(weather_2018.head(),"\n")
print(weather_2019.head(),"\n")
print(weather_2020.head(),"\n")
print(weather_2021.head(),"\n")
# Out:
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20130101  TMAX  250  NaN  NaN  S NaN
# 1  AE000041196  20130101  TAVG  176    H  NaN  S NaN
# 2  AEM00041194  20130101  TMAX  241  NaN  NaN  S NaN
# 3  AEM00041194  20130101  TMIN  157  NaN  NaN  S NaN
# 4  AEM00041194  20130101  PRCP    0  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20140101  TMAX  244  NaN  NaN  S NaN
# 1  AE000041196  20140101  TMIN  128  NaN  NaN  S NaN
# 2  AE000041196  20140101  TAVG  182    H  NaN  S NaN
# 3  AEM00041194  20140101  TMAX  241  NaN  NaN  S NaN
# 4  AEM00041194  20140101  TMIN  159  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20150101  TMIN  125  NaN  NaN  S NaN
# 1  AE000041196  20150101  PRCP    0  NaN  NaN  S NaN
# 2  AE000041196  20150101  TAVG  206    H  NaN  S NaN
# 3  AEM00041194  20150101  TMAX  286  NaN  NaN  S NaN
# 4  AEM00041194  20150101  TMIN  180  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20160101  TMIN  155  NaN  NaN  S NaN
# 1  AE000041196  20160101  TAVG  229    H  NaN  S NaN
# 2  AEM00041194  20160101  PRCP    0  NaN  NaN  S NaN
# 3  AEM00041194  20160101  TAVG  241    H  NaN  S NaN
# 4  AEM00041218  20160101  TMIN  182  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20170101  TMIN  163  NaN  NaN  S NaN
# 1  AE000041196  20170101  TAVG  217    H  NaN  S NaN
# 2  AEM00041194  20170101  PRCP    0  NaN  NaN  S NaN
# 3  AEM00041194  20170101  TAVG  223    H  NaN  S NaN
# 4  AEM00041218  20170101  TMIN  137  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20180101  TMAX  259  NaN  NaN  S NaN
# 1  AE000041196  20180101  TMIN  112  NaN  NaN  S NaN
# 2  AE000041196  20180101  TAVG  186    H  NaN  S NaN
# 3  AEM00041194  20180101  TMAX  250  NaN  NaN  S NaN
# 4  AEM00041194  20180101  PRCP    0  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20190101  TMAX  269  NaN  NaN  S NaN
# 1  AE000041196  20190101  TMIN  140  NaN  NaN  S NaN
# 2  AE000041196  20190101  TAVG  198    H  NaN  S NaN
# 3  AEM00041194  20190101  TMAX  280  NaN  NaN  S NaN
# 4  AEM00041194  20190101  TMIN  185  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20200101  TMIN  168  NaN  NaN  S NaN
# 1  AE000041196  20200101  PRCP    0    D  NaN  S NaN
# 2  AE000041196  20200101  TAVG  211    H  NaN  S NaN
# 3  AEM00041194  20200101  PRCP    0  NaN  NaN  S NaN
# 4  AEM00041194  20200101  TAVG  217    H  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20210101  TMAX  278  NaN  NaN  S NaN
# 1  AE000041196  20210101  PRCP    0    D  NaN  S NaN
# 2  AE000041196  20210101  TAVG  214    H  NaN  S NaN
# 3  AEM00041194  20210101  TMAX  266  NaN  NaN  S NaN
# 4  AEM00041194  20210101  TMIN  178  NaN  NaN  S NaN

# %%
# Name Columns

names = [
    "station_id",
    "date",
    "element",
    "value",
    "measurement_flag",
    "quality_flag",
    "source_flag",
    "time_of_observation"
]

weather_2013.columns = names
weather_2014.columns = names
weather_2015.columns = names
weather_2016.columns = names
weather_2017.columns = names
weather_2018.columns = names
weather_2019.columns = names
weather_2020.columns = names
weather_2021.columns = names

# %%
# Filter out all records that are not PRCP, TMIN, TMAX, TAVG

weather_2013 = weather_2013[weather_2013.element.isin(["PRCP","TMIN","TMAX","TAVG"])]
weather_2014 = weather_2014[weather_2014.element.isin(["PRCP","TMIN","TMAX","TAVG"])]
weather_2015 = weather_2015[weather_2015.element.isin(["PRCP","TMIN","TMAX","TAVG"])]
weather_2016 = weather_2016[weather_2016.element.isin(["PRCP","TMIN","TMAX","TAVG"])]
weather_2017 = weather_2017[weather_2017.element.isin(["PRCP","TMIN","TMAX","TAVG"])]
weather_2018 = weather_2018[weather_2018.element.isin(["PRCP","TMIN","TMAX","TAVG"])]
weather_2019 = weather_2019[weather_2019.element.isin(["PRCP","TMIN","TMAX","TAVG"])]
weather_2020 = weather_2020[weather_2020.element.isin(["PRCP","TMIN","TMAX","TAVG"])]
weather_2021 = weather_2021[weather_2021.element.isin(["PRCP","TMIN","TMAX","TAVG"])]

# %%
# Merge all years into a single dataset

weather = weather_2013.append(weather_2014, ignore_index=True)
print("2013")
print("2014")
weather = weather.append(weather_2015, ignore_index=True)
print("2015")
weather = weather.append(weather_2016, ignore_index=True)
print("2016")
weather = weather.append(weather_2017, ignore_index=True)
print("2017")
weather = weather.append(weather_2018, ignore_index=True)
print("2018")
weather = weather.append(weather_2019, ignore_index=True)
print("2019")
weather = weather.append(weather_2020, ignore_index=True)
print("2020")
weather = weather.append(weather_2021, ignore_index=True)
print("2021")
# Out:
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
weather.shape
# Out:
# (196506835, 8)

# %%
weather["date"] = pd.to_datetime(weather.date, format='%Y%m%d')
weather
# Out:
#             station_id       date element  value measurement_flag  \
# 0          AE000041196 2013-01-01    TMAX    250              NaN
# 1          AE000041196 2013-01-01    TAVG    176                H
# 2          AEM00041194 2013-01-01    TMAX    241              NaN
# 3          AEM00041194 2013-01-01    TMIN    157              NaN
# 4          AEM00041194 2013-01-01    PRCP      0              NaN
# ...                ...        ...     ...    ...              ...
# 196506830  GQC00914001 2021-11-29    PRCP    203              NaN
# 196506831  GQC00914275 2021-11-29    PRCP    208              NaN
# 196506832  RMW00040710 2021-11-29    TMAX    311              NaN
# 196506833  RMW00040710 2021-11-29    TMIN    261              NaN
# 196506834  RMW00040710 2021-11-29    PRCP     28              NaN
#
#           quality_flag source_flag  time_of_observation
# 0                  NaN           S                  NaN
# 1                  NaN           S                  NaN
# 2                  NaN           S                  NaN
# 3                  NaN           S                  NaN
# 4                  NaN           S                  NaN
# ...                ...         ...                  ...
# 196506830          NaN           H                800.0
# 196506831          NaN           H                900.0
# 196506832          NaN           H               2400.0
# 196506833          NaN           H               2400.0
# 196506834          NaN           H               2400.0
#
# [196506835 rows x 8 columns]

# %%
weather_growing_season = weather[weather.date.dt.month.isin(range(5,10))]
weather_growing_season

# %%
83768529/196506835
# Out:
# 0.426288118680452

# %% [markdown]
# # Import Station Data

# %%
station_list = pd.read_csv('source_data/weather/ghcnd-stations.txt', names=['data'], header=None, error_bad_lines=False)
station_list
# Out:
#                                                      data
# 0       ACW00011604  17.1167  -61.7833   10.1    ST JO...
# 1       ACW00011647  17.1333  -61.7833   19.2    ST JO...
# 2       AE000041196  25.3330   55.5170   34.0    SHARJ...
# 3       AEM00041194  25.2550   55.3640   10.4    DUBAI...
# 4       AEM00041217  24.4330   54.6510   26.8    ABU D...
# ...                                                   ...
# 119498  ZI000067969 -21.0500   29.3670  861.0    WEST ...
# 119499  ZI000067975 -20.0670   30.8670 1095.0    MASVI...
# 119500  ZI000067977 -21.0170   31.5830  430.0    BUFFA...
# 119501  ZI000067983 -20.2000   32.6160 1132.0    CHIPI...
# 119502  ZI000067991 -22.2170   30.0000  457.0    BEITB...
#
# [119503 rows x 1 columns]

# %%
station_list["id"] = station_list.data.str[0:11]
station_list["country"] = station_list.data.str[0:2]
station_list["state"] = station_list.data.str[38:40]
station_list["latitude"] = station_list.data.str[12:20]
station_list["longitude"] = station_list.data.str[21:30]

station_list.head(10)
# Out:
#                                                 data           id country  \
# 0  ACW00011604  17.1167  -61.7833   10.1    ST JO...  ACW00011604      AC
# 1  ACW00011647  17.1333  -61.7833   19.2    ST JO...  ACW00011647      AC
# 2  AE000041196  25.3330   55.5170   34.0    SHARJ...  AE000041196      AE
# 3  AEM00041194  25.2550   55.3640   10.4    DUBAI...  AEM00041194      AE
# 4  AEM00041217  24.4330   54.6510   26.8    ABU D...  AEM00041217      AE
# 5  AEM00041218  24.2620   55.6090  264.9    AL AI...  AEM00041218      AE
# 6  AF000040930  35.3170   69.0170 3366.0    NORTH...  AF000040930      AF
# 7  AFM00040938  34.2100   62.2280  977.2    HERAT...  AFM00040938      AF
# 8  AFM00040948  34.5660   69.2120 1791.3    KABUL...  AFM00040948      AF
# 9  AFM00040990  31.5000   65.8500 1010.0    KANDA...  AFM00040990      AF
#
#   state  latitude  longitude
# 0         17.1167   -61.7833
# 1         17.1333   -61.7833
# 2         25.3330    55.5170
# 3         25.2550    55.3640
# 4         24.4330    54.6510
# 5         24.2620    55.6090
# 6         35.3170    69.0170
# 7         34.2100    62.2280
# 8         34.5660    69.2120
# 9         31.5000    65.8500

# %%
us_stations = station_list[station_list.country == "US"]
us_stations = us_stations.drop(["data","country"], axis=1)
us_stations.index = range(len(us_stations))
us_stations
# Out:
#                 id state  latitude  longitude
# 0      US009052008    SD   43.7333   -96.6333
# 1      US10RMHS145    CO   40.5268  -105.1113
# 2      US10adam001    NE   40.5680   -98.5069
# 3      US10adam002    NE   40.5093   -98.5493
# 4      US10adam003    NE   40.4663   -98.6537
# ...            ...   ...       ...        ...
# 66099  USW00096405    AK   60.4731  -145.3542
# 66100  USW00096406    AK   64.5014  -154.1297
# 66101  USW00096407    AK   66.5620  -159.0036
# 66102  USW00096408    AK   63.4519  -150.8747
# 66103  USW00096409    AK   68.6483  -149.3986
#
# [66104 rows x 4 columns]

# %% [markdown]
# # State Abbbreviations

# %%
state_abbrev = pd.read_csv("source_data/weather/ghcnd-states.txt", header=None, names = ["data"])
state_abbrev["code"] = state_abbrev.data.str[:2]
state_abbrev["state"] = state_abbrev.data.str[3:]
state_abbrev["state"] = state_abbrev["state"].str.title()
state_abbrev.drop('data', axis=1, inplace=True)
state_abbrev.head(20)
# Out:
#    code                 state
# 0    AB               Alberta
# 1    AK                Alaska
# 2    AL               Alabama
# 3    AR              Arkansas
# 4    AS        American Samoa
# 5    AZ               Arizona
# 6    BC      British Columbia
# 7    CA            California
# 8    CO              Colorado
# 9    CT           Connecticut
# 10   DC  District Of Columbia
# 11   DE              Delaware
# 12   FL               Florida
# 13   FM            Micronesia
# 14   GA               Georgia
# 15   GU                  Guam
# 16   HI                Hawaii
# 17   IA                  Iowa
# 18   ID                 Idaho
# 19   IL              Illinois

# %%
print(state_abbrev.state.values)
# Out:
# ['Alberta' 'Alaska' 'Alabama' 'Arkansas' 'American Samoa' 'Arizona'
#  'British Columbia' 'California' 'Colorado' 'Connecticut'
#  'District Of Columbia' 'Delaware' 'Florida' 'Micronesia' 'Georgia' 'Guam'
#  'Hawaii' 'Iowa' 'Idaho' 'Illinois' 'Indiana' 'Kansas' 'Kentucky'
#  'Louisiana' 'Massachusetts' 'Manitoba' 'Maryland' 'Maine'
#  'Marshall Islands' 'Michigan' 'Minnesota' 'Missouri'
#  'Northern Mariana Islands' 'Mississippi' 'Montana' 'New Brunswick'
#  'North Carolina' 'North Dakota' 'Nebraska' 'New Hampshire' 'New Jersey'
#  'Newfoundland And Labrador' 'New Mexico' 'Nova Scotia'
#  'Northwest Territories' 'Nunavut' 'Nevada' 'New York' 'Ohio' 'Oklahoma'
#  'Ontario' 'Oregon' 'Pennsylvania' 'Prince Edward Island'
#  'Pacific Islands' 'Puerto Rico' 'Palau' 'Quebec' 'Rhode Island'
#  'South Carolina' 'South Dakota' 'Saskatchewan' 'Tennessee' 'Texas'
#  'U.S. Minor Outlying Islands' 'Utah' 'Virginia' 'Virgin Islands'
#  'Vermont' 'Washington' 'Wisconsin' 'West Virginia' 'Wyoming'
#  'Yukon Territory']

# %%
state_abbrev_dict = {}
for i in state_abbrev.index:
    state_abbrev_dict[state_abbrev.loc[i].code] = state_abbrev.loc[i].state
    
state_abbrev_dict
# Out:
# {'AB': 'Alberta',
#  'AK': 'Alaska',
#  'AL': 'Alabama',
#  'AR': 'Arkansas',
#  'AS': 'American Samoa',
#  'AZ': 'Arizona',
#  'BC': 'British Columbia',
#  'CA': 'California',
#  'CO': 'Colorado',
#  'CT': 'Connecticut',
#  'DC': 'District Of Columbia',
#  'DE': 'Delaware',
#  'FL': 'Florida',
#  'FM': 'Micronesia',
#  'GA': 'Georgia',
#  'GU': 'Guam',
#  'HI': 'Hawaii',
#  'IA': 'Iowa',
#  'ID': 'Idaho',
#  'IL': 'Illinois',
#  'IN': 'Indiana',
#  'KS': 'Kansas',
#  'KY': 'Kentucky',
#  'LA': 'Louisiana',
#  'MA': 'Massachusetts',
#  'MB': 'Manitoba',
#  'MD': 'Maryland',
#  'ME': 'Maine',
#  'MH': 'Marshall Islands',
#  'MI': 'Michigan',
#  'MN': 'Minnesota',
#  'MO': 'Missouri',
#  'MP': 'Northern Mariana Islands',
#  'MS': 'Mississippi',
#  'MT': 'Montana',
#  'NB': 'New Brunswick',
#  'NC': 'North Carolina',
#  'ND': 'North Dakota',
#  'NE': 'Nebraska',
#  'NH': 'New Hampshire',
#  'NJ': 'New Jersey',
#  'NL': 'Newfoundland And Labrador',
#  'NM': 'New Mexico',
#  'NS': 'Nova Scotia',
#  'NT': 'Northwest Territories',
#  'NU': 'Nunavut',
#  'NV': 'Nevada',
#  'NY': 'New York',
#  'OH': 'Ohio',
#  'OK': 'Oklahoma',
#  'ON': 'Ontario',
#  'OR': 'Oregon',
#  'PA': 'Pennsylvania',
#  'PE': 'Prince Edward Island',
#  'PI': 'Pacific Islands',
#  'PR': 'Puerto Rico',
#  'PW': 'Palau',
#  'QC': 'Quebec',
#  'RI': 'Rhode Island',
#  'SC': 'South Carolina',
#  'SD': 'South Dakota',
#  'SK': 'Saskatchewan',
#  'TN': 'Tennessee',
#  'TX': 'Texas',
#  'UM': 'U.S. Minor Outlying Islands',
#  'UT': 'Utah',
#  'VA': 'Virginia',
#  'VI': 'Virgin Islands',
#  'VT': 'Vermont',
#  'WA': 'Washington',
#  'WI': 'Wisconsin',
#  'WV': 'West Virginia',
#  'WY': 'Wyoming',
#  'YT': 'Yukon Territory'}

# %%
for i in range(len(us_pumpkins_clean)):
    if us_pumpkins_clean.loc[i].state_prov in state_abbrev.state.values:
        continue
    else:
        print(us_pumpkins_clean.loc[i].state_prov)
        break

# %% [markdown]
# # City Latitude/Longitude

# %%
cities = pd.read_csv("source_data/uscities/worldcitiespop.csv")
cities
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Country         City   AccentCity Region  Population   Latitude  \
# 0            ad        aixas        Aixàs      6         NaN  42.483333
# 1            ad   aixirivali   Aixirivali      6         NaN  42.466667
# 2            ad   aixirivall   Aixirivall      6         NaN  42.466667
# 3            ad    aixirvall    Aixirvall      6         NaN  42.466667
# 4            ad     aixovall     Aixovall      6         NaN  42.466667
# ...         ...          ...          ...    ...         ...        ...
# 3173953      zw   zimre park   Zimre Park      4         NaN -17.866111
# 3173954      zw  ziyakamanas  Ziyakamanas      0         NaN -18.216667
# 3173955      zw   zizalisari   Zizalisari      4         NaN -17.758889
# 3173956      zw      zuzumba      Zuzumba      6         NaN -20.033333
# 3173957      zw   zvishavane   Zvishavane      7     79876.0 -20.333333
#
#          Longitude
# 0         1.466667
# 1         1.500000
# 2         1.500000
# 3         1.500000
# 4         1.483333
# ...            ...
# 3173953  31.213611
# 3173954  27.950000
# 3173955  31.010556
# 3173956  27.933333
# 3173957  30.033333
#
# [3173958 rows x 7 columns]

# %%
us_cities = cities[cities.Country == "us"]
us_cities.index = range(len(us_cities))
us_cities
# Out:
#        Country           City     AccentCity Region  Population   Latitude  \
# 0           us         abanda         Abanda     AL         NaN  33.100833
# 1           us      abbeville      Abbeville     AL         NaN  31.571667
# 2           us  abbot springs  Abbot Springs     AL         NaN  33.360833
# 3           us           abel           Abel     AL         NaN  33.548611
# 4           us    abercrombie    Abercrombie     AL         NaN  32.848611
# ...        ...            ...            ...    ...         ...        ...
# 141984      us        wyoming        Wyoming     WY         NaN  41.477500
# 141985      us          wyopo          Wyopo     WY         NaN  42.855556
# 141986      us      y-o ranch      Y-O Ranch     WY         NaN  42.030833
# 141987      us        yanceys        Yanceys     WY         NaN  44.930833
# 141988      us          yoder          Yoder     WY         NaN  41.916944
#
#          Longitude
# 0       -85.529722
# 1       -85.250556
# 2       -86.481667
# 3       -85.712500
# 4       -87.165000
# ...            ...
# 141984 -105.636111
# 141985 -108.688611
# 141986 -104.939444
# 141987 -110.435556
# 141988 -104.295278
#
# [141989 rows x 7 columns]

# %%
us_cities.columns
# Out:
# Index(['Country', 'City', 'AccentCity', 'Region', 'Population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
us_cities.columns = ['delete1', 'delete2', 'city', 'state_code', 'delete3', 'latitude',
       'longitude']
us_cities.drop(['delete1','delete2','delete3'], axis=1, inplace=True)
us_cities = us_cities.merge(state_abbrev, how="left", left_on="state_code", right_on="code").drop(["code"],axis=1)
us_cities
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                  city state_code   latitude   longitude    state
# 0              Abanda         AL  33.100833  -85.529722  Alabama
# 1           Abbeville         AL  31.571667  -85.250556  Alabama
# 2       Abbot Springs         AL  33.360833  -86.481667  Alabama
# 3                Abel         AL  33.548611  -85.712500  Alabama
# 4         Abercrombie         AL  32.848611  -87.165000  Alabama
# ...               ...        ...        ...         ...      ...
# 141984        Wyoming         WY  41.477500 -105.636111  Wyoming
# 141985          Wyopo         WY  42.855556 -108.688611  Wyoming
# 141986      Y-O Ranch         WY  42.030833 -104.939444  Wyoming
# 141987        Yanceys         WY  44.930833 -110.435556  Wyoming
# 141988          Yoder         WY  41.916944 -104.295278  Wyoming
#
# [141989 rows x 5 columns]

# %%
pumpkin_coord = us_pumpkins_clean.merge(us_cities, how="left", left_on=["city","state_prov"], right_on=["city","state"])
pumpkin_coord
# Out:
#            id  weight_lbs            city      state_prov        country  \
# 0      2013-F       154.5         Gleason       Wisconsin  United States
# 1      2013-F       146.5  New Middletown            Ohio  United States
# 2      2013-F       145.0         Glenson       Wisconsin  United States
# 3      2013-F       140.8  Combined Locks       Wisconsin  United States
# 4      2013-F       139.0             NaN       Wisconsin  United States
# ...       ...         ...             ...             ...            ...
# 12237  2021-W         2.5          Garner  North Carolina  United States
# 12238  2021-W       181.0          Bailey  North Carolina  United States
# 12239  2021-W       159.5         Raleigh  North Carolina  United States
# 12240  2021-W       141.0     Spring Hope  North Carolina  United States
# 12241  2021-W       116.5     Rocky Mount  North Carolina  United States
#
#          ott est_weight  year              type state_code   latitude  \
# 0      184.0     129.00  2013     Field Pumpkin         WI  45.308889
# 1      194.0     151.00  2013     Field Pumpkin         OH  40.961111
# 2      177.0     115.00  2013     Field Pumpkin        NaN        NaN
# 3      194.0     151.00  2013     Field Pumpkin         WI  44.265833
# 4        0.0       0.00  2013     Field Pumpkin        NaN        NaN
# ...      ...        ...   ...               ...        ...        ...
# 12237   42.0       0.00  2021  Giant Watermelon         NC  35.711111
# 12238  185.0     180.00  2021  Giant Watermelon         NC  35.780556
# 12239  175.0     152.00  2021  Giant Watermelon         NC  35.771944
# 12240  169.0     139.00  2021  Giant Watermelon         NC  35.945000
# 12241  159.0     116.00  2021  Giant Watermelon         NC  35.938056
#
#        longitude           state
# 0     -89.496389       Wisconsin
# 1     -80.557778            Ohio
# 2            NaN             NaN
# 3     -88.314167       Wisconsin
# 4            NaN             NaN
# ...          ...             ...
# 12237 -78.614444  North Carolina
# 12238 -78.119167  North Carolina
# 12239 -78.638889  North Carolina
# 12240 -78.112222  North Carolina
# 12241 -77.790833  North Carolina
#
# [12242 rows x 13 columns]

# %%
pumpkin_filtered = pumpkin_coord.dropna(subset=['latitude', 'longitude'])
pumpkin_filtered.index = range(len(pumpkin_filtered))
print(f"{len(pumpkin_coord) - len(pumpkin_filtered)} pumpkins omitted due to failure to match city")
# Out:
# 1933 pumpkins omitted due to failure to match city

# %%
# Drop excess columns and rearrange columns

pumpkin_clean = pumpkin_filtered.drop(["id","country","state_prov","est_weight","ott"], axis=1)
pumpkin_clean = pumpkin_clean.reindex(columns = [
    'year',
    'type',
    'weight_lbs',
    'city',
    'state',
    'state_code',
    'latitude',
    'longitude'
])

pumpkin_clean
# Out:
#        year              type  weight_lbs            city           state  \
# 0      2013     Field Pumpkin       154.5         Gleason       Wisconsin
# 1      2013     Field Pumpkin       146.5  New Middletown            Ohio
# 2      2013     Field Pumpkin       140.8  Combined Locks       Wisconsin
# 3      2013     Field Pumpkin       136.5       West Linn          Oregon
# 4      2013     Field Pumpkin       136.0      Saegertown    Pennsylvania
# ...     ...               ...         ...             ...             ...
# 10304  2021  Giant Watermelon         2.5          Garner  North Carolina
# 10305  2021  Giant Watermelon       181.0          Bailey  North Carolina
# 10306  2021  Giant Watermelon       159.5         Raleigh  North Carolina
# 10307  2021  Giant Watermelon       141.0     Spring Hope  North Carolina
# 10308  2021  Giant Watermelon       116.5     Rocky Mount  North Carolina
#
#       state_code   latitude   longitude
# 0             WI  45.308889  -89.496389
# 1             OH  40.961111  -80.557778
# 2             WI  44.265833  -88.314167
# 3             OR  45.365833 -122.611111
# 4             PA  41.718889  -80.147778
# ...          ...        ...         ...
# 10304         NC  35.711111  -78.614444
# 10305         NC  35.780556  -78.119167
# 10306         NC  35.771944  -78.638889
# 10307         NC  35.945000  -78.112222
# 10308         NC  35.938056  -77.790833
#
# [10309 rows x 8 columns]

# %%
pumpkin_clean.isna().sum()
# Out:
# year          0
# type          0
# weight_lbs    0
# city          0
# state         0
# state_code    0
# latitude      0
# longitude     0
# dtype: int64

# %% [markdown]
# # Calculate Nearest Station to Each Pumpkin

# %%
def distance(lat_a, long_a, lat_b, long_b):
    return ((float(lat_b) - float(lat_a))**2 + (float(long_b) - float(long_a))**2)**.5

# %%
us_stations.head(5)
# Out:
#             id state  latitude  longitude
# 0  US009052008    SD   43.7333   -96.6333
# 1  US10RMHS145    CO   40.5268  -105.1113
# 2  US10adam001    NE   40.5680   -98.5069
# 3  US10adam002    NE   40.5093   -98.5493
# 4  US10adam003    NE   40.4663   -98.6537

# %%
pumpkin_clean.head(5)
# Out:
#    year           type  weight_lbs            city         state state_code  \
# 0  2013  Field Pumpkin       154.5         Gleason     Wisconsin         WI
# 1  2013  Field Pumpkin       146.5  New Middletown          Ohio         OH
# 2  2013  Field Pumpkin       140.8  Combined Locks     Wisconsin         WI
# 3  2013  Field Pumpkin       136.5       West Linn        Oregon         OR
# 4  2013  Field Pumpkin       136.0      Saegertown  Pennsylvania         PA
#
#     latitude   longitude
# 0  45.308889  -89.496389
# 1  40.961111  -80.557778
# 2  44.265833  -88.314167
# 3  45.365833 -122.611111
# 4  41.718889  -80.147778

# %%
pumpkin_clean["nearest_station"] = ""
for i in range(len(pumpkin_clean)):
    
    state_stations = us_stations[us_stations.state == pumpkin_clean.loc[i,"state_code"]]
    
    pumpkin_lat = pumpkin_clean.loc[i,"latitude"]
    pumpkin_long = pumpkin_clean.loc[i,"longitude"]
    
    closest_distance = 1000000000000000000.0
    nearest_station = ""
    
    for index, row in state_stations.iterrows():
        check = distance(pumpkin_lat, pumpkin_long, row["latitude"], row["longitude"])
        if check < closest_distance:
            closest_distance = check
            nearest_station = row["id"]
    
    pumpkin_clean.loc[i, "nearest_station"] = nearest_station
    print(pumpkin_clean.loc[i, "nearest_station"])
    print(closest_distance)
    print(f"{i+1} pumpkins located. {len(pumpkin_clean) - (i+1)} left. {(i+1)/len(pumpkin_clean)*100:.0f}% done.\n")
# Out:
# US1WILN0003
# 0.09195883626069894
# 1 pumpkins located. 10308 left. 0% done.
#
# US1OHMH0002
# 0.07675439997843923
# 2 pumpkins located. 10307 left. 0% done.
#
# US1WIOG0002
# 0.015965821550423306
# 3 pumpkins located. 10306 left. 0% done.
#
# USC00356334
# 0.011906691904136612
# 4 pumpkins located. 10305 left. 0% done.
#
# US1PACW0005
# 0.0012860544506391482
# 5 pumpkins located. 10304 left. 0% done.
#
# US1OHGG0004
# 0.05571759277104635
# 6 pumpkins located. 10303 left. 0% done.
#
# US1PACW0005
# 0.0012860544506391482
# 7 pumpkins located. 10302 left. 0% done.
#
# US1PACW0005
# 0.0012860544506391482
# 8 pumpkins located. 10301 left. 0% done.
#
# US1WILN0003
# 0.09195883626069894
# 9 pumpkins located. 10300 left. 0% done.
#
# US1ORMN0085
# 0.014746508555246611
# 10 pumpkins located. 10299 left. 0% done.
#
# US1WATH0001
# 0.01644087414707886
# 11 pumpkins located. 10298 left. 0% done.
#
# US1PACW0005
# 0.0012860544506391482
# 12 pumpkins located. 10297 left. 0% done.
#
# US1WIOG0002
# 0.015965821550423306
# 13 pumpkins located. 10296 left. 0% done.
#
# USC00366233
# 0.1391318515511442
# 14 pumpkins located. 10295 left. 0% done.
#
# US1NYOS0006
# 0.012957990651723933
# 15 pumpkins located. 10294 left. 0% done.
#
# USW00024227
# 0.12729738143516653
# 16 pumpkins located. 10293 left. 0% done.
#
# USC00055056
# 0.0034178168616825887
# 17 pumpkins located. 10292 left. 0% done.
#
# US1MIWS0016
# 0.02695569609748464
# 18 pumpkins located. 10291 left. 0% done.
#
# US1INMN0024
# 0.010017268891765086
# 19 pumpkins located. 10290 left. 0% done.
#
# USC00366233
# 0.1391318515511442
# 20 pumpkins located. 10289 left. 0% done.
#
# US1WIOG0002
# 0.015965821550423306
# 21 pumpkins located. 10288 left. 0% done.
#
# USC00450945
# 0.03749121209296117
# 22 pumpkins located. 10287 left. 0% done.
#
# USW00024227
# 0.12729738143516653
# 23 pumpkins located. 10286 left. 0% done.
#
# USW00024227
# 0.12729738143516653
# 24 pumpkins located. 10285 left. 0% done.
#
# USW00024227
# 0.12729738143516653
# 25 pumpkins located. 10284 left. 0% done.
#
# US1OHGG0004
# 0.05571759277104635
# 26 pumpkins located. 10283 left. 0% done.
#
# USC00356334
# 0.011906691904136612
# 27 pumpkins located. 10282 left. 0% done.
#
# US1OHGG0004
# 0.05571759277104635
# 28 pumpkins located. 10281 left. 0% done.
#
# USC00450945
# 0.03749121209296117
# 29 pumpkins located. 10280 left. 0% done.
#
# US1WIVL0002
# 0.008539190929489054
# 30 pumpkins located. 10279 left. 0% done.
#
# USC00361255
# 0.11167202362386663
# 31 pumpkins located. 10278 left. 0% done.
#
# US1WIWN0004
# 0.010326333949661136
# 32 pumpkins located. 10277 left. 0% done.
#
# USC00450945
# 0.03749121209296117
# 33 pumpkins located. 10276 left. 0% done.
#
# USC00477202
# 0.02065374885414909
# 34 pumpkins located. 10275 left. 0% done.
#
# USC00450945
# 0.03749121209296117
# 35 pumpkins located. 10274 left. 0% done.
#
# US1WASG0040
# 0.0012752186949772652
# 36 pumpkins located. 10273 left. 0% done.
#
# US1NYSV0003
# 0.013474330419359984
# 37 pumpkins located. 10272 left. 0% done.
#
# USW00024227
# 0.12729738143516653
# 38 pumpkins located. 10271 left. 0% done.
#
# US1OHGG0004
# 0.05571759277104635
# 39 pumpkins located. 10270 left. 0% done.
#
# USC00477202
# 0.02065374885414909
# 40 pumpkins located. 10269 left. 0% done.
#
# US1MNSR0039
# 0.00273232506301261
# 41 pumpkins located. 10268 left. 0% done.
#
# USC00364477
# 0.07043627152026077
# 42 pumpkins located. 10267 left. 0% done.
#
# US1NYOS0006
# 0.012957990651723933
# 43 pumpkins located. 10266 left. 0% done.
#
# USC00356334
# 0.011906691904136612
# 44 pumpkins located. 10265 left. 0% done.
#
# USC00356334
# 0.011906691904136612
# 45 pumpkins located. 10264 left. 0% done.
#
# USC00200233
# 0.03611788836921223
# 46 pumpkins located. 10263 left. 0% done.
#
# US1WISW0003
# 0.14174950884493073
# 47 pumpkins located. 10262 left. 0% done.
#
# USC00361255
# 0.11167202362386663
# 48 pumpkins located. 10261 left. 0% done.
#
# USC00356334
# 0.011906691904136612
# 49 pumpkins located. 10260 left. 0% done.
#
# USC00356334
# 0.011906691904136612
# 50 pumpkins located. 10259 left. 0% done.
#
# US1OHMH0002
# 0.07675439997843923
# 51 pumpkins located. 10258 left. 0% done.
#
# US1MNSR0039
# 0.00273232506301261
# 52 pumpkins located. 10257 left. 1% done.
#
# USC00451189
# 0.010255424713285362
# 53 pumpkins located. 10256 left. 1% done.
#
# USC00354819
# 0.005882645474612106
# 54 pumpkins located. 10255 left. 1% done.
#
# USC00450945
# 0.03749121209296117
# 55 pumpkins located. 10254 left. 1% done.
#
# USC00336050
# 0.06953891273380723
# 56 pumpkins located. 10253 left. 1% done.
#
# US1NYOS0006
# 0.012957990651723933
# 57 pumpkins located. 10252 left. 1% done.
#
# US1WIOG0002
# 0.015965821550423306
# 58 pumpkins located. 10251 left. 1% done.
#
# US1NYER0058
# 0.008900561780025858
# 59 pumpkins located. 10250 left. 1% done.
#
# US1VTCH0015
# 0.011113835777072992
# 60 pumpkins located. 10249 left. 1% done.
#
# USC00337417
# 0.025473882534074073
# 61 pumpkins located. 10248 left. 1% done.
#
# US1WATH0001
# 0.01644087414707886
# 62 pumpkins located. 10247 left. 1% done.
#
# US1NYOS0006
# 0.012957990651723933
# 63 pumpkins located. 10246 left. 1% done.
#
# US1WISW0003
# 0.14174950884493073
# 64 pumpkins located. 10245 left. 1% done.
#
# US1MNSR0039
# 0.00273232506301261
# 65 pumpkins located. 10244 left. 1% done.
#
# US1WIOG0002
# 0.015965821550423306
# 66 pumpkins located. 10243 left. 1% done.
#
# USC00055056
# 0.0034178168616825887
# 67 pumpkins located. 10242 left. 1% done.
#
# US1VTCH0015
# 0.011113835777072992
# 68 pumpkins located. 10241 left. 1% done.
#
# USC00069568
# 0.08025885306961347
# 69 pumpkins located. 10240 left. 1% done.
#
# US1OHGG0004
# 0.05571759277104635
# 70 pumpkins located. 10239 left. 1% done.
#
# US1WATH0001
# 0.01644087414707886
# 71 pumpkins located. 10238 left. 1% done.
#
# USC00356334
# 0.011906691904136612
# 72 pumpkins located. 10237 left. 1% done.
#
# USC00069568
# 0.08025885306961347
# 73 pumpkins located. 10236 left. 1% done.
#
# US1IAWS0002
# 0.09243093170605665
# 74 pumpkins located. 10235 left. 1% done.
#
# USC00365662
# 0.006598085786788081
# 75 pumpkins located. 10234 left. 1% done.
#
# US1MIOK0067
# 0.06056651669196267
# 76 pumpkins located. 10233 left. 1% done.
#
# US1WISW0003
# 0.14174950884493073
# 77 pumpkins located. 10232 left. 1% done.
#
# US1WIWK0081
# 0.02178187356611217
# 78 pumpkins located. 10231 left. 1% done.
#
# US1WIWK0081
# 0.02178187356611217
# 79 pumpkins located. 10230 left. 1% done.
#
# US1MABE0021
# 0.006456564121118058
# 80 pumpkins located. 10229 left. 1% done.
#
# USC00202308
# 0.010991581582289802
# 81 pumpkins located. 10228 left. 1% done.
#
# US1WIWN0004
# 0.010326333949661136
# 82 pumpkins located. 10227 left. 1% done.
#
# USC00330637
# 0.043120243322595536
# 83 pumpkins located. 10226 left. 1% done.
#
# USC00202308
# 0.010991581582289802
# 84 pumpkins located. 10225 left. 1% done.
#
# US1WATH0001
# 0.01644087414707886
# 85 pumpkins located. 10224 left. 1% done.
#
# USC00133517
# 0.1626868261172361
# 86 pumpkins located. 10223 left. 1% done.
#
# USC00126830
# 0.1338066596102363
# 87 pumpkins located. 10222 left. 1% done.
#
# US1WIWK0081
# 0.02178187356611217
# 88 pumpkins located. 10221 left. 1% done.
#
# US1MIOK0067
# 0.06056651669196267
# 89 pumpkins located. 10220 left. 1% done.
#
# US1INRN0007
# 0.08468642148655887
# 90 pumpkins located. 10219 left. 1% done.
#
# US1WAPR0020
# 0.05939614823943253
# 91 pumpkins located. 10218 left. 1% done.
#
# US1WATH0001
# 0.01644087414707886
# 92 pumpkins located. 10217 left. 1% done.
#
# USC00107210
# 0.004216972379562929
# 93 pumpkins located. 10216 left. 1% done.
#
# USC00331770
# 0.06936675196216512
# 94 pumpkins located. 10215 left. 1% done.
#
# US1WIWK0081
# 0.02178187356611217
# 95 pumpkins located. 10214 left. 1% done.
#
# USC00330637
# 0.043120243322595536
# 96 pumpkins located. 10213 left. 1% done.
#
# US1WISW0003
# 0.14174950884493073
# 97 pumpkins located. 10212 left. 1% done.
#
# USC00200842
# 0.09539157639129879
# 98 pumpkins located. 10211 left. 1% done.
#
# USC00450945
# 0.03749121209296117
# 99 pumpkins located. 10210 left. 1% done.
#
# USC00200842
# 0.09539157639129879
# 100 pumpkins located. 10209 left. 1% done.
#
# USC00304808
# 0.008516741682705773
# 101 pumpkins located. 10208 left. 1% done.
#
# USC00352706
# 0.003166370824789818
# 102 pumpkins located. 10207 left. 1% done.
#
# US1MAWR0068
# 0.019172163199036075
# 103 pumpkins located. 10206 left. 1% done.
#
# USC00475178
# 0.01895224698233919
# 104 pumpkins located. 10205 left. 1% done.
#
# USC00352706
# 0.003166370824789818
# 105 pumpkins located. 10204 left. 1% done.
#
# USC00336645
# 0.00941191653385006
# 106 pumpkins located. 10203 left. 1% done.
#
# US1WICR0004
# 0.0009868398248927518
# 107 pumpkins located. 10202 left. 1% done.
#
# US1WIWK0081
# 0.02178187356611217
# 108 pumpkins located. 10201 left. 1% done.
#
# USC00360867
# 0.008249531973394645
# 109 pumpkins located. 10200 left. 1% done.
# USC00475178
# 0.01895224698233919
# 110 pumpkins located. 10199 left. 1% done.
#
# US1WIWK0081
# 0.02178187356611217
# 111 pumpkins located. 10198 left. 1% done.
#
# US1WATH0001
# 0.01644087414707886
# 112 pumpkins located. 10197 left. 1% done.
#
# USC00330637
# 0.043120243322595536
# 113 pumpkins located. 10196 left. 1% done.
#
# USC00336050
# 0.06953891273380723
# 114 pumpkins located. 10195 left. 1% done.
#
# US1WIPT0012
# 0.038920366413098435
# 115 pumpkins located. 10194 left. 1% done.
#
# US1MNWR0029
# 0.012439914096168014
# 116 pumpkins located. 10193 left. 1% done.
#
# US1MNWR0029
# 0.012439914096168014
# 117 pumpkins located. 10192 left. 1% done.
#
# USC00136566
# 0.0037397559505946178
# 118 pumpkins located. 10191 left. 1% done.
#
# USC00153052
# 0.04087519489593608
# 119 pumpkins located. 10190 left. 1% done.
#
# US1VTCH0019
# 0.012558047402763698
# 120 pumpkins located. 10189 left. 1% done.
#
# US1WIWN0004
# 0.010326333949661136
# 121 pumpkins located. 10188 left. 1% done.
#
# USC00136566
# 0.0037397559505946178
# 122 pumpkins located. 10187 left. 1% done.
#
# USC00136566
# 0.0037397559505946178
# 123 pumpkins located. 10186 left. 1% done.
#
# US1OHPL0001
# 0.005388945727134212
# 124 pumpkins located. 10185 left. 1% done.
#
# US1INAL0041
# 0.01433617433522398
# 125 pumpkins located. 10184 left. 1% done.
#
# US1UTUT0026
# 0.010097883508932579
# 126 pumpkins located. 10183 left. 1% done.
#
# US1WIBN0010
# 0.029702501174972758
# 127 pumpkins located. 10182 left. 1% done.
#
# USC00360352
# 0.04479836056029247
# 128 pumpkins located. 10181 left. 1% done.
#
# US1WIWK0081
# 0.02178187356611217
# 129 pumpkins located. 10180 left. 1% done.
#
# US1WIWK0081
# 0.02178187356611217
# 130 pumpkins located. 10179 left. 1% done.
#
# US1MIOK0067
# 0.06056651669196267
# 131 pumpkins located. 10178 left. 1% done.
#
# USC00336645
# 0.00941191653385006
# 132 pumpkins located. 10177 left. 1% done.
#
# US1WIWN0004
# 0.010326333949661136
# 133 pumpkins located. 10176 left. 1% done.
#
# USC00129724
# 0.039444652891490684
# 134 pumpkins located. 10175 left. 1% done.
#
# USC00190655
# 0.00880530523320593
# 135 pumpkins located. 10174 left. 1% done.
#
# US1WAPR0020
# 0.05939614823943253
# 136 pumpkins located. 10173 left. 1% done.
#
# USC00437954
# 0.04555271497649278
# 137 pumpkins located. 10172 left. 1% done.
#
# US1UTUT0026
# 0.010097883508932579
# 138 pumpkins located. 10171 left. 1% done.
#
# US1KYNL0004
# 0.10116272030866764
# 139 pumpkins located. 10170 left. 1% done.
#
# US1OHPL0001
# 0.005388945727134212
# 140 pumpkins located. 10169 left. 1% done.
#
# USC00364477
# 0.07043627152026077
# 141 pumpkins located. 10168 left. 1% done.
#
# US1OHCB0006
# 0.013103222513941117
# 142 pumpkins located. 10167 left. 1% done.
#
# USC00203947
# 0.013668127311377102
# 143 pumpkins located. 10166 left. 1% done.
#
# USC00364992
# 0.013002816532601933
# 144 pumpkins located. 10165 left. 1% done.
#
# USC00362629
# 0.009320862329733504
# 145 pumpkins located. 10164 left. 1% done.
#
# US1VTRT0019
# 0.04282462357336368
# 146 pumpkins located. 10163 left. 1% done.
#
# US1WISC0027
# 0.02653237257710141
# 147 pumpkins located. 10162 left. 1% done.
#
# US1INMN0024
# 0.010017268891765086
# 148 pumpkins located. 10161 left. 1% done.
#
# USC00129724
# 0.039444652891490684
# 149 pumpkins located. 10160 left. 1% done.
#
# US1KYNL0004
# 0.10116272030866764
# 150 pumpkins located. 10159 left. 1% done.
#
# USC00437954
# 0.04555271497649278
# 151 pumpkins located. 10158 left. 1% done.
#
# US1WIWK0081
# 0.02178187356611217
# 152 pumpkins located. 10157 left. 1% done.
#
# USC00066645
# 0.0074520957696550165
# 153 pumpkins located. 10156 left. 1% done.
#
# USC00066645
# 0.0074520957696550165
# 154 pumpkins located. 10155 left. 1% done.
#
# US1MANF0026
# 0.02692860094565073
# 155 pumpkins located. 10154 left. 2% done.
#
# USC00248564
# 0.08868051150196954
# 156 pumpkins located. 10153 left. 2% done.
#
# USC00066645
# 0.0074520957696550165
# 157 pumpkins located. 10152 left. 2% done.
#
# USC00129724
# 0.039444652891490684
# 158 pumpkins located. 10151 left. 2% done.
#
# US1MNOL0009
# 0.10927702731031899
# 159 pumpkins located. 10150 left. 2% done.
#
# US1OHWD0003
# 0.05992279350739841
# 160 pumpkins located. 10149 left. 2% done.
#
# USC00126830
# 0.1338066596102363
# 161 pumpkins located. 10148 left. 2% done.
#
# USC00130213
# 0.008956822477312885
# 162 pumpkins located. 10147 left. 2% done.
#
# USC00336333
# 0.032092097073423344
# 163 pumpkins located. 10146 left. 2% done.
#
# US1SDMH0002
# 0.024800201612085643
# 164 pumpkins located. 10145 left. 2% done.
#
# US1ORWS0129
# 0.012196446213956444
# 165 pumpkins located. 10144 left. 2% done.
#
# USC00332920
# 0.020836985197002198
# 166 pumpkins located. 10143 left. 2% done.
#
# USC00130213
# 0.008956822477312885
# 167 pumpkins located. 10142 left. 2% done.
#
# USW00024227
# 0.12729738143516653
# 168 pumpkins located. 10141 left. 2% done.
#
# US1NYOS0006
# 0.012957990651723933
# 169 pumpkins located. 10140 left. 2% done.
#
# USC00450945
# 0.03749121209296117
# 170 pumpkins located. 10139 left. 2% done.
#
# US1ORCC0027
# 0.006045420958874934
# 171 pumpkins located. 10138 left. 2% done.
#
# US1NHMR0047
# 0.08622770530246886
# 172 pumpkins located. 10137 left. 2% done.
#
# US1ORCC0027
# 0.006045420958874934
# 173 pumpkins located. 10136 left. 2% done.
#
# US1MAPL0048
# 0.023367002634049994
# 174 pumpkins located. 10135 left. 2% done.
#
# US1IAWH0006
# 0.0038605828899237193
# 175 pumpkins located. 10134 left. 2% done.
#
# USC00335356
# 0.08172587847248167
# 176 pumpkins located. 10133 left. 2% done.
#
# USC00208751
# 0.033524744511626244
# 177 pumpkins located. 10132 left. 2% done.
#
# USC00156558
# 0.005096838260131603
# 178 pumpkins located. 10131 left. 2% done.
#
# US1ORCC0103
# 0.023392233790941325
# 179 pumpkins located. 10130 left. 2% done.
#
# US1COJF0130
# 0.031247511174007668
# 180 pumpkins located. 10129 left. 2% done.
#
# USC00352693
# 0.02574163578407676
# 181 pumpkins located. 10128 left. 2% done.
#
# US1WIWK0081
# 0.02178187356611217
# 182 pumpkins located. 10127 left. 2% done.
#
# USC00193876
# 0.028137192073471613
# 183 pumpkins located. 10126 left. 2% done.
#
# USC00331245
# 0.010006288183439743
# 184 pumpkins located. 10125 left. 2% done.
#
# USC00200842
# 0.09539157639129879
# 185 pumpkins located. 10124 left. 2% done.
#
# US1OHHM0022
# 0.02019467510806173
# 186 pumpkins located. 10123 left. 2% done.
#
# USC00307405
# 0.012627127313845165
# 187 pumpkins located. 10122 left. 2% done.
#
# USC00450176
# 0.002378969535336015
# 188 pumpkins located. 10121 left. 2% done.
#
# US1CTNH0016
# 0.02961052623984213
# 189 pumpkins located. 10120 left. 2% done.
#
# USC00042760
# 0.10118263287762615
# 190 pumpkins located. 10119 left. 2% done.
#
# USC00042760
# 0.10118263287762615
# 191 pumpkins located. 10118 left. 2% done.
#
# USC00117457
# 0.043527493511116434
# 192 pumpkins located. 10117 left. 2% done.
#
# USC00352693
# 0.02574163578407676
# 193 pumpkins located. 10116 left. 2% done.
#
# US1WAPR0019
# 0.010564393037465813
# 194 pumpkins located. 10115 left. 2% done.
#
# USC00201476
# 0.01739604645027681
# 195 pumpkins located. 10114 left. 2% done.
#
# US1WIDA0094
# 0.023939640353398392
# 196 pumpkins located. 10113 left. 2% done.
#
# USC00205451
# 0.006986702572746285
# 197 pumpkins located. 10112 left. 2% done.
#
# US1MNOL0009
# 0.10927702731031899
# 198 pumpkins located. 10111 left. 2% done.
#
# USC00279291
# 0.030176578097588985
# 199 pumpkins located. 10110 left. 2% done.
#
# USC00194360
# 0.01579480611625238
# 200 pumpkins located. 10109 left. 2% done.
#
# USC00045391
# 0.017416576019713755
# 201 pumpkins located. 10108 left. 2% done.
#
# USC00041428
# 0.05893888682568522
# 202 pumpkins located. 10107 left. 2% done.
#
# USC00040383
# 0.013267330469244066
# 203 pumpkins located. 10106 left. 2% done.
#
# US1WASP0013
# 0.005688210897116438
# 204 pumpkins located. 10105 left. 2% done.
#
# US1WASP0013
# 0.005688210897116438
# 205 pumpkins located. 10104 left. 2% done.
#
# US1MTLK0003
# 0.010790381645248167
# 206 pumpkins located. 10103 left. 2% done.
#
# USC00203337
# 0.0036293691256189843
# 207 pumpkins located. 10102 left. 2% done.
#
# US1UTBE0014
# 0.006210670308428146
# 208 pumpkins located. 10101 left. 2% done.
#
# USC00131257
# 0.0031291494131691273
# 209 pumpkins located. 10100 left. 2% done.
#
# US1NYSV0003
# 0.013474330419359984
# 210 pumpkins located. 10099 left. 2% done.
#
# US1ILCK0063
# 0.011022205589200897
# 211 pumpkins located. 10098 left. 2% done.
#
# US1WIWS0016
# 0.008418757393441148
# 212 pumpkins located. 10097 left. 2% done.
#
# US1NYCQ0006
# 0.03438431941640623
# 213 pumpkins located. 10096 left. 2% done.
#
# USC00177479
# 0.019163030598782722
# 214 pumpkins located. 10095 left. 2% done.
#
# US1INLK0094
# 0.011281096227762894
# 215 pumpkins located. 10094 left. 2% done.
#
# USC00500287
# 0.01711792114128376
# 216 pumpkins located. 10093 left. 2% done.
#
# USC00207662
# 0.013656375303123929
# 217 pumpkins located. 10092 left. 2% done.
# USC00154620
# 0.00778609675768362
# 218 pumpkins located. 10091 left. 2% done.
#
# USC00360620
# 0.0867703043445579
# 219 pumpkins located. 10090 left. 2% done.
#
# US1CASN0062
# 0.007228607843838768
# 220 pumpkins located. 10089 left. 2% done.
#
# USC00331592
# 0.013601196806533643
# 221 pumpkins located. 10088 left. 2% done.
#
# USC00186620
# 0.008513158297600682
# 222 pumpkins located. 10087 left. 2% done.
#
# USC00177479
# 0.019163030598782722
# 223 pumpkins located. 10086 left. 2% done.
#
# US1MNOT0027
# 0.00905676234644907
# 224 pumpkins located. 10085 left. 2% done.
#
# US1OHHM0022
# 0.02019467510806173
# 225 pumpkins located. 10084 left. 2% done.
#
# US1WYLM0132
# 0.00856592159898838
# 226 pumpkins located. 10083 left. 2% done.
#
# USW00094298
# 0.018348873427265794
# 227 pumpkins located. 10082 left. 2% done.
#
# USC00203337
# 0.0036293691256189843
# 228 pumpkins located. 10081 left. 2% done.
#
# USW00023293
# 0.07152573089629875
# 229 pumpkins located. 10080 left. 2% done.
#
# US1OHLS0022
# 0.030070321876900005
# 230 pumpkins located. 10079 left. 2% done.
#
# USC00017157
# 0.0303318663462805
# 231 pumpkins located. 10078 left. 2% done.
#
# US1WAKG0013
# 0.024789442366466973
# 232 pumpkins located. 10077 left. 2% done.
#
# USC00332170
# 0.06009116693990782
# 233 pumpkins located. 10076 left. 2% done.
#
# US1COJF0299
# 0.01259252604124377
# 234 pumpkins located. 10075 left. 2% done.
#
# US1CASJ0010
# 0.011999702732984828
# 235 pumpkins located. 10074 left. 2% done.
#
# US1CTFR0068
# 0.01855044668195797
# 236 pumpkins located. 10073 left. 2% done.
#
# US1NHHL0059
# 0.03065274348585645
# 237 pumpkins located. 10072 left. 2% done.
#
# US1CAPC0049
# 0.030551705381695472
# 238 pumpkins located. 10071 left. 2% done.
#
# US1IACN0007
# 0.021681234156983167
# 239 pumpkins located. 10070 left. 2% done.
#
# US1WIOG0002
# 0.015965821550423306
# 240 pumpkins located. 10069 left. 2% done.
#
# USC00362677
# 0.012622610733519364
# 241 pumpkins located. 10068 left. 2% done.
#
# US1ILMU0002
# 0.017289241284694817
# 242 pumpkins located. 10067 left. 2% done.
#
# USC00478229
# 0.0076029168218430246
# 243 pumpkins located. 10066 left. 2% done.
#
# US1MIBY0002
# 0.03968224719846476
# 244 pumpkins located. 10065 left. 2% done.
#
# USC00305597
# 0.04139643007217125
# 245 pumpkins located. 10064 left. 2% done.
#
# USW00024175
# 0.009116351338666263
# 246 pumpkins located. 10063 left. 2% done.
#
# USC00176881
# 0.03604699129926323
# 247 pumpkins located. 10062 left. 2% done.
#
# USC00186620
# 0.008513158297600682
# 248 pumpkins located. 10061 left. 2% done.
#
# USC00361723
# 0.010334158198873922
# 249 pumpkins located. 10060 left. 2% done.
#
# USC00200233
# 0.03611788836921223
# 250 pumpkins located. 10059 left. 2% done.
#
# USC00041960
# 0.014296633567378743
# 251 pumpkins located. 10058 left. 2% done.
#
# USC00360620
# 0.0867703043445579
# 252 pumpkins located. 10057 left. 2% done.
#
# US1VTCH0015
# 0.011113835777072992
# 253 pumpkins located. 10056 left. 2% done.
#
# US1MIIH0025
# 0.04468407035186332
# 254 pumpkins located. 10055 left. 2% done.
#
# USC00017157
# 0.0303318663462805
# 255 pumpkins located. 10054 left. 2% done.
#
# US1NYOD0060
# 0.11211197534629179
# 256 pumpkins located. 10053 left. 2% done.
#
# US1CASN0168
# 0.0085345216766926
# 257 pumpkins located. 10052 left. 2% done.
#
# US1ORPK0021
# 0.008989607346797707
# 258 pumpkins located. 10051 left. 3% done.
#
# US1WIMC0016
# 0.007794841377485465
# 259 pumpkins located. 10050 left. 3% done.
#
# US1ILCK0063
# 0.011022205589200897
# 260 pumpkins located. 10049 left. 3% done.
#
# USC00130213
# 0.008956822477312885
# 261 pumpkins located. 10048 left. 3% done.
#
# US1MTLK0003
# 0.010790381645248167
# 262 pumpkins located. 10047 left. 3% done.
#
# US1ORDG0025
# 0.019321970402892154
# 263 pumpkins located. 10046 left. 3% done.
#
# US1WISW0003
# 0.14174950884493073
# 264 pumpkins located. 10045 left. 3% done.
#
# USC00214562
# 0.014044798044116872
# 265 pumpkins located. 10044 left. 3% done.
#
# USC00205451
# 0.006986702572746285
# 266 pumpkins located. 10043 left. 3% done.
#
# US1COJF0391
# 0.013104997586056747
# 267 pumpkins located. 10042 left. 3% done.
#
# USC00055056
# 0.0034178168616825887
# 268 pumpkins located. 10041 left. 3% done.
#
# US1WIBR0002
# 0.11209588672315235
# 269 pumpkins located. 10040 left. 3% done.
#
# US1WAKG0028
# 0.015274115415630405
# 270 pumpkins located. 10039 left. 3% done.
#
# USC00186620
# 0.008513158297600682
# 271 pumpkins located. 10038 left. 3% done.
#
# USC00040383
# 0.013267330469244066
# 272 pumpkins located. 10037 left. 3% done.
#
# USC00193876
# 0.028137192073471613
# 273 pumpkins located. 10036 left. 3% done.
#
# US1ORCC0103
# 0.023392233790941325
# 274 pumpkins located. 10035 left. 3% done.
#
# USC00126830
# 0.1338066596102363
# 275 pumpkins located. 10034 left. 3% done.
#
# US1MIBY0002
# 0.03968224719846476
# 276 pumpkins located. 10033 left. 3% done.
#
# US1OHGY0004
# 0.06861759414084401
# 277 pumpkins located. 10032 left. 3% done.
#
# US1MNCV0045
# 0.018463948188842203
# 278 pumpkins located. 10031 left. 3% done.
#
# USC00045909
# 0.013703728401417526
# 279 pumpkins located. 10030 left. 3% done.
#
# USC00304808
# 0.008516741682705773
# 280 pumpkins located. 10029 left. 3% done.
#
# US1INHN0012
# 0.0064449151553785935
# 281 pumpkins located. 10028 left. 3% done.
#
# US1WATH0001
# 0.01644087414707886
# 282 pumpkins located. 10027 left. 3% done.
#
# USC00329155
# 0.010038472081450898
# 283 pumpkins located. 10026 left. 3% done.
#
# USC00129724
# 0.039444652891490684
# 284 pumpkins located. 10025 left. 3% done.
#
# US1MNGR0008
# 0.034585051109553754
# 285 pumpkins located. 10024 left. 3% done.
#
# US1WICT0001
# 0.011048434099469645
# 286 pumpkins located. 10023 left. 3% done.
#
# US1VTCH0019
# 0.012558047402763698
# 287 pumpkins located. 10022 left. 3% done.
#
# US1NCAG0005
# 0.044017253844932866
# 288 pumpkins located. 10021 left. 3% done.
#
# US1IAPK0034
# 0.010614155386549041
# 289 pumpkins located. 10020 left. 3% done.
#
# US1ORCC0103
# 0.023392233790941325
# 290 pumpkins located. 10019 left. 3% done.
#
# US1ILDP0161
# 0.009868389664465002
# 291 pumpkins located. 10018 left. 3% done.
#
# USC00043244
# 0.02895699170994996
# 292 pumpkins located. 10017 left. 3% done.
#
# USC00055056
# 0.0034178168616825887
# 293 pumpkins located. 10016 left. 3% done.
#
# USC00360352
# 0.04479836056029247
# 294 pumpkins located. 10015 left. 3% done.
#
# US1ORCC0027
# 0.006045420958874934
# 295 pumpkins located. 10014 left. 3% done.
#
# USC00424542
# 0.024968245467593735
# 296 pumpkins located. 10013 left. 3% done.
#
# US1IACN0007
# 0.021681234156983167
# 297 pumpkins located. 10012 left. 3% done.
#
# USC00046521
# 0.004476551803567035
# 298 pumpkins located. 10011 left. 3% done.
#
# US1VTCH0019
# 0.012558047402763698
# 299 pumpkins located. 10010 left. 3% done.
#
# USC00335830
# 0.014572198686881038
# 300 pumpkins located. 10009 left. 3% done.
#
# USC00311815
# 0.010048671566435215
# 301 pumpkins located. 10008 left. 3% done.
#
# US1WIOG0005
# 0.030357065262633005
# 302 pumpkins located. 10007 left. 3% done.
#
# US1ORPK0021
# 0.008989607346797707
# 303 pumpkins located. 10006 left. 3% done.
#
# US1MIAN0025
# 0.005778121079553107
# 304 pumpkins located. 10005 left. 3% done.
#
# USC00055056
# 0.0034178168616825887
# 305 pumpkins located. 10004 left. 3% done.
#
# USC00365101
# 0.05925597636163656
# 306 pumpkins located. 10003 left. 3% done.
#
# US1MANF0026
# 0.02692860094565073
# 307 pumpkins located. 10002 left. 3% done.
#
# US1ORCC0027
# 0.006045420958874934
# 308 pumpkins located. 10001 left. 3% done.
#
# US1ORPK0021
# 0.008989607346797707
# 309 pumpkins located. 10000 left. 3% done.
#
# USC00368692
# 0.006483934676568965
# 310 pumpkins located. 9999 left. 3% done.
#
# USC00472423
# 0.005566477530719535
# 311 pumpkins located. 9998 left. 3% done.
#
# US1CTNH0042
# 0.011460193478728651
# 312 pumpkins located. 9997 left. 3% done.
#
# USC00352693
# 0.02574163578407676
# 313 pumpkins located. 9996 left. 3% done.
#
# US1IAWH0006
# 0.0038605828899237193
# 314 pumpkins located. 9995 left. 3% done.
#
# US1ORJS0032
# 0.01455531317869366
# 315 pumpkins located. 9994 left. 3% done.
#
# US1PAWN0012
# 0.03706614004423408
# 316 pumpkins located. 9993 left. 3% done.
#
# US1MIWS0018
# 0.015031076294450024
# 317 pumpkins located. 9992 left. 3% done.
#
# US1NYNG0011
# 0.02889187468338924
# 318 pumpkins located. 9991 left. 3% done.
#
# USC00208751
# 0.033524744511626244
# 319 pumpkins located. 9990 left. 3% done.
#
# USC00471708
# 0.0602836833318155
# 320 pumpkins located. 9989 left. 3% done.
#
# US1ORCC0027
# 0.006045420958874934
# 321 pumpkins located. 9988 left. 3% done.
#
# USC00450945
# 0.03749121209296117
# 322 pumpkins located. 9987 left. 3% done.
#
# US1IADB0012
# 0.01319794469605416
# 323 pumpkins located. 9986 left. 3% done.
#
# USC00424970
# 0.04569522628984372
# 324 pumpkins located. 9985 left. 3% done.
#
# USC00307749
# 0.05221479073364657
# 325 pumpkins located. 9984 left. 3% done.
# USC00450945
# 0.03749121209296117
# 326 pumpkins located. 9983 left. 3% done.
#
# US1OHPT0012
# 0.04495242136325724
# 327 pumpkins located. 9982 left. 3% done.
#
# US1IAPK0034
# 0.010614155386549041
# 328 pumpkins located. 9981 left. 3% done.
#
# USC00205451
# 0.006986702572746285
# 329 pumpkins located. 9980 left. 3% done.
#
# US1ALJF0037
# 0.03233171786729538
# 330 pumpkins located. 9979 left. 3% done.
#
# USC00214562
# 0.014044798044116872
# 331 pumpkins located. 9978 left. 3% done.
#
# USC00122184
# 0.038500104191034785
# 332 pumpkins located. 9977 left. 3% done.
#
# US1COJF0299
# 0.01259252604124377
# 333 pumpkins located. 9976 left. 3% done.
#
# US1PABR0019
# 0.03595566714720868
# 334 pumpkins located. 9975 left. 3% done.
#
# USC00194360
# 0.01579480611625238
# 335 pumpkins located. 9974 left. 3% done.
#
# US1WIBN0010
# 0.029702501174972758
# 336 pumpkins located. 9973 left. 3% done.
#
# USC00041960
# 0.014296633567378743
# 337 pumpkins located. 9972 left. 3% done.
#
# US1WYLM0132
# 0.00856592159898838
# 338 pumpkins located. 9971 left. 3% done.
#
# USC00130753
# 0.012477632056208355
# 339 pumpkins located. 9970 left. 3% done.
#
# USC00055056
# 0.0034178168616825887
# 340 pumpkins located. 9969 left. 3% done.
#
# US1WAKG0248
# 0.048670402482226184
# 341 pumpkins located. 9968 left. 3% done.
#
# USC00200842
# 0.09539157639129879
# 342 pumpkins located. 9967 left. 3% done.
#
# USC00368692
# 0.006483934676568965
# 343 pumpkins located. 9966 left. 3% done.
#
# USC00360867
# 0.008249531973394645
# 344 pumpkins located. 9965 left. 3% done.
#
# US1CASJ0010
# 0.011999702732984828
# 345 pumpkins located. 9964 left. 3% done.
#
# USC00478027
# 0.0974711291829605
# 346 pumpkins located. 9963 left. 3% done.
#
# USC00369733
# 0.007933620007301412
# 347 pumpkins located. 9962 left. 3% done.
#
# USC00426919
# 0.027847969564947967
# 348 pumpkins located. 9961 left. 3% done.
#
# US1INAL0041
# 0.01433617433522398
# 349 pumpkins located. 9960 left. 3% done.
#
# US1NYFL0009
# 0.06830340548061818
# 350 pumpkins located. 9959 left. 3% done.
#
# USC00190655
# 0.00880530523320593
# 351 pumpkins located. 9958 left. 3% done.
#
# US1PAWN0012
# 0.03706614004423408
# 352 pumpkins located. 9957 left. 3% done.
#
# USC00478241
# 0.019645773899241527
# 353 pumpkins located. 9956 left. 3% done.
#
# USC00450945
# 0.03749121209296117
# 354 pumpkins located. 9955 left. 3% done.
#
# USC00055056
# 0.0034178168616825887
# 355 pumpkins located. 9954 left. 3% done.
#
# US1OHER0017
# 0.009822483028236155
# 356 pumpkins located. 9953 left. 3% done.
#
# USC00307818
# 0.06278418829809229
# 357 pumpkins located. 9952 left. 3% done.
#
# US1WIMT0014
# 0.03753831672731039
# 358 pumpkins located. 9951 left. 3% done.
#
# US1MICL0003
# 0.005143960980609396
# 359 pumpkins located. 9950 left. 3% done.
#
# US1WATH0001
# 0.01644087414707886
# 360 pumpkins located. 9949 left. 3% done.
#
# US1CTHR0068
# 0.00577145611435754
# 361 pumpkins located. 9948 left. 4% done.
#
# US1CASA0061
# 0.07435991865063676
# 362 pumpkins located. 9947 left. 4% done.
#
# USC00352997
# 0.008385385582077999
# 363 pumpkins located. 9946 left. 4% done.
#
# US1WIOG0002
# 0.015965821550423306
# 364 pumpkins located. 9945 left. 4% done.
#
# US1RIWS0051
# 0.010169368444998361
# 365 pumpkins located. 9944 left. 4% done.
#
# USC00305715
# 0.027765228471957965
# 366 pumpkins located. 9943 left. 4% done.
#
# USC00331254
# 0.009469274992833164
# 367 pumpkins located. 9942 left. 4% done.
#
# US1VTFR0021
# 0.09712470706120338
# 368 pumpkins located. 9941 left. 4% done.
#
# US1ORCC0035
# 0.010517844578146222
# 369 pumpkins located. 9940 left. 4% done.
#
# USC00451189
# 0.010255424713285362
# 370 pumpkins located. 9939 left. 4% done.
#
# US1COJF0426
# 0.006800192953150706
# 371 pumpkins located. 9938 left. 4% done.
#
# US1WISW0003
# 0.14174950884493073
# 372 pumpkins located. 9937 left. 4% done.
#
# US1UTUT0026
# 0.010097883508932579
# 373 pumpkins located. 9936 left. 4% done.
#
# US1UTUT0026
# 0.010097883508932579
# 374 pumpkins located. 9935 left. 4% done.
#
# USC00398930
# 0.003538274183840974
# 375 pumpkins located. 9934 left. 4% done.
#
# USC00213206
# 0.09530674593253981
# 376 pumpkins located. 9933 left. 4% done.
#
# US1ORKL0016
# 0.007044876958467453
# 377 pumpkins located. 9932 left. 4% done.
#
# US1MNOL0015
# 0.016600440407705086
# 378 pumpkins located. 9931 left. 4% done.
#
# USC00426400
# 0.03260554220863305
# 379 pumpkins located. 9930 left. 4% done.
#
# USC00248564
# 0.08868051150196954
# 380 pumpkins located. 9929 left. 4% done.
#
# US1CASC0008
# 0.01519680440749484
# 381 pumpkins located. 9928 left. 4% done.
#
# USC00450945
# 0.02277834981402271
# 382 pumpkins located. 9927 left. 4% done.
#
# US1MNAA0054
# 0.012431428888111972
# 383 pumpkins located. 9926 left. 4% done.
#
# USC00055056
# 0.0034178168616825887
# 384 pumpkins located. 9925 left. 4% done.
#
# US1COAR0180
# 0.010167235223996643
# 385 pumpkins located. 9924 left. 4% done.
#
# US1PABR0021
# 0.0408019974729171
# 386 pumpkins located. 9923 left. 4% done.
#
# US1ILCK0288
# 0.009061480324977248
# 387 pumpkins located. 9922 left. 4% done.
#
# USC00063420
# 0.016532962712414185
# 388 pumpkins located. 9921 left. 4% done.
#
# US1CAPC0010
# 0.011130720629410916
# 389 pumpkins located. 9920 left. 4% done.
#
# US1CAAL0033
# 0.005283595530507784
# 390 pumpkins located. 9919 left. 4% done.
#
# US1NHHL0059
# 0.03065274348585645
# 391 pumpkins located. 9918 left. 4% done.
#
# US1CAPC0049
# 0.030551705381695472
# 392 pumpkins located. 9917 left. 4% done.
#
# US1CTNH0016
# 0.02961052623984213
# 393 pumpkins located. 9916 left. 4% done.
#
# USC00472901
# 0.018662675975588437
# 394 pumpkins located. 9915 left. 4% done.
#
# USC00337559
# 0.0669385254995164
# 395 pumpkins located. 9914 left. 4% done.
#
# USC00351667
# 0.07558796843480754
# 396 pumpkins located. 9913 left. 4% done.
#
# US1ORCC0027
# 0.006045420958874934
# 397 pumpkins located. 9912 left. 4% done.
#
# US1TNKX0011
# 0.0721904408021645
# 398 pumpkins located. 9911 left. 4% done.
#
# US1WIWK0081
# 0.02178187356611217
# 399 pumpkins located. 9910 left. 4% done.
#
# US1IAPK0034
# 0.010614155386549041
# 400 pumpkins located. 9909 left. 4% done.
#
# US1CASA0010
# 0.045360955177004406
# 401 pumpkins located. 9908 left. 4% done.
#
# USC00360352
# 0.04479836056029247
# 402 pumpkins located. 9907 left. 4% done.
#
# USC00314970
# 0.022631612987591684
# 403 pumpkins located. 9906 left. 4% done.
#
# USC00331592
# 0.013601196806533643
# 404 pumpkins located. 9905 left. 4% done.
#
# USC00448169
# 0.0926506060516115
# 405 pumpkins located. 9904 left. 4% done.
#
# US1VTAD0005
# 0.10526258537700232
# 406 pumpkins located. 9903 left. 4% done.
#
# USC00450945
# 0.03749121209296117
# 407 pumpkins located. 9902 left. 4% done.
#
# US1CTLT0022
# 0.04138647121947324
# 408 pumpkins located. 9901 left. 4% done.
#
# USC00471708
# 0.0602836833318155
# 409 pumpkins located. 9900 left. 4% done.
#
# US1ORWS0129
# 0.012196446213956444
# 410 pumpkins located. 9899 left. 4% done.
#
# US1CASJ0010
# 0.011999702732984828
# 411 pumpkins located. 9898 left. 4% done.
#
# US1MIBY0002
# 0.03968224719846476
# 412 pumpkins located. 9897 left. 4% done.
#
# USC00369733
# 0.007933620007301412
# 413 pumpkins located. 9896 left. 4% done.
#
# USC00426724
# 0.01833518024372369
# 414 pumpkins located. 9895 left. 4% done.
#
# US1WAPR0005
# 0.005397134219196858
# 415 pumpkins located. 9894 left. 4% done.
#
# USC00214562
# 0.014044798044116872
# 416 pumpkins located. 9893 left. 4% done.
#
# USC00312230
# 0.04429227108401602
# 417 pumpkins located. 9892 left. 4% done.
#
# US1MIWY0039
# 0.02877554156049682
# 418 pumpkins located. 9891 left. 4% done.
#
# US1CASA0061
# 0.07435991865063676
# 419 pumpkins located. 9890 left. 4% done.
#
# USC00430337
# 0.014525036707703443
# 420 pumpkins located. 9889 left. 4% done.
#
# US1WACW0006
# 0.08111968720413922
# 421 pumpkins located. 9888 left. 4% done.
#
# US1CODN0024
# 0.0033653050054710987
# 422 pumpkins located. 9887 left. 4% done.
#
# USC00478081
# 0.11097751480411783
# 423 pumpkins located. 9886 left. 4% done.
#
# USC00437607
# 0.018880549400910464
# 424 pumpkins located. 9885 left. 4% done.
#
# USC00350078
# 0.014144824556353238
# 425 pumpkins located. 9884 left. 4% done.
#
# USC00405040
# 0.08002489921623474
# 426 pumpkins located. 9883 left. 4% done.
#
# US1MIWS0018
# 0.015031076294450024
# 427 pumpkins located. 9882 left. 4% done.
#
# US1WIDN0005
# 0.027441094006068832
# 428 pumpkins located. 9881 left. 4% done.
#
# USC00157648
# 0.04433874394442798
# 429 pumpkins located. 9880 left. 4% done.
#
# US1INLK0094
# 0.011281096227762894
# 430 pumpkins located. 9879 left. 4% done.
#
# US1MICT0018
# 0.03112534105917337
# 431 pumpkins located. 9878 left. 4% done.
#
# USC00362425
# 0.006692676004394691
# 432 pumpkins located. 9877 left. 4% done.
#
# US1ORCC0027
# 0.006045420958874934
# 433 pumpkins located. 9876 left. 4% done.
#
# US1TNKX0011
# 0.0721904408021645
# 434 pumpkins located. 9875 left. 4% done.
#
# US1WIPP0004
# 0.0035180299273911714
# 435 pumpkins located. 9874 left. 4% done.
#
# USC00477202
# 0.02065374885414909
# 436 pumpkins located. 9873 left. 4% done.
# USC00477636
# 0.011022417740232285
# 437 pumpkins located. 9872 left. 4% done.
#
# US1COMR0069
# 0.0029409474833815875
# 438 pumpkins located. 9871 left. 4% done.
#
# USC00055056
# 0.0034178168616825887
# 439 pumpkins located. 9870 left. 4% done.
#
# USC00330430
# 0.009095358170520632
# 440 pumpkins located. 9869 left. 4% done.
#
# US1MEYK0067
# 0.05386120377507189
# 441 pumpkins located. 9868 left. 4% done.
#
# US1WACW0006
# 0.06506788382666526
# 442 pumpkins located. 9867 left. 4% done.
#
# US1ORJC0099
# 0.0140276047866383
# 443 pumpkins located. 9866 left. 4% done.
#
# USC00047668
# 0.021924413428860885
# 444 pumpkins located. 9865 left. 4% done.
#
# USC00366921
# 0.05929227714372054
# 445 pumpkins located. 9864 left. 4% done.
#
# US1ILCK0288
# 0.009061480324977248
# 446 pumpkins located. 9863 left. 4% done.
#
# USC00335830
# 0.014572198686881038
# 447 pumpkins located. 9862 left. 4% done.
#
# USC00424542
# 0.024968245467593735
# 448 pumpkins located. 9861 left. 4% done.
#
# US1CASA0041
# 0.04714120251509844
# 449 pumpkins located. 9860 left. 4% done.
#
# USC00047668
# 0.021924413428860885
# 450 pumpkins located. 9859 left. 4% done.
#
# USC00369733
# 0.007933620007301412
# 451 pumpkins located. 9858 left. 4% done.
#
# USC00333125
# 0.05394237666250783
# 452 pumpkins located. 9857 left. 4% done.
#
# USC00366921
# 0.0766741747563673
# 453 pumpkins located. 9856 left. 4% done.
#
# US1ORPK0021
# 0.008989607346797707
# 454 pumpkins located. 9855 left. 4% done.
#
# USC00424542
# 0.024968245467593735
# 455 pumpkins located. 9854 left. 4% done.
#
# USC00475484
# 0.008488453711973236
# 456 pumpkins located. 9853 left. 4% done.
#
# USC00424542
# 0.024968245467593735
# 457 pumpkins located. 9852 left. 4% done.
#
# US1WACW0006
# 0.06506788382666526
# 458 pumpkins located. 9851 left. 4% done.
#
# USC00352693
# 0.02574163578407676
# 459 pumpkins located. 9850 left. 4% done.
#
# USC00426724
# 0.01833518024372369
# 460 pumpkins located. 9849 left. 4% done.
#
# US1WIMC0016
# 0.007794841377485465
# 461 pumpkins located. 9848 left. 4% done.
#
# USC00453985
# 0.0035757511168960456
# 462 pumpkins located. 9847 left. 4% done.
#
# US1NYNG0011
# 0.02889187468338924
# 463 pumpkins located. 9846 left. 4% done.
#
# USW00024175
# 0.009116351338666263
# 464 pumpkins located. 9845 left. 5% done.
#
# USC00450945
# 0.03749121209296117
# 465 pumpkins located. 9844 left. 5% done.
#
# US1INLK0094
# 0.011281096227762894
# 466 pumpkins located. 9843 left. 5% done.
#
# US1CASJ0010
# 0.011999702732984828
# 467 pumpkins located. 9842 left. 5% done.
#
# USC00477576
# 0.01581937230897856
# 468 pumpkins located. 9841 left. 5% done.
#
# USW00024274
# 0.012757930208692335
# 469 pumpkins located. 9840 left. 5% done.
#
# US1CTMD0024
# 0.023671806390280527
# 470 pumpkins located. 9839 left. 5% done.
#
# US1MABE0019
# 0.03687663805949028
# 471 pumpkins located. 9838 left. 5% done.
#
# US1COMR0029
# 0.002186427268401841
# 472 pumpkins located. 9837 left. 5% done.
#
# USC00476750
# 0.029462843869694864
# 473 pumpkins located. 9836 left. 5% done.
#
# US1IADB0012
# 0.01319794469605416
# 474 pumpkins located. 9835 left. 5% done.
#
# USC00360352
# 0.04479836056029247
# 475 pumpkins located. 9834 left. 5% done.
#
# US1CODG0015
# 0.003915817181632842
# 476 pumpkins located. 9833 left. 5% done.
#
# US1MABE0019
# 0.03687663805949028
# 477 pumpkins located. 9832 left. 5% done.
#
# US1OHCB0006
# 0.013103222513941117
# 478 pumpkins located. 9831 left. 5% done.
#
# USC00130213
# 0.008956822477312885
# 479 pumpkins located. 9830 left. 5% done.
#
# US1MIOK0067
# 0.06056651669196267
# 480 pumpkins located. 9829 left. 5% done.
#
# US1COJF0426
# 0.006800192953150706
# 481 pumpkins located. 9828 left. 5% done.
#
# USC00425082
# 0.02405678491092013
# 482 pumpkins located. 9827 left. 5% done.
#
# USC00366921
# 0.05929227714372054
# 483 pumpkins located. 9826 left. 5% done.
#
# USC00367540
# 0.04088663084346918
# 484 pumpkins located. 9825 left. 5% done.
#
# US1COJF0391
# 0.013104997586056747
# 485 pumpkins located. 9824 left. 5% done.
#
# US1CASC0045
# 0.014915473852681755
# 486 pumpkins located. 9823 left. 5% done.
#
# US1WIMT0014
# 0.03753831672731039
# 487 pumpkins located. 9822 left. 5% done.
#
# USC00055056
# 0.0034178168616825887
# 488 pumpkins located. 9821 left. 5% done.
#
# US1MEYK0075
# 0.05675685742005349
# 489 pumpkins located. 9820 left. 5% done.
#
# USC00190655
# 0.00880530523320593
# 490 pumpkins located. 9819 left. 5% done.
#
# US1MNWR0029
# 0.012439914096168014
# 491 pumpkins located. 9818 left. 5% done.
#
# USC00314015
# 0.01900693911626595
# 492 pumpkins located. 9817 left. 5% done.
#
# US1OHDL0012
# 0.026827564960866464
# 493 pumpkins located. 9816 left. 5% done.
#
# US1INLK0094
# 0.011281096227762894
# 494 pumpkins located. 9815 left. 5% done.
#
# US1UTUT0026
# 0.010097883508932579
# 495 pumpkins located. 9814 left. 5% done.
#
# USC00055056
# 0.0034178168616825887
# 496 pumpkins located. 9813 left. 5% done.
#
# US1UTCH0014
# 0.007952727337208969
# 497 pumpkins located. 9812 left. 5% done.
#
# US1PALC0008
# 0.03274210976862165
# 498 pumpkins located. 9811 left. 5% done.
#
# US1CTNH0042
# 0.011460193478728651
# 499 pumpkins located. 9810 left. 5% done.
#
# USC00208751
# 0.033524744511626244
# 500 pumpkins located. 9809 left. 5% done.
#
# USC00450945
# 0.03749121209296117
# 501 pumpkins located. 9808 left. 5% done.
#
# US1OHER0017
# 0.009822483028236155
# 502 pumpkins located. 9807 left. 5% done.
#
# USC00335356
# 0.051780715925223084
# 503 pumpkins located. 9806 left. 5% done.
#
# USC00069568
# 0.08025885306961347
# 504 pumpkins located. 9805 left. 5% done.
#
# USC00332920
# 0.020836985197002198
# 505 pumpkins located. 9804 left. 5% done.
#
# US1MANF0026
# 0.02692860094565073
# 506 pumpkins located. 9803 left. 5% done.
#
# US1UTSL0008
# 0.021166386600683804
# 507 pumpkins located. 9802 left. 5% done.
#
# USC00426724
# 0.01833518024372369
# 508 pumpkins located. 9801 left. 5% done.
#
# US1UTIR0003
# 0.08371200566286635
# 509 pumpkins located. 9800 left. 5% done.
#
# US1ORDG0031
# 0.020411561042695984
# 510 pumpkins located. 9799 left. 5% done.
#
# US1NYOS0006
# 0.012957990651723933
# 511 pumpkins located. 9798 left. 5% done.
#
# US1PALC0008
# 0.03274210976862165
# 512 pumpkins located. 9797 left. 5% done.
#
# US1VTRT0019
# 0.04282462357336368
# 513 pumpkins located. 9796 left. 5% done.
#
# USC00107210
# 0.004216972379562929
# 514 pumpkins located. 9795 left. 5% done.
#
# US1NYFL0009
# 0.06830340548061818
# 515 pumpkins located. 9794 left. 5% done.
#
# US1CASC0045
# 0.014915473852681755
# 516 pumpkins located. 9793 left. 5% done.
#
# USC00424542
# 0.024968245467593735
# 517 pumpkins located. 9792 left. 5% done.
#
# US1COMR0069
# 0.0029409474833815875
# 518 pumpkins located. 9791 left. 5% done.
#
# US1MAMD0093
# 0.017555830876951957
# 519 pumpkins located. 9790 left. 5% done.
#
# USC00475932
# 0.08429689403649845
# 520 pumpkins located. 9789 left. 5% done.
#
# USC00470904
# 0.00973229962804106
# 521 pumpkins located. 9788 left. 5% done.
#
# US1WACW0006
# 0.08111968720413922
# 522 pumpkins located. 9787 left. 5% done.
#
# US1CASC0008
# 0.01519680440749484
# 523 pumpkins located. 9786 left. 5% done.
#
# US1VTRT0019
# 0.04282462357336368
# 524 pumpkins located. 9785 left. 5% done.
#
# USC00066645
# 0.0074520957696550165
# 525 pumpkins located. 9784 left. 5% done.
#
# US1CAPC0008
# 0.012830304135133282
# 526 pumpkins located. 9783 left. 5% done.
#
# US1WIWW0014
# 0.0229338101694847
# 527 pumpkins located. 9782 left. 5% done.
#
# USC00133517
# 0.1626868261172361
# 528 pumpkins located. 9781 left. 5% done.
#
# US1CASA0041
# 0.04714120251509844
# 529 pumpkins located. 9780 left. 5% done.
#
# USC00477202
# 0.02065374885414909
# 530 pumpkins located. 9779 left. 5% done.
#
# US1CTFR0029
# 0.0356002602015762
# 531 pumpkins located. 9778 left. 5% done.
#
# USC00314970
# 0.022631612987591684
# 532 pumpkins located. 9777 left. 5% done.
#
# US1MILV0019
# 0.039843993577441006
# 533 pumpkins located. 9776 left. 5% done.
#
# US1CTWN0002
# 0.026245981030444895
# 534 pumpkins located. 9775 left. 5% done.
#
# US1PALC0008
# 0.03274210976862165
# 535 pumpkins located. 9774 left. 5% done.
#
# US1KYFY0012
# 0.003953673740967175
# 536 pumpkins located. 9773 left. 5% done.
#
# USC00303769
# 0.05334915645603847
# 537 pumpkins located. 9772 left. 5% done.
#
# US1WIRK0002
# 0.006098112235769596
# 538 pumpkins located. 9771 left. 5% done.
#
# USW00094298
# 0.018348873427265794
# 539 pumpkins located. 9770 left. 5% done.
#
# USC00352997
# 0.008385385582077999
# 540 pumpkins located. 9769 left. 5% done.
#
# US1NYOS0006
# 0.012957990651723933
# 541 pumpkins located. 9768 left. 5% done.
#
# USC00055056
# 0.0034178168616825887
# 542 pumpkins located. 9767 left. 5% done.
#
# US1UTBE0014
# 0.006210670308428146
# 543 pumpkins located. 9766 left. 5% done.
#
# US1CASA0010
# 0.045360955177004406
# 544 pumpkins located. 9765 left. 5% done.
#
# US1MELN0026
# 0.05382418690561671
# 545 pumpkins located. 9764 left. 5% done.
#
# US1OHAS0004
# 0.01631390486979083
# 546 pumpkins located. 9763 left. 5% done.
# USC00043244
# 0.02895699170994996
# 547 pumpkins located. 9762 left. 5% done.
#
# USC00365684
# 0.008856144940664522
# 548 pumpkins located. 9761 left. 5% done.
#
# USC00066645
# 0.0074520957696550165
# 549 pumpkins located. 9760 left. 5% done.
#
# USC00305597
# 0.04139643007217125
# 550 pumpkins located. 9759 left. 5% done.
#
# US1SCLX0043
# 0.010450050067804757
# 551 pumpkins located. 9758 left. 5% done.
#
# US1COAR0180
# 0.010167235223996643
# 552 pumpkins located. 9757 left. 5% done.
#
# US1CASJ0010
# 0.011999702732984828
# 553 pumpkins located. 9756 left. 5% done.
#
# US1WIOG0002
# 0.015965821550423306
# 554 pumpkins located. 9755 left. 5% done.
#
# US1INRN0007
# 0.08468642148655887
# 555 pumpkins located. 9754 left. 5% done.
#
# US1NCBC0022
# 0.027400068833851342
# 556 pumpkins located. 9753 left. 5% done.
#
# USC00330430
# 0.009095358170520632
# 557 pumpkins located. 9752 left. 5% done.
#
# US1CTMD0024
# 0.023671806390280527
# 558 pumpkins located. 9751 left. 5% done.
#
# USC00420061
# 0.014463666594603276
# 559 pumpkins located. 9750 left. 5% done.
#
# USC00136566
# 0.0037397559505946178
# 560 pumpkins located. 9749 left. 5% done.
#
# US1MNRM0020
# 0.01078689813431221
# 561 pumpkins located. 9748 left. 5% done.
#
# US1MDMG0040
# 0.002292714602830798
# 562 pumpkins located. 9747 left. 5% done.
#
# USC00206584
# 0.004553895388558315
# 563 pumpkins located. 9746 left. 5% done.
#
# US1UTWB0011
# 0.020155942554229127
# 564 pumpkins located. 9745 left. 5% done.
#
# US1CTWN0010
# 0.07517541802058503
# 565 pumpkins located. 9744 left. 5% done.
#
# US1CODN0024
# 0.0033653050054710987
# 566 pumpkins located. 9743 left. 5% done.
#
# USC00207662
# 0.013656375303123929
# 567 pumpkins located. 9742 left. 6% done.
#
# USC00425610
# 0.039695484076277536
# 568 pumpkins located. 9741 left. 6% done.
#
# USC00425034
# 0.008366700000003391
# 569 pumpkins located. 9740 left. 6% done.
#
# US1MELN0026
# 0.03665476765850667
# 570 pumpkins located. 9739 left. 6% done.
#
# US1OHAS0004
# 0.01631390486979083
# 571 pumpkins located. 9738 left. 6% done.
#
# USC00208751
# 0.033524744511626244
# 572 pumpkins located. 9737 left. 6% done.
#
# US1NYOS0006
# 0.012957990651723933
# 573 pumpkins located. 9736 left. 6% done.
#
# US1ILWL0095
# 0.01908192990475597
# 574 pumpkins located. 9735 left. 6% done.
#
# US1PAWN0012
# 0.03706614004423408
# 575 pumpkins located. 9734 left. 6% done.
#
# USC00405040
# 0.08002489921623474
# 576 pumpkins located. 9733 left. 6% done.
#
# US1UTSL0097
# 0.03254428220441296
# 577 pumpkins located. 9732 left. 6% done.
#
# USC00047668
# 0.021924413428860885
# 578 pumpkins located. 9731 left. 6% done.
#
# US1NCPT0010
# 0.08392537914242683
# 579 pumpkins located. 9730 left. 6% done.
#
# US1CODG0003
# 0.001998179604038893
# 580 pumpkins located. 9729 left. 6% done.
#
# USC00010395
# 0.011960344548967489
# 581 pumpkins located. 9728 left. 6% done.
#
# USC00042760
# 0.07608014522712107
# 582 pumpkins located. 9727 left. 6% done.
#
# US1ORPK0021
# 0.008989607346797707
# 583 pumpkins located. 9726 left. 6% done.
#
# USC00126830
# 0.1338066596102363
# 584 pumpkins located. 9725 left. 6% done.
#
# US1NYER0151
# 0.009139828455720657
# 585 pumpkins located. 9724 left. 6% done.
#
# US1NYOS0006
# 0.012957990651723933
# 586 pumpkins located. 9723 left. 6% done.
#
# US1NYON0004
# 0.07808966367477622
# 587 pumpkins located. 9722 left. 6% done.
#
# USC00055056
# 0.0034178168616825887
# 588 pumpkins located. 9721 left. 6% done.
#
# US1CASC0045
# 0.014915473852681755
# 589 pumpkins located. 9720 left. 6% done.
#
# US1IALY0002
# 0.008219821511445362
# 590 pumpkins located. 9719 left. 6% done.
#
# US1CASM0017
# 0.013628033707032212
# 591 pumpkins located. 9718 left. 6% done.
#
# USC00425610
# 0.039695484076277536
# 592 pumpkins located. 9717 left. 6% done.
#
# US1MOBT0009
# 0.004569463863517025
# 593 pumpkins located. 9716 left. 6% done.
#
# USC00310901
# 0.02756859033103925
# 594 pumpkins located. 9715 left. 6% done.
#
# US1CASA0041
# 0.04714120251509844
# 595 pumpkins located. 9714 left. 6% done.
#
# USC00479335
# 0.012458962880196007
# 596 pumpkins located. 9713 left. 6% done.
#
# US1CODN0024
# 0.0033653050054710987
# 597 pumpkins located. 9712 left. 6% done.
#
# US1ORPK0014
# 0.012026359988371647
# 598 pumpkins located. 9711 left. 6% done.
#
# USC00201476
# 0.01739604645027681
# 599 pumpkins located. 9710 left. 6% done.
#
# USC00047807
# 0.05966594215161631
# 600 pumpkins located. 9709 left. 6% done.
#
# USC00331592
# 0.013601196806533643
# 601 pumpkins located. 9708 left. 6% done.
#
# US1MNWR0029
# 0.012439914096168014
# 602 pumpkins located. 9707 left. 6% done.
#
# US1CASC0041
# 0.006835840551822468
# 603 pumpkins located. 9706 left. 6% done.
#
# USC00450945
# 0.03749121209296117
# 604 pumpkins located. 9705 left. 6% done.
#
# USC00129724
# 0.039444652891490684
# 605 pumpkins located. 9704 left. 6% done.
#
# USC00470904
# 0.00973229962804106
# 606 pumpkins located. 9703 left. 6% done.
#
# US1CTMD0024
# 0.023671806390280527
# 607 pumpkins located. 9702 left. 6% done.
#
# USW00024175
# 0.009116351338666263
# 608 pumpkins located. 9701 left. 6% done.
#
# USW00094960
# 0.032700882436106596
# 609 pumpkins located. 9700 left. 6% done.
#
# US1CASC0003
# 0.03135883505569634
# 610 pumpkins located. 9699 left. 6% done.
#
# US1ORCC0035
# 0.010517844578146222
# 611 pumpkins located. 9698 left. 6% done.
#
# USC00437954
# 0.04555271497649278
# 612 pumpkins located. 9697 left. 6% done.
#
# USC00361838
# 0.18627900328323954
# 613 pumpkins located. 9696 left. 6% done.
#
# USC00331592
# 0.013601196806533643
# 614 pumpkins located. 9695 left. 6% done.
#
# US1INAL0041
# 0.01433617433522398
# 615 pumpkins located. 9694 left. 6% done.
#
# US1OHST0006
# 0.054079009215953135
# 616 pumpkins located. 9693 left. 6% done.
#
# USC00312740
# 0.08559828556753377
# 617 pumpkins located. 9692 left. 6% done.
#
# US1KYNL0004
# 0.10116272030866764
# 618 pumpkins located. 9691 left. 6% done.
#
# US1OHWD0003
# 0.05992279350739841
# 619 pumpkins located. 9690 left. 6% done.
#
# USC00330715
# 0.038474464987195506
# 620 pumpkins located. 9689 left. 6% done.
#
# US1PAYR0024
# 0.042556905200538064
# 621 pumpkins located. 9688 left. 6% done.
#
# US1WIPK0025
# 0.07746678195471174
# 622 pumpkins located. 9687 left. 6% done.
#
# USC00330430
# 0.009095358170520632
# 623 pumpkins located. 9686 left. 6% done.
#
# US1MNWR0029
# 0.012439914096168014
# 624 pumpkins located. 9685 left. 6% done.
#
# US1CAPC0008
# 0.012830304135133282
# 625 pumpkins located. 9684 left. 6% done.
#
# USC00366921
# 0.05929227714372054
# 626 pumpkins located. 9683 left. 6% done.
#
# US1VTRT0019
# 0.04282462357336368
# 627 pumpkins located. 9682 left. 6% done.
#
# US1INMD0030
# 0.001823420338265049
# 628 pumpkins located. 9681 left. 6% done.
#
# US1ILCK0260
# 0.02450028440753317
# 629 pumpkins located. 9680 left. 6% done.
#
# USC00312740
# 0.08559828556753377
# 630 pumpkins located. 9679 left. 6% done.
#
# US1ILDP0161
# 0.009868389664465002
# 631 pumpkins located. 9678 left. 6% done.
#
# US1MIWS0016
# 0.02695569609748464
# 632 pumpkins located. 9677 left. 6% done.
#
# US1UTUT0026
# ...
# 0.03611788836921223
# 10103 pumpkins located. 206 left. 98% done.
#
# USC00040383
# 0.013267330469244066
# 10104 pumpkins located. 205 left. 98% done.
#
# US1CASN0168
# 0.0085345216766926
# 10105 pumpkins located. 204 left. 98% done.
#
# USC00040383
# 0.013267330469244066
# 10106 pumpkins located. 203 left. 98% done.
#
# USC00361130
# 0.007140622841887986
# 10107 pumpkins located. 202 left. 98% done.
#
# US1WAPR0068
# 0.03724801396316192
# 10108 pumpkins located. 201 left. 98% done.
#
# US1IADB0012
# 0.01319794469605416
# 10109 pumpkins located. 200 left. 98% done.
#
# US1NHMR0041
# 0.028646241401261777
# 10110 pumpkins located. 199 left. 98% done.
#
# US1NCBC0022
# 0.027400068833851342
# 10111 pumpkins located. 198 left. 98% done.
#
# US1MOGR0054
# 0.009798979538707809
# 10112 pumpkins located. 197 left. 98% done.
#
# USC00396650
# 0.0025225907713965815
# 10113 pumpkins located. 196 left. 98% done.
#
# US1CASA0010
# 0.045360955177004406
# 10114 pumpkins located. 195 left. 98% done.
#
# US1NHMR0041
# 0.028646241401261777
# 10115 pumpkins located. 194 left. 98% done.
#
# USC00055056
# 0.0034178168616825887
# 10116 pumpkins located. 193 left. 98% done.
#
# US1MNHN0311
# 0.031568430941354524
# 10117 pumpkins located. 192 left. 98% done.
#
# USC00276368
# 0.005996368242536234
# 10118 pumpkins located. 191 left. 98% done.
#
# US1COAR0180
# 0.010167235223996643
# 10119 pumpkins located. 190 left. 98% done.
#
# US1COAD0154
# 0.017578400796711906
# 10120 pumpkins located. 189 left. 98% done.
#
# US1COAD0154
# 0.017578400796711906
# 10121 pumpkins located. 188 left. 98% done.
#
# US1COAR0180
# 0.010167235223996643
# 10122 pumpkins located. 187 left. 98% done.
#
# USC00474230
# 0.07342215559420902
# 10123 pumpkins located. 186 left. 98% done.
#
# US1COAR0180
# 0.010167235223996643
# 10124 pumpkins located. 185 left. 98% done.
#
# US1COAR0180
# 0.010167235223996643
# 10125 pumpkins located. 184 left. 98% done.
#
# US1MOCR0010
# 0.013787459931399619
# 10126 pumpkins located. 183 left. 98% done.
#
# US1NHST0040
# 0.06348163177517933
# 10127 pumpkins located. 182 left. 98% done.
#
# US1COAD0154
# 0.017578400796711906
# 10128 pumpkins located. 181 left. 98% done.
#
# USC00209110
# 0.04483595939166579
# 10129 pumpkins located. 180 left. 98% done.
#
# USC00209110
# 0.04483595939166579
# 10130 pumpkins located. 179 left. 98% done.
#
# US1KYHN0001
# 0.10230566944211704
# 10131 pumpkins located. 178 left. 98% done.
#
# US1KYHN0001
# 0.10230566944211704
# 10132 pumpkins located. 177 left. 98% done.
#
# USC00406547
# 0.051602037379640704
# 10133 pumpkins located. 176 left. 98% done.
#
# US1KYHD0009
# 0.02916498453987105
# 10134 pumpkins located. 175 left. 98% done.
#
# US1NCRN0035
# 0.13842909347477678
# 10135 pumpkins located. 174 left. 98% done.
#
# US1KYHD0009
# 0.02916498453987105
# 10136 pumpkins located. 173 left. 98% done.
#
# US1NCWK0099
# 0.02842590921273643
# 10137 pumpkins located. 172 left. 98% done.
#
# US1KYHD0009
# 0.02916498453987105
# 10138 pumpkins located. 171 left. 98% done.
#
# US1KYHN0001
# 0.10230566944211704
# 10139 pumpkins located. 170 left. 98% done.
#
# USC00141632
# 0.00904792387346021
# 10140 pumpkins located. 169 left. 98% done.
#
# US1GAHY0007
# 0.04070852459337503
# 10141 pumpkins located. 168 left. 98% done.
#
# US1KYHD0009
# 0.02916498453987105
# 10142 pumpkins located. 167 left. 98% done.
#
# US1KYHN0001
# 0.10230566944211704
# 10143 pumpkins located. 166 left. 98% done.
#
# USC00156126
# 0.016849180065813527
# 10144 pumpkins located. 165 left. 98% done.
#
# USC00156126
# 0.016849180065813527
# 10145 pumpkins located. 164 left. 98% done.
#
# USC00153604
# 0.05738609249722426
# 10146 pumpkins located. 163 left. 98% done.
#
# US1NCRN0035
# 0.13842909347477678
# 10147 pumpkins located. 162 left. 98% done.
#
# USC00141632
# 0.00904792387346021
# 10148 pumpkins located. 161 left. 98% done.
#
# USC00406547
# 0.051602037379640704
# 10149 pumpkins located. 160 left. 98% done.
#
# USC00156126
# 0.016849180065813527
# 10150 pumpkins located. 159 left. 98% done.
#
# USC00156126
# 0.016849180065813527
# 10151 pumpkins located. 158 left. 98% done.
#
# US1KYHN0001
# 0.10230566944211704
# 10152 pumpkins located. 157 left. 98% done.
#
# US1TNSV0007
# 0.009506441117486674
# 10153 pumpkins located. 156 left. 98% done.
#
# US1KYHN0001
# 0.10230566944211704
# 10154 pumpkins located. 155 left. 98% done.
#
# US1KYHN0001
# 0.10230566944211704
# 10155 pumpkins located. 154 left. 99% done.
#
# USC00150955
# 0.06838504934976541
# 10156 pumpkins located. 153 left. 99% done.
#
# USC00156126
# 0.016849180065813527
# 10157 pumpkins located. 152 left. 99% done.
#
# USC00153604
# 0.05738609249722426
# 10158 pumpkins located. 151 left. 99% done.
#
# USC00150955
# 0.06838504934976541
# 10159 pumpkins located. 150 left. 99% done.
#
# US1OHCB0006
# 0.013103222513941117
# 10160 pumpkins located. 149 left. 99% done.
#
# USC00158065
# 0.008656780101742865
# 10161 pumpkins located. 148 left. 99% done.
#
# USC00158065
# 0.008656780101742865
# 10162 pumpkins located. 147 left. 99% done.
#
# US1KYHN0001
# 0.10230566944211704
# 10163 pumpkins located. 146 left. 99% done.
#
# USC00121814
# 0.007153534980698308
# 10164 pumpkins located. 145 left. 99% done.
#
# USC00121814
# 0.007153534980698308
# 10165 pumpkins located. 144 left. 99% done.
#
# USC00158065
# 0.008656780101742865
# 10166 pumpkins located. 143 left. 99% done.
#
# USC00012737
# 0.0374800618469389
# 10167 pumpkins located. 142 left. 99% done.
# US1KSMC0002
# 0.05077051423858875
# 10168 pumpkins located. 141 left. 99% done.
#
# US1TNSV0007
# 0.009506441117486674
# 10169 pumpkins located. 140 left. 99% done.
#
# US1NCRN0035
# 0.13842909347477678
# 10170 pumpkins located. 139 left. 99% done.
#
# US1VAKQ0001
# 0.05388127581275585
# 10171 pumpkins located. 138 left. 99% done.
#
# US1NCWN0006
# 0.060338490205270885
# 10172 pumpkins located. 137 left. 99% done.
#
# USC00304808
# 0.008516741682705773
# 10173 pumpkins located. 136 left. 99% done.
#
# US1KYHD0009
# 0.02916498453987105
# 10174 pumpkins located. 135 left. 99% done.
#
# US1ALFR0007
# 0.025612375418332244
# 10175 pumpkins located. 134 left. 99% done.
#
# USC00332170
# 0.06009116693990782
# 10176 pumpkins located. 133 left. 99% done.
#
# USC00012737
# 0.0374800618469389
# 10177 pumpkins located. 132 left. 99% done.
#
# USC00158065
# 0.008656780101742865
# 10178 pumpkins located. 131 left. 99% done.
#
# USC00158065
# 0.008656780101742865
# 10179 pumpkins located. 130 left. 99% done.
#
# USC00334556
# 0.023222267177002535
# 10180 pumpkins located. 129 left. 99% done.
#
# USC00168436
# 0.012755643466708311
# 10181 pumpkins located. 128 left. 99% done.
#
# US1PAWT0029
# 0.04179009322913922
# 10182 pumpkins located. 127 left. 99% done.
#
# US1PAWT0029
# 0.04179009322913922
# 10183 pumpkins located. 126 left. 99% done.
#
# USC00033540
# 0.008301540002911506
# 10184 pumpkins located. 125 left. 99% done.
#
# US1KYHN0001
# 0.10230566944211704
# 10185 pumpkins located. 124 left. 99% done.
#
# US1NCWN0006
# 0.060338490205270885
# 10186 pumpkins located. 123 left. 99% done.
#
# US1OKWW0001
# 0.007006305749106581
# 10187 pumpkins located. 122 left. 99% done.
#
# USC00153604
# 0.05738609249722426
# 10188 pumpkins located. 121 left. 99% done.
#
# USC00030220
# 0.02308083776859227
# 10189 pumpkins located. 120 left. 99% done.
#
# USC00130753
# 0.012477632056208355
# 10190 pumpkins located. 119 left. 99% done.
#
# USC00030220
# 0.02308083776859227
# 10191 pumpkins located. 118 left. 99% done.
#
# US1WIWN0004
# 0.010326333949661136
# 10192 pumpkins located. 117 left. 99% done.
#
# US1ALFR0007
# 0.025612375418332244
# 10193 pumpkins located. 116 left. 99% done.
#
# USC00153604
# 0.05738609249722426
# 10194 pumpkins located. 115 left. 99% done.
#
# US1OHPT0012
# 0.04495242136325724
# 10195 pumpkins located. 114 left. 99% done.
#
# USC00406547
# 0.051602037379640704
# 10196 pumpkins located. 113 left. 99% done.
#
# USC00334556
# 0.023222267177002535
# 10197 pumpkins located. 112 left. 99% done.
#
# USC00069568
# 0.08025885306961347
# 10198 pumpkins located. 111 left. 99% done.
#
# USC00042760
# 0.07608014522712107
# 10199 pumpkins located. 110 left. 99% done.
#
# USC00153604
# 0.05738609249722426
# 10200 pumpkins located. 109 left. 99% done.
#
# USC00012737
# 0.0374800618469389
# 10201 pumpkins located. 108 left. 99% done.
#
# USC00217308
# 0.040735926622322095
# 10202 pumpkins located. 107 left. 99% done.
#
# US1OKWW0001
# 0.007006305749106581
# 10203 pumpkins located. 106 left. 99% done.
#
# US1IAWP0011
# 0.07439912201128987
# 10204 pumpkins located. 105 left. 99% done.
#
# USC00339299
# 0.021838904078717584
# 10205 pumpkins located. 104 left. 99% done.
#
# USC00251260
# 0.016886088949191105
# 10206 pumpkins located. 103 left. 99% done.
#
# US1IAWP0011
# 0.07439912201128987
# 10207 pumpkins located. 102 left. 99% done.
#
# USC00158065
# 0.008656780101742865
# 10208 pumpkins located. 101 left. 99% done.
#
# US1KSMC0002
# 0.05077051423858875
# 10209 pumpkins located. 100 left. 99% done.
#
# USC00038052
# 0.031782675473439166
# 10210 pumpkins located. 99 left. 99% done.
#
# US1VASP0008
# 0.027447553993936294
# 10211 pumpkins located. 98 left. 99% done.
#
# US1VASP0008
# 0.027447553993936294
# 10212 pumpkins located. 97 left. 99% done.
#
# USC00168436
# 0.012755643466708311
# 10213 pumpkins located. 96 left. 99% done.
#
# USC00033540
# 0.008301540002911506
# 10214 pumpkins located. 95 left. 99% done.
#
# US1NCWK0234
# 0.027939688519562626
# 10215 pumpkins located. 94 left. 99% done.
#
# USC00030220
# 0.02308083776859227
# 10216 pumpkins located. 93 left. 99% done.
#
# US1KSMC0002
# 0.05077051423858875
# 10217 pumpkins located. 92 left. 99% done.
#
# USC00038052
# 0.031782675473439166
# 10218 pumpkins located. 91 left. 99% done.
#
# US1OKWW0001
# 0.007006305749106581
# 10219 pumpkins located. 90 left. 99% done.
#
# USW00024239
# 0.010222936110510086
# 10220 pumpkins located. 89 left. 99% done.
#
# USC00121814
# 0.007153534980698308
# 10221 pumpkins located. 88 left. 99% done.
#
# USC00334556
# 0.023222267177002535
# 10222 pumpkins located. 87 left. 99% done.
#
# US1OKWW0001
# 0.007006305749106581
# 10223 pumpkins located. 86 left. 99% done.
#
# USC00339299
# 0.021838904078717584
# 10224 pumpkins located. 85 left. 99% done.
#
# US1ARCK0002
# 0.08178548280581911
# 10225 pumpkins located. 84 left. 99% done.
#
# USC00158065
# 0.008656780101742865
# 10226 pumpkins located. 83 left. 99% done.
#
# US1VALN0002
# 0.05922686334536693
# 10227 pumpkins located. 82 left. 99% done.
#
# USC00334984
# 0.003132729808013495
# 10228 pumpkins located. 81 left. 99% done.
#
# US1OKWW0001
# 0.007006305749106581
# 10229 pumpkins located. 80 left. 99% done.
#
# USC00475910
# 0.060710606415683446
# 10230 pumpkins located. 79 left. 99% done.
#
# USC00474195
# 0.0048715603506488065
# 10231 pumpkins located. 78 left. 99% done.
#
# US1WIWN0004
# 0.010326333949661136
# 10232 pumpkins located. 77 left. 99% done.
#
# USC00130753
# 0.012477632056208355
# 10233 pumpkins located. 76 left. 99% done.
#
# USC00331523
# 0.015801890119854615
# 10234 pumpkins located. 75 left. 99% done.
#
# USC00150955
# 0.06838504934976541
# 10235 pumpkins located. 74 left. 99% done.
#
# US1ORCC0031
# 0.015242707772891214
# 10236 pumpkins located. 73 left. 99% done.
#
# USC00332170
# 0.06009116693990782
# 10237 pumpkins located. 72 left. 99% done.
#
# USC00130213
# 0.008956822477312885
# 10238 pumpkins located. 71 left. 99% done.
#
# USC00233641
# 0.06161311513022482
# 10239 pumpkins located. 70 left. 99% done.
#
# US1MNSW0005
# 0.008922430881775613
# 10240 pumpkins located. 69 left. 99% done.
#
# US1IAWP0011
# 0.07439912201128987
# 10241 pumpkins located. 68 left. 99% done.
#
# USC00130753
# 0.012477632056208355
# 10242 pumpkins located. 67 left. 99% done.
#
# US1WIWN0004
# 0.010326333949661136
# 10243 pumpkins located. 66 left. 99% done.
#
# USC00130213
# 0.008956822477312885
# 10244 pumpkins located. 65 left. 99% done.
#
# US1NHMR0041
# 0.028646241401261777
# 10245 pumpkins located. 64 left. 99% done.
#
# USC00474195
# 0.0048715603506488065
# 10246 pumpkins located. 63 left. 99% done.
#
# USC00478969
# 0.014960903344712626
# 10247 pumpkins located. 62 left. 99% done.
#
# USC00148719
# 0.0061516788033909395
# 10248 pumpkins located. 61 left. 99% done.
#
# USC00448984
# 0.02775833363913813
# 10249 pumpkins located. 60 left. 99% done.
#
# USC00071330
# 0.014132151033697849
# 10250 pumpkins located. 59 left. 99% done.
#
# US1OHCB0006
# 0.013103222513941117
# 10251 pumpkins located. 58 left. 99% done.
#
# US1OHCB0006
# 0.013103222513941117
# 10252 pumpkins located. 57 left. 99% done.
#
# US1ORCC0031
# 0.015242707772891214
# 10253 pumpkins located. 56 left. 99% done.
#
# US1MOSL0054
# 0.004181211886520842
# 10254 pumpkins located. 55 left. 99% done.
#
# USC00130753
# 0.012477632056208355
# 10255 pumpkins located. 54 left. 99% done.
#
# USC00349760
# 0.010830063859923498
# 10256 pumpkins located. 53 left. 99% done.
#
# USC00202308
# 0.010991581582289802
# 10257 pumpkins located. 52 left. 99% done.
#
# US1OHCB0006
# 0.013103222513941117
# 10258 pumpkins located. 51 left. 100% done.
#
# USC00153604
# 0.05738609249722426
# 10259 pumpkins located. 50 left. 100% done.
#
# USC00202308
# 0.010991581582289802
# 10260 pumpkins located. 49 left. 100% done.
#
# USC00150955
# 0.06838504934976541
# 10261 pumpkins located. 48 left. 100% done.
#
# US1IAWP0011
# 0.07439912201128987
# 10262 pumpkins located. 47 left. 100% done.
#
# USC00130213
# 0.008956822477312885
# 10263 pumpkins located. 46 left. 100% done.
#
# US1MNCG0029
# 0.012216524318311875
# 10264 pumpkins located. 45 left. 100% done.
#
# US1CTMD0025
# 0.010206216382190126
# 10265 pumpkins located. 44 left. 100% done.
#
# US1CASN0168
# 0.0085345216766926
# 10266 pumpkins located. 43 left. 100% done.
#
# USC00203712
# 0.04526633110933289
# 10267 pumpkins located. 42 left. 100% done.
#
# US1PAWT0010
# 0.057120263131830405
# 10268 pumpkins located. 41 left. 100% done.
#
# US1CTMD0025
# 0.010206216382190126
# 10269 pumpkins located. 40 left. 100% done.
#
# US1PAWT0019
# 0.019440015438518574
# 10270 pumpkins located. 39 left. 100% done.
#
# USC00130213
# 0.008956822477312885
# 10271 pumpkins located. 38 left. 100% done.
#
# US1MAHS0039
# 0.03649297897635544
# 10272 pumpkins located. 37 left. 100% done.
#
# US1WICH0001
# 0.027485637389734252
# 10273 pumpkins located. 36 left. 100% done.
#
# USC00396650
# 0.0025225907713965815
# 10274 pumpkins located. 35 left. 100% done.
# USC00045131
# 0.0047623704286809026
# 10275 pumpkins located. 34 left. 100% done.
#
# USC00126830
# 0.1338066596102363
# 10276 pumpkins located. 33 left. 100% done.
#
# USC00305687
# 0.007588758808264999
# 10277 pumpkins located. 32 left. 100% done.
#
# US1IAWP0011
# 0.07439912201128987
# 10278 pumpkins located. 31 left. 100% done.
#
# USC00040383
# 0.013267330469244066
# 10279 pumpkins located. 30 left. 100% done.
#
# US1WAKG0248
# 0.048670402482226184
# 10280 pumpkins located. 29 left. 100% done.
#
# US1NHMR0041
# 0.028646241401261777
# 10281 pumpkins located. 28 left. 100% done.
#
# USC00305687
# 0.007588758808264999
# 10282 pumpkins located. 27 left. 100% done.
#
# US1WAKG0248
# 0.048670402482226184
# 10283 pumpkins located. 26 left. 100% done.
#
# US1PAJF0004
# 0.08001236155576466
# 10284 pumpkins located. 25 left. 100% done.
#
# US1NCFR0022
# 0.019027924112991736
# 10285 pumpkins located. 24 left. 100% done.
#
# US1NCBC0022
# 0.027400068833851342
# 10286 pumpkins located. 23 left. 100% done.
#
# USC00209110
# 0.04483595939166579
# 10287 pumpkins located. 22 left. 100% done.
#
# USC00201476
# 0.01739604645027681
# 10288 pumpkins located. 21 left. 100% done.
#
# USC00361130
# 0.007140622841887986
# 10289 pumpkins located. 20 left. 100% done.
#
# US1WATH0001
# 0.01644087414707886
# 10290 pumpkins located. 19 left. 100% done.
#
# US1WIEC0028
# 0.041970510467350994
# 10291 pumpkins located. 18 left. 100% done.
#
# US1NCBC0022
# 0.027400068833851342
# 10292 pumpkins located. 17 left. 100% done.
#
# USC00361130
# 0.007140622841887986
# 10293 pumpkins located. 16 left. 100% done.
#
# USC00040383
# 0.013267330469244066
# 10294 pumpkins located. 15 left. 100% done.
#
# USC00232318
# 0.003415310950708232
# 10295 pumpkins located. 14 left. 100% done.
#
# US1WYWH0017
# 0.003748634978216612
# 10296 pumpkins located. 13 left. 100% done.
#
# USC00060918
# 0.004763706980922565
# 10297 pumpkins located. 12 left. 100% done.
#
# US1WASG0024
# 0.011507970109886589
# 10298 pumpkins located. 11 left. 100% done.
#
# US1ILWL0042
# 0.013104388276450527
# 10299 pumpkins located. 10 left. 100% done.
#
# US1COAR0180
# 0.010167235223996643
# 10300 pumpkins located. 9 left. 100% done.
#
# US1COJF0391
# 0.013104997586056747
# 10301 pumpkins located. 8 left. 100% done.
#
# US1COAR0180
# 0.010167235223996643
# 10302 pumpkins located. 7 left. 100% done.
#
# US1OHGG0004
# 0.05571759277104635
# 10303 pumpkins located. 6 left. 100% done.
#
# USC00396650
# 0.0025225907713965815
# 10304 pumpkins located. 5 left. 100% done.
#
# US1NCWK0099
# 0.02842590921273643
# 10305 pumpkins located. 4 left. 100% done.
#
# US1NCWN0006
# 0.060338490205270885
# 10306 pumpkins located. 3 left. 100% done.
#
# US1NCWK0234
# 0.027939688519562626
# 10307 pumpkins located. 2 left. 100% done.
#
# US1NCFK0018
# 0.08696752228757146
# 10308 pumpkins located. 1 left. 100% done.
#
# US1NCED0018
# 0.02426765502166045
# 10309 pumpkins located. 0 left. 100% done.

# %%
len(pumpkin_clean.nearest_station.unique())
# Out:
# 1394

# %%
weather_filtered = weather_growing_season.merge(pumpkin_clean.drop(["year","type","weight_lbs","city","state","state_code","latitude","longitude"], axis=1), how="inner", left_on="station_id", right_on="nearest_station").drop(["nearest_station"], axis=1)
weather_filtered.index = range(len(weather_filtered))
weather_filtered
# Out:
#           station_id       date element  value measurement_flag quality_flag  \
# 0        US1ALJF0037 2013-05-01    PRCP      0              NaN          NaN
# 1        US1ALJF0037 2013-05-01    PRCP      0              NaN          NaN
# 2        US1ALJF0037 2013-05-01    PRCP      0              NaN          NaN
# 3        US1ALJF0037 2013-05-01    PRCP      0              NaN          NaN
# 4        US1ALJF0037 2013-05-01    PRCP      0              NaN          NaN
# ...              ...        ...     ...    ...              ...          ...
# 8801622  US1WAKG0204 2021-09-28    PRCP     71              NaN          NaN
# 8801623  US1WAKG0204 2021-09-29    PRCP      0                T          NaN
# 8801624  US1WAKG0204 2021-09-29    PRCP      0                T          NaN
# 8801625  US1WAKG0204 2021-09-30    PRCP     43              NaN          NaN
# 8801626  US1WAKG0204 2021-09-30    PRCP     43              NaN          NaN
#
#         source_flag  time_of_observation
# 0                 N                  NaN
# 1                 N                  NaN
# 2                 N                  NaN
# 3                 N                  NaN
# 4                 N                  NaN
# ...             ...                  ...
# 8801622           N                  NaN
# 8801623           N                  NaN
# 8801624           N                  NaN
# 8801625           N                  NaN
# 8801626           N                  NaN
#
# [8801627 rows x 8 columns]

# %% [markdown]
# # Export Cleaned and Filtered Datasets

# %%
# Export Weather Dataset
weather_filtered.to_csv(r'weather.csv', index = False)

# %%
# Export Pumpkin Dataset
pumpkin_clean.to_csv(r'pumpkin.csv', index = False)
