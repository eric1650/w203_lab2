# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Pumpkin Dataset Exploratory Data Analysis

# %%
pumpkins_raw = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-10-19/pumpkins.csv")

# %%
pumpkins_raw
# Out:
#            id                                              place  \
# 0      2013-F                                                  1
# 1      2013-F                                                  2
# 2      2013-F                                                  3
# 3      2013-F                                                  4
# 4      2013-F                                                  5
# ...       ...                                                ...
# 28060  2021-W                                                DMG
# 28061  2021-W                                                DMG
# 28062  2021-W                                                DMG
# 28063  2021-W                                                DMG
# 28064  2021-W  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               weight_lbs  \
# 0                                                 154.50
# 1                                                 146.50
# 2                                                 145.00
# 3                                                 140.80
# 4                                                 139.00
# ...                                                  ...
# 28060                                             159.50
# 28061                                             141.00
# 28062                                             116.50
# 28063                                              16.30
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                              grower_name  \
# 0                            Ellenbecker, Todd & Sequoia
# 1                                            Razo, Steve
# 2                            Ellenbecker, Todd & Sequoia
# 3                                Martin, Margaret & Glen
# 4                                           Barlow, John
# ...                                                  ...
# 28060                                     Huber, Brandon
# 28061                                      Vester, Danny
# 28062                                   bradley, jeffrey
# 28063                                         Kyro, Anni
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                     city  \
# 0                                                Gleason
# 1                                         New Middletown
# 2                                                Glenson
# 3                                         Combined Locks
# 4                                                    NaN
# ...                                                  ...
# 28060                                            Raleigh
# 28061                                        Spring Hope
# 28062                                        rocky mount
# 28063                                         Orimattila
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               state_prov  \
# 0                                              Wisconsin
# 1                                                   Ohio
# 2                                              Wisconsin
# 3                                              Wisconsin
# 4                                              Wisconsin
# ...                                                  ...
# 28060                                     North Carolina
# 28061                                     North Carolina
# 28062                                     North Carolina
# 28063                                  Paijanne Tavastia
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                  country  \
# 0                                          United States
# 1                                          United States
# 2                                          United States
# 3                                          United States
# 4                                          United States
# ...                                                  ...
# 28060                                      United States
# 28061                                      United States
# 28062                                      United States
# 28063                                            Finland
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                 gpc_site  \
# 0                             Nekoosa Giant Pumpkin Fest
# 1            Ohio Valley Giant Pumpkin Growers Weigh-off
# 2                                  Mishicot Pumpkin Fest
# 3                    Cedarburg Wine and Harvest Festival
# 4                                 Stillwater Harvestfest
# ...                                                  ...
# 28060                    Yadkin Valley Pumpkin Weigh-off
# 28061                              Tennessee Valley Fair
# 28062              Spring Hope National Pumpkin Festival
# 28063                                  Finnish Weigh-off
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                              seed_mother  \
# 0                                             209 Werner
# 1                                           150.5 Snyder
# 2                                             209 Werner
# 3                                         109 Martin '12
# 4                                         130.5 McKinnon
# ...                                                  ...
# 28060                                           330 Vial
# 28061                                           305 Vial
# 28062                                             unknow
# 28063                            var. Carolina Cross -20
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                        pollinator_father  \
# 0                                                   Self
# 1                                                    NaN
# 2                                          103 Mackinnon
# 3                                         209 Werner '12
# 4                                                   open
# ...                                                  ...
# 28060                                                NaN
# 28061                                                NaN
# 28062                                                NaN
# 28063                                                NaN
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                      ott  \
# 0                                                  184.0
# 1                                                  194.0
# 2                                                  177.0
# 3                                                  194.0
# 4                                                    0.0
# ...                                                  ...
# 28060                                              175.0
# 28061                                              169.0
# 28062                                              159.0
# 28063                                                0.0
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               est_weight  \
# 0                                                 129.00
# 1                                                 151.00
# 2                                                 115.00
# 3                                                 151.00
# 4                                                   0.00
# ...                                                  ...
# 28060                                             152.00
# 28061                                             139.00
# 28062                                             116.00
# 28063                                               0.00
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                pct_chart variety
# 0                                                   20.0     NaN
# 1                                                   -3.0     NaN
# 2                                                   26.0     NaN
# 3                                                   -7.0     NaN
# 4                                                    0.0     NaN
# ...                                                  ...     ...
# 28060                                                5.0     NaN
# 28061                                                1.0     NaN
# 28062                                                0.0     NaN
# 28063                                                0.0     NaN
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...     NaN
#
# [28065 rows x 14 columns]

# %%
pumpkins_raw.shape
# Out:
# (28065, 14)

# %%
pumpkins_raw.columns
# Out:
# Index(['id', 'place', 'weight_lbs', 'grower_name', 'city', 'state_prov',
#        'country', 'gpc_site', 'seed_mother', 'pollinator_father', 'ott',
#        'est_weight', 'pct_chart', 'variety'],
#       dtype='object')

# %%
pumpkins = pumpkins_raw.drop([
    "grower_name",
    "gpc_site",
    "seed_mother",
    "pollinator_father",
    "pct_chart",
    "variety"
], axis=1)

pumpkins
# Out:
#            id                                              place  \
# 0      2013-F                                                  1
# 1      2013-F                                                  2
# 2      2013-F                                                  3
# 3      2013-F                                                  4
# 4      2013-F                                                  5
# ...       ...                                                ...
# 28060  2021-W                                                DMG
# 28061  2021-W                                                DMG
# 28062  2021-W                                                DMG
# 28063  2021-W                                                DMG
# 28064  2021-W  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               weight_lbs  \
# 0                                                 154.50
# 1                                                 146.50
# 2                                                 145.00
# 3                                                 140.80
# 4                                                 139.00
# ...                                                  ...
# 28060                                             159.50
# 28061                                             141.00
# 28062                                             116.50
# 28063                                              16.30
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                     city  \
# 0                                                Gleason
# 1                                         New Middletown
# 2                                                Glenson
# 3                                         Combined Locks
# 4                                                    NaN
# ...                                                  ...
# 28060                                            Raleigh
# 28061                                        Spring Hope
# 28062                                        rocky mount
# 28063                                         Orimattila
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               state_prov  \
# 0                                              Wisconsin
# 1                                                   Ohio
# 2                                              Wisconsin
# 3                                              Wisconsin
# 4                                              Wisconsin
# ...                                                  ...
# 28060                                     North Carolina
# 28061                                     North Carolina
# 28062                                     North Carolina
# 28063                                  Paijanne Tavastia
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                  country  \
# 0                                          United States
# 1                                          United States
# 2                                          United States
# 3                                          United States
# 4                                          United States
# ...                                                  ...
# 28060                                      United States
# 28061                                      United States
# 28062                                      United States
# 28063                                            Finland
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                                      ott  \
# 0                                                  184.0
# 1                                                  194.0
# 2                                                  177.0
# 3                                                  194.0
# 4                                                    0.0
# ...                                                  ...
# 28060                                              175.0
# 28061                                              169.0
# 28062                                              159.0
# 28063                                                0.0
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
#                                               est_weight
# 0                                                 129.00
# 1                                                 151.00
# 2                                                 115.00
# 3                                                 151.00
# 4                                                   0.00
# ...                                                  ...
# 28060                                             152.00
# 28061                                             139.00
# 28062                                             116.00
# 28063                                               0.00
# 28064  253 Entries.\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
# [28065 rows x 8 columns]

# %%
pumpkins[pumpkins.country == "United States"].state_prov.value_counts()
# Out:
# Wisconsin         1910
# California        1211
# Ohio              1190
# Michigan          1128
# Washington        1117
# Pennsylvania       992
# Oregon             873
# New York           802
# Minnesota          708
# Indiana            674
# Colorado           604
# Iowa               599
# Utah               518
# Connecticut        459
# North Carolina     427
# Massachusetts      415
# Vermont            381
# Kentucky           345
# Maine              332
# Rhode Island       308
# Tennessee          251
# New Hampshire      219
# South Dakota       201
# Illinois           192
# Missouri           165
# Virginia           145
# Arkansas           131
# West Virginia       89
# Wyoming             85
# Kansas              78
# Alabama             75
# Nebraska            69
# Oklahoma            61
# Alaska              61
# North Dakota        42
# Idaho               42
# Montana             35
# Georgia             29
# Louisiana           25
# New Jersey          22
# Arizona             12
# Texas               10
# South Carolina       9
# Nevada               7
# Maryland             7
# Delaware             5
# New Mexico           3
# Hawaii               3
# Mississippi          3
# Florida              1
# Name: state_prov, dtype: int64

# %%
us_pumpkins = pumpkins[pumpkins.country == "United States"]
us_pumpkins.reset_index()
us_pumpkins.city = us_pumpkins.city.str.title()
us_pumpkins.state_prov = us_pumpkins.state_prov.str.title()

us_pumpkins
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#            id place weight_lbs            city      state_prov        country  \
# 0      2013-F     1     154.50         Gleason       Wisconsin  United States
# 1      2013-F     2     146.50  New Middletown            Ohio  United States
# 2      2013-F     3     145.00         Glenson       Wisconsin  United States
# 3      2013-F     4     140.80  Combined Locks       Wisconsin  United States
# 4      2013-F     5     139.00             NaN       Wisconsin  United States
# ...       ...   ...        ...             ...             ...            ...
# 28058  2021-W   230       2.50          Garner  North Carolina  United States
# 28059  2021-W   DMG     181.00          Bailey  North Carolina  United States
# 28060  2021-W   DMG     159.50         Raleigh  North Carolina  United States
# 28061  2021-W   DMG     141.00     Spring Hope  North Carolina  United States
# 28062  2021-W   DMG     116.50     Rocky Mount  North Carolina  United States
#
#          ott est_weight
# 0      184.0     129.00
# 1      194.0     151.00
# 2      177.0     115.00
# 3      194.0     151.00
# 4        0.0       0.00
# ...      ...        ...
# 28058   42.0       0.00
# 28059  185.0     180.00
# 28060  175.0     152.00
# 28061  169.0     139.00
# 28062  159.0     116.00
#
# [17070 rows x 8 columns]

# %%
us_pumpkins.place.value_counts()
# Out:
# EXH     1191
# DMG      309
# 108       46
# 30        46
# 101       45
#         ...
# 1556       1
# 367        1
# 1704       1
# 1748       1
# 1624       1
# Name: place, Length: 1748, dtype: int64

# %%
# filter out "EXH" and "DMG" in "place" which are unofficial or invalid entries

us_pumpkins.place = pd.to_numeric(us_pumpkins.place, errors='coerce')
us_pumpkins[us_pumpkins.place.isna()]
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#            id  place weight_lbs          city      state_prov        country  \
# 12     2013-F    NaN     130.50    Saegertown    Pennsylvania  United States
# 35     2013-F    NaN     115.50      Bessemer    Pennsylvania  United States
# 59     2013-F    NaN     106.00        Tenino      Washington  United States
# 60     2013-F    NaN     106.00     Huntsburg            Ohio  United States
# 64     2013-F    NaN     105.00        Oswego        New York  United States
# ...       ...    ...        ...           ...             ...            ...
# 28015  2021-W    NaN      52.50  Kernersville  North Carolina  United States
# 28059  2021-W    NaN     181.00        Bailey  North Carolina  United States
# 28060  2021-W    NaN     159.50       Raleigh  North Carolina  United States
# 28061  2021-W    NaN     141.00   Spring Hope  North Carolina  United States
# 28062  2021-W    NaN     116.50   Rocky Mount  North Carolina  United States
#
#          ott est_weight
# 12     182.0     125.00
# 35       0.0       0.00
# 59       0.0       0.00
# 60       0.0       0.00
# 64     169.0     100.00
# ...      ...        ...
# 28015  115.0      46.00
# 28059  185.0     180.00
# 28060  175.0     152.00
# 28061  169.0     139.00
# 28062  159.0     116.00
#
# [1500 rows x 8 columns]

# %%
us_pumpkins = us_pumpkins[us_pumpkins.place.notnull()]
us_pumpkins.reset_index()
us_pumpkins
# Out:
#            id  place weight_lbs            city      state_prov  \
# 0      2013-F    1.0     154.50         Gleason       Wisconsin
# 1      2013-F    2.0     146.50  New Middletown            Ohio
# 2      2013-F    3.0     145.00         Glenson       Wisconsin
# 3      2013-F    4.0     140.80  Combined Locks       Wisconsin
# 4      2013-F    5.0     139.00             NaN       Wisconsin
# ...       ...    ...        ...             ...             ...
# 28050  2021-W  222.0      16.00      Plankinton    South Dakota
# 28052  2021-W  224.0       9.30             NaN            Utah
# 28055  2021-W  227.0       6.00     Fond Du Lac       Wisconsin
# 28057  2021-W  229.0       5.00     Fond Du Lac       Wisconsin
# 28058  2021-W  230.0       2.50          Garner  North Carolina
#
#              country    ott est_weight
# 0      United States  184.0     129.00
# 1      United States  194.0     151.00
# 2      United States  177.0     115.00
# 3      United States  194.0     151.00
# 4      United States    0.0       0.00
# ...              ...    ...        ...
# 28050  United States   86.0      21.00
# 28052  United States    0.0       0.00
# 28055  United States    0.0       0.00
# 28057  United States    0.0       0.00
# 28058  United States   42.0       0.00
#
# [15570 rows x 8 columns]

# %%
us_pumpkins.weight_lbs.value_counts()
# Out:
# 77.00       32
# 101.00      31
# 110.00      30
# 104.00      30
# 94.00       29
#             ..
# 591.50       1
# 1,243.00     1
# 4.04         1
# 2,004.00     1
# 8.71         1
# Name: weight_lbs, Length: 4572, dtype: int64

# %%
# Strip commas from weight_lbs, convert to number, and confirm all values are numeric

us_pumpkins.weight_lbs = us_pumpkins.weight_lbs.str.replace(',', '')
us_pumpkins.weight_lbs = pd.to_numeric(us_pumpkins.weight_lbs, errors='coerce')
us_pumpkins[us_pumpkins.weight_lbs.isna()].count()
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# id            0
# place         0
# weight_lbs    0
# city          0
# state_prov    0
# country       0
# ott           0
# est_weight    0
# dtype: int64

# %%
us_pumpkins.est_weight.value_counts()
# Out:
# 0.00        3281
# 1,170.00      40
# 1,187.00      39
# 1,338.00      38
# 1,002.00      38
#             ...
# 1,332.00       1
# 1,984.00       1
# 1,913.00       1
# 340.00         1
# 1,604.00       1
# Name: est_weight, Length: 1180, dtype: int64

# %%
us_pumpkins.est_weight.isna().sum()
# Out:
# 1623

# %%
# Strip commas from est_weight, convert to number, and confirm all values are numeric

us_pumpkins.est_weight = us_pumpkins.est_weight.str.replace(',', '')
us_pumpkins.est_weight = pd.to_numeric(us_pumpkins.est_weight, errors='coerce')
us_pumpkins[us_pumpkins.est_weight.isna()]
# Out:
#            id  place  weight_lbs            city     state_prov  \
# 2334   2013-T    5.0        5.59     Sharpsville   Pennsylvania
# 2336   2013-T    6.0        5.33  Combined Locks      Wisconsin
# 2341   2013-T   11.0        5.08      Snegertown   Pennsylvania
# 2342   2013-T   11.0        5.08      Snegertown   Pennsylvania
# 2344   2013-T   14.0        4.93         Seymour      Wisconsin
# ...       ...    ...         ...             ...            ...
# 27800  2021-T  334.0        0.44      Centennial       Colorado
# 27801  2021-T  335.0        0.33      Centennial       Colorado
# 27802  2021-T  336.0        0.32        Billings       Missouri
# 27803  2021-T  337.0        0.28      Barrington  New Hampshire
# 27804  2021-T  338.0        0.21          Aurora       Colorado
#
#              country  ott  est_weight
# 2334   United States  NaN         NaN
# 2336   United States  NaN         NaN
# 2341   United States  NaN         NaN
# 2342   United States  NaN         NaN
# 2344   United States  NaN         NaN
# ...              ...  ...         ...
# 27800  United States  NaN         NaN
# 27801  United States  NaN         NaN
# 27802  United States  NaN         NaN
# 27803  United States  NaN         NaN
# 27804  United States  NaN         NaN
#
# [1623 rows x 8 columns]

# %%
# Evaluate weight_lbs and est_weight

fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].hist(us_pumpkins.weight_lbs, bins=100)
ax[0].set_title("weight_lbs")
ax[1].hist(us_pumpkins.est_weight, bins=100)
ax[1].set_title("est_weight")
plt.show()

# %%
# find outlier record
us_pumpkins[us_pumpkins.est_weight > 2500]
# Out:
#            id   place  weight_lbs       city state_prov        country  \
# 20983  2019-P  1282.0       316.0  Littleton   Colorado  United States
#
#           ott  est_weight
# 20983  1132.0     11033.0

# %%
us_pumpkins.loc[20983, "est_weight"] = np.nan
us_pumpkins.loc[20983]
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# id                   2019-P
# place                  1282
# weight_lbs              316
# city              Littleton
# state_prov         Colorado
# country       United States
# ott                  1132.0
# est_weight              NaN
# Name: 20983, dtype: object

# %%
# Evaluate weight_lbs and est_weight after omitting outlier

fig, ax = plt.subplots(1,2, figsize=(15,5), sharex=True, sharey=True)

ax[0].hist(us_pumpkins.weight_lbs, bins=100)
ax[0].set_title("weight_lbs")
ax[1].hist(us_pumpkins.est_weight, bins=100)
ax[1].set_title("est_weight")
plt.show()

# %%
us_pumpkins.id.unique()
# Out:
# array(['2013-F', '2013-L', '2013-P', '2013-S', '2013-T', '2013-W',
#        '2014-F', '2014-L', '2014-P', '2014-S', '2014-T', '2014-W',
#        '2015-F', '2015-L', '2015-P', '2015-S', '2015-T', '2015-W',
#        '2016-F', '2016-L', '2016-P', '2016-S', '2016-T', '2016-W',
#        '2017-F', '2017-L', '2017-P', '2017-S', '2017-T', '2017-W',
#        '2018-F', '2018-L', '2018-P', '2018-S', '2018-T', '2018-W',
#        '2019-F', '2019-L', '2019-P', '2019-S', '2019-T', '2019-W',
#        '2020-F', '2020-L', '2020-P', '2020-S', '2020-T', '2020-W',
#        '2021-F', '2021-L', '2021-P', '2021-S', '2021-T', '2021-W'],
#       dtype=object)

# %%
us_pumpkins.loc[:,"year"] = us_pumpkins.loc[:,"id"].str[:4]
us_pumpkins.year.unique()
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# array(['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021'], dtype=object)

# %%
us_pumpkins.loc[:,"type"] = us_pumpkins.loc[:,"id"].str[-1]
us_pumpkins.type.unique()
# Out:
# array(['F', 'L', 'P', 'S', 'T', 'W'], dtype=object)

# %%
types = {
    "F" : "Field Pumpkin",
    "P" : "Giant Pumpkin", 
    "S" : "Giant Squash", 
    "W" : "Giant Watermelon", 
    "L" : "Long Gourd", #(length in inches, not weight in pounds) 
    "T" : "Tomato"
}

# %%
us_pumpkins["type"] = us_pumpkins["type"].map(types)
us_pumpkins
# Out:
# <ipython-input-25-26479dac6a7f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_pumpkins["type"] = us_pumpkins["type"].map(types)
#            id  place  weight_lbs            city      state_prov  \
# 0      2013-F    1.0       154.5         Gleason       Wisconsin
# 1      2013-F    2.0       146.5  New Middletown            Ohio
# 2      2013-F    3.0       145.0         Glenson       Wisconsin
# 3      2013-F    4.0       140.8  Combined Locks       Wisconsin
# 4      2013-F    5.0       139.0             NaN       Wisconsin
# ...       ...    ...         ...             ...             ...
# 28050  2021-W  222.0        16.0      Plankinton    South Dakota
# 28052  2021-W  224.0         9.3             NaN            Utah
# 28055  2021-W  227.0         6.0     Fond Du Lac       Wisconsin
# 28057  2021-W  229.0         5.0     Fond Du Lac       Wisconsin
# 28058  2021-W  230.0         2.5          Garner  North Carolina
#
#              country    ott  est_weight  year              type
# 0      United States  184.0       129.0  2013     Field Pumpkin
# 1      United States  194.0       151.0  2013     Field Pumpkin
# 2      United States  177.0       115.0  2013     Field Pumpkin
# 3      United States  194.0       151.0  2013     Field Pumpkin
# 4      United States    0.0         0.0  2013     Field Pumpkin
# ...              ...    ...         ...   ...               ...
# 28050  United States   86.0        21.0  2021  Giant Watermelon
# 28052  United States    0.0         0.0  2021  Giant Watermelon
# 28055  United States    0.0         0.0  2021  Giant Watermelon
# 28057  United States    0.0         0.0  2021  Giant Watermelon
# 28058  United States   42.0         0.0  2021  Giant Watermelon
#
# [15570 rows x 10 columns]

# %%
# Filter out all types except "Giant Pumpkin"

us_pumpkins = us_pumpkins[us_pumpkins.type == "Giant Pumpkin"]
us_pumpkins.reset_index()
us_pumpkins.drop(["id"], axis=1, inplace=True)
us_pumpkins
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         place  weight_lbs         city     state_prov        country    ott  \
# 496       1.0      2032.0         Napa     California  United States  475.0
# 497       2.0      1985.0         Napa     California  United States  453.0
# 498       3.0      1894.0         Napa     California  United States  445.0
# 499       4.0      1874.5         Napa     California  United States  436.0
# 501       6.0      1791.0       Sumner     Washington  United States  431.0
# ...       ...         ...          ...            ...            ...    ...
# 27235  1367.0        45.5          NaN  West Virginia  United States    0.0
# 27242  1373.0        30.0          NaN           Ohio  United States    0.0
# 27243  1374.0        27.0     Laveland       Colorado  United States  100.0
# 27245  1376.0        25.0   Sacramento     California  United States    0.0
# 27248  1378.0         1.0  Hodgenville       Kentucky  United States   39.0
#
#        est_weight  year           type
# 496        2000.0  2013  Giant Pumpkin
# 497        1809.0  2013  Giant Pumpkin
# 498        1745.0  2013  Giant Pumpkin
# 499        1667.0  2013  Giant Pumpkin
# 501        1619.0  2013  Giant Pumpkin
# ...           ...   ...            ...
# 27235         0.0  2021  Giant Pumpkin
# 27242         0.0  2021  Giant Pumpkin
# 27243        29.0  2021  Giant Pumpkin
# 27245         0.0  2021  Giant Pumpkin
# 27248         0.0  2021  Giant Pumpkin
#
# [9042 rows x 9 columns]

# %%
us_pumpkins.year.value_counts()
# Out:
# 2015    1182
# 2014    1141
# 2018    1077
# 2016    1038
# 2019    1037
# 2013    1004
# 2017     933
# 2021     840
# 2020     790
# Name: year, dtype: int64

# %%
us_pumpkins.weight_lbs.describe()
# Out:
# count    9042.000000
# mean      843.299604
# std       493.354997
# min         1.000000
# 25%       439.000000
# 50%       794.000000
# 75%      1205.500000
# max      2528.000000
# Name: weight_lbs, dtype: float64

# %%
# Evaluate weight_lbs and est_weight after filtering for only Giant Pumpkins

fig, ax = plt.subplots(1,2, figsize=(15,5), sharex=True)

ax[0].hist(us_pumpkins.weight_lbs, bins=100)
ax[0].set_title("weight_lbs")
ax[1].hist(us_pumpkins.est_weight, bins=100)
ax[1].set_title("est_weight")
plt.show()

# %%
pumpkins_clean = us_pumpkins[["year","type","weight_lbs","est_weight","ott","city","state_prov"]]
pumpkins_clean.index = range(len(pumpkins_clean))
pumpkins_clean.columns = ["year","type","weight_lbs","est_weight","ott","city","state"]
pumpkins_clean
# Out:
#       year           type  weight_lbs  est_weight    ott         city  \
# 0     2013  Giant Pumpkin      2032.0      2000.0  475.0         Napa
# 1     2013  Giant Pumpkin      1985.0      1809.0  453.0         Napa
# 2     2013  Giant Pumpkin      1894.0      1745.0  445.0         Napa
# 3     2013  Giant Pumpkin      1874.5      1667.0  436.0         Napa
# 4     2013  Giant Pumpkin      1791.0      1619.0  431.0       Sumner
# ...    ...            ...         ...         ...    ...          ...
# 9037  2021  Giant Pumpkin        45.5         0.0    0.0          NaN
# 9038  2021  Giant Pumpkin        30.0         0.0    0.0          NaN
# 9039  2021  Giant Pumpkin        27.0        29.0  100.0     Laveland
# 9040  2021  Giant Pumpkin        25.0         0.0    0.0   Sacramento
# 9041  2021  Giant Pumpkin         1.0         0.0   39.0  Hodgenville
#
#               state
# 0        California
# 1        California
# 2        California
# 3        California
# 4        Washington
# ...             ...
# 9037  West Virginia
# 9038           Ohio
# 9039       Colorado
# 9040     California
# 9041       Kentucky
#
# [9042 rows x 7 columns]

# %% [markdown]
# # Import, Format, and Filter Weather Data

# %%
# Read in weather data for years 2013 - 2021

weather_2013 = pd.read_csv("source_data/weather/2013.csv.gz", header=None)
print(2013)
weather_2014 = pd.read_csv("source_data/weather/2014.csv.gz", header=None)
print(2014)
weather_2015 = pd.read_csv("source_data/weather/2015.csv.gz", header=None)
print(2015)
weather_2016 = pd.read_csv("source_data/weather/2016.csv.gz", header=None)
print(2016)
weather_2017 = pd.read_csv("source_data/weather/2017.csv.gz", header=None)
print(2017)
weather_2018 = pd.read_csv("source_data/weather/2018.csv.gz", header=None)
print(2018)
weather_2019 = pd.read_csv("source_data/weather/2019.csv.gz", header=None)
print(2019)
weather_2020 = pd.read_csv("source_data/weather/2020.csv.gz", header=None)
print(2020)
weather_2021 = pd.read_csv("source_data/weather/2021.csv.gz", header=None)
print(2021)
# Out:
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
# Confirm csv files were correctly loaded

print(weather_2013.head(),"\n")
print(weather_2014.head(),"\n")
print(weather_2015.head(),"\n")
print(weather_2016.head(),"\n")
print(weather_2017.head(),"\n")
print(weather_2018.head(),"\n")
print(weather_2019.head(),"\n")
print(weather_2020.head(),"\n")
print(weather_2021.head(),"\n")
# Out:
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20130101  TMAX  250  NaN  NaN  S NaN
# 1  AE000041196  20130101  TAVG  176    H  NaN  S NaN
# 2  AEM00041194  20130101  TMAX  241  NaN  NaN  S NaN
# 3  AEM00041194  20130101  TMIN  157  NaN  NaN  S NaN
# 4  AEM00041194  20130101  PRCP    0  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20140101  TMAX  244  NaN  NaN  S NaN
# 1  AE000041196  20140101  TMIN  128  NaN  NaN  S NaN
# 2  AE000041196  20140101  TAVG  182    H  NaN  S NaN
# 3  AEM00041194  20140101  TMAX  241  NaN  NaN  S NaN
# 4  AEM00041194  20140101  TMIN  159  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20150101  TMIN  125  NaN  NaN  S NaN
# 1  AE000041196  20150101  PRCP    0  NaN  NaN  S NaN
# 2  AE000041196  20150101  TAVG  206    H  NaN  S NaN
# 3  AEM00041194  20150101  TMAX  286  NaN  NaN  S NaN
# 4  AEM00041194  20150101  TMIN  180  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20160101  TMIN  155  NaN  NaN  S NaN
# 1  AE000041196  20160101  TAVG  229    H  NaN  S NaN
# 2  AEM00041194  20160101  PRCP    0  NaN  NaN  S NaN
# 3  AEM00041194  20160101  TAVG  241    H  NaN  S NaN
# 4  AEM00041218  20160101  TMIN  182  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20170101  TMIN  163  NaN  NaN  S NaN
# 1  AE000041196  20170101  TAVG  217    H  NaN  S NaN
# 2  AEM00041194  20170101  PRCP    0  NaN  NaN  S NaN
# 3  AEM00041194  20170101  TAVG  223    H  NaN  S NaN
# 4  AEM00041218  20170101  TMIN  137  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20180101  TMAX  259  NaN  NaN  S NaN
# 1  AE000041196  20180101  TMIN  112  NaN  NaN  S NaN
# 2  AE000041196  20180101  TAVG  186    H  NaN  S NaN
# 3  AEM00041194  20180101  TMAX  250  NaN  NaN  S NaN
# 4  AEM00041194  20180101  PRCP    0  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20190101  TMAX  269  NaN  NaN  S NaN
# 1  AE000041196  20190101  TMIN  140  NaN  NaN  S NaN
# 2  AE000041196  20190101  TAVG  198    H  NaN  S NaN
# 3  AEM00041194  20190101  TMAX  280  NaN  NaN  S NaN
# 4  AEM00041194  20190101  TMIN  185  NaN  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20200101  TMIN  168  NaN  NaN  S NaN
# 1  AE000041196  20200101  PRCP    0    D  NaN  S NaN
# 2  AE000041196  20200101  TAVG  211    H  NaN  S NaN
# 3  AEM00041194  20200101  PRCP    0  NaN  NaN  S NaN
# 4  AEM00041194  20200101  TAVG  217    H  NaN  S NaN
#
#              0         1     2    3    4    5  6   7
# 0  AE000041196  20210101  TMAX  278  NaN  NaN  S NaN
# 1  AE000041196  20210101  PRCP    0    D  NaN  S NaN
# 2  AE000041196  20210101  TAVG  214    H  NaN  S NaN
# 3  AEM00041194  20210101  TMAX  266  NaN  NaN  S NaN
# 4  AEM00041194  20210101  TMIN  178  NaN  NaN  S NaN

# %%
# Name Columns

names = [
    "station_id",
    "date",
    "element",
    "value",
    "measurement_flag",
    "quality_flag",
    "source_flag",
    "time_of_observation"
]

weather_2013.columns = names
weather_2014.columns = names
weather_2015.columns = names
weather_2016.columns = names
weather_2017.columns = names
weather_2018.columns = names
weather_2019.columns = names
weather_2020.columns = names
weather_2021.columns = names

# %%
# Filter out all records that are not PRCP, TMIN, TMAX, TAVG

weather_2013 = weather_2013[weather_2013.element.isin(["PRCP","TMIN","TMAX"])]
weather_2014 = weather_2014[weather_2014.element.isin(["PRCP","TMIN","TMAX"])]
weather_2015 = weather_2015[weather_2015.element.isin(["PRCP","TMIN","TMAX"])]
weather_2016 = weather_2016[weather_2016.element.isin(["PRCP","TMIN","TMAX"])]
weather_2017 = weather_2017[weather_2017.element.isin(["PRCP","TMIN","TMAX"])]
weather_2018 = weather_2018[weather_2018.element.isin(["PRCP","TMIN","TMAX"])]
weather_2019 = weather_2019[weather_2019.element.isin(["PRCP","TMIN","TMAX"])]
weather_2020 = weather_2020[weather_2020.element.isin(["PRCP","TMIN","TMAX"])]
weather_2021 = weather_2021[weather_2021.element.isin(["PRCP","TMIN","TMAX"])]

# %%
# Filter out any weather stations that are missing PRCP or TMIN or TMAX

def unique(list1):
 
    # initialize a null list
    unique_list = []
     
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    return unique_list

station_list = list(weather_2013.station_id.unique())
station_list.append(list(weather_2014.station_id.unique()))
station_list.append(list(weather_2015.station_id.unique()))
station_list.append(list(weather_2016.station_id.unique()))
station_list.append(list(weather_2017.station_id.unique()))
station_list.append(list(weather_2018.station_id.unique()))
station_list.append(list(weather_2019.station_id.unique()))
station_list.append(list(weather_2020.station_id.unique()))
station_list.append(list(weather_2021.station_id.unique()))

unique_station_list = unique(station_list)
unique_station_list
# Out:
# ['AE000041196',
#  'AEM00041194',
#  'AEM00041218',
#  'AEM00041217',
#  'AG000060390',
#  'AG000060590',
#  'AG000060611',
#  'AGE00147708',
#  'AGE00147716',
#  'AGE00147718',
#  'AGM00060351',
#  'AGM00060360',
#  'AGM00060367',
#  'AGM00060369',
#  'AGM00060402',
#  'AGM00060403',
#  'AGM00060419',
#  'AGM00060421',
#  'AGM00060423',
#  'AGM00060425',
#  'AGM00060430',
#  'AGM00060437',
#  'AGM00060444',
#  'AGM00060445',
#  'AGM00060452',
#  'AGM00060457',
#  'AGM00060461',
#  'AGM00060467',
#  'AGM00060468',
#  'AGM00060475',
#  'AGM00060490',
#  'AGM00060507',
#  'AGM00060511',
#  'AGM00060514',
#  'AGM00060515',
#  'AGM00060518',
#  'AGM00060520',
#  'AGM00060522',
#  'AGM00060531',
#  'AGM00060535',
#  'AGM00060536',
#  'AGM00060540',
#  'AGM00060549',
#  'AGM00060550',
#  'AGM00060555',
#  'AGM00060557',
#  'AGM00060559',
#  'AGM00060560',
#  'AGM00060566',
#  'AGM00060571',
#  'AGM00060580',
#  'AGM00060581',
#  'AGM00060602',
#  'AGM00060603',
#  'AGM00060607',
#  'AGM00060620',
#  'AGM00060640',
#  'AGM00060656',
#  'AGM00060670',
#  'AJ000037675',
#  'AJ000037735',
#  'AJ000037749',
#  'AJ000037756',
#  'ALM00013615',
#  'AM000037682',
#  'AMM00037717',
#  'AQW00061705',
#  'AR000000011',
#  'AR000087007',
#  'AR000087129',
#  'AR000087155',
#  'AR000087217',
#  'AR000087257',
#  'AR000087270',
#  'AR000087344',
#  'AR000087418',
#  'AR000087534',
#  'AR000087623',
#  'AR000087692',
#  'AR000087715',
#  'AR000087803',
#  'AR000087828',
#  'AR000087860',
#  'AR000087925',
#  'AR000875850',
#  'AR000877500',
#  'ARM00087022',
#  'ARM00087046',
#  'ARM00087121',
#  'ARM00087148',
#  'ARM00087166',
#  'ARM00087178',
#  'ARM00087222',
#  'ARM00087289',
#  'ARM00087311',
#  'ARM00087320',
#  'ARM00087349',
#  'ARM00087395',
#  'ARM00087416',
#  'ARM00087436',
#  'ARM00087448',
#  'ARM00087453',
#  'ARM00087467',
#  'ARM00087480',
#  'ARM00087497',
#  'ARM00087506',
#  'ARM00087509',
#  'ARM00087532',
#  'ARM00087548',
#  'ARM00087576',
#  'ARM00087582',
#  'ARM00087593',
#  'ARM00087641',
#  'ARM00087645',
#  'ARM00087648',
#  'ARM00087765',
#  'ARM00087784',
#  'ARM00087791',
#  'ARM00087800',
#  'ARM00087904',
#  'ARM00087938',
#  'ASM00094299',
#  'ASM00094995',
#  'ASM00094998',
#  'ASN00001006',
#  'ASN00001007',
#  'ASN00001010',
#  'ASN00001013',
#  'ASN00001014',
#  'ASN00001018',
#  'ASN00001019',
#  'ASN00001020',
#  'ASN00001023',
#  'ASN00001024',
#  'ASN00001025',
#  'ASN00001026',
#  'ASN00001031',
#  'ASN00002005',
#  'ASN00002009',
#  'ASN00002012',
#  'ASN00002021',
#  'ASN00002022',
#  'ASN00002030',
#  'ASN00002032',
#  'ASN00002036',
#  'ASN00002043',
#  'ASN00002044',
#  'ASN00002049',
#  'ASN00002050',
#  'ASN00002056',
#  'ASN00002060',
#  'ASN00002064',
#  'ASN00002067',
#  'ASN00003000',
#  'ASN00003001',
#  'ASN00003003',
#  'ASN00003004',
#  'ASN00003008',
#  'ASN00003009',
#  'ASN00003014',
#  'ASN00003018',
#  'ASN00003019',
#  'ASN00003022',
#  'ASN00003026',
#  'ASN00003027',
#  'ASN00003028',
#  'ASN00003030',
#  'ASN00003032',
#  'ASN00003040',
#  'ASN00003051',
#  'ASN00003052',
#  'ASN00003057',
#  'ASN00003059',
#  'ASN00003063',
#  'ASN00003066',
#  'ASN00003068',
#  'ASN00003073',
#  'ASN00003075',
#  'ASN00003080',
#  'ASN00003084',
#  'ASN00003086',
#  'ASN00003093',
#  'ASN00003096',
#  'ASN00003098',
#  'ASN00003100',
#  'ASN00003104',
#  'ASN00003105',
#  'ASN00004004',
#  'ASN00004006',
#  'ASN00004008',
#  'ASN00004019',
#  'ASN00004026',
#  'ASN00004028',
#  'ASN00004032',
#  'ASN00004033',
#  'ASN00004035',
#  'ASN00004036',
#  'ASN00004038',
#  'ASN00004039',
#  'ASN00004042',
#  'ASN00004068',
#  'ASN00004083',
#  'ASN00004086',
#  'ASN00004090',
#  'ASN00004103',
#  'ASN00004106',
#  'ASN00005004',
#  'ASN00005007',
#  'ASN00005008',
#  'ASN00005009',
#  'ASN00005012',
#  'ASN00005013',
#  'ASN00005014',
#  'ASN00005017',
#  'ASN00005020',
#  'ASN00005022',
#  'ASN00005026',
#  'ASN00005029',
#  'ASN00005032',
#  'ASN00005036',
#  'ASN00005040',
#  'ASN00005051',
#  'ASN00005052',
#  'ASN00005061',
#  'ASN00005069',
#  'ASN00005070',
#  'ASN00005071',
#  'ASN00005078',
#  'ASN00005082',
#  'ASN00005084',
#  'ASN00005088',
#  'ASN00005094',
#  'ASN00005095',
#  'ASN00006001',
#  'ASN00006008',
#  'ASN00006010',
#  'ASN00006011',
#  'ASN00006015',
#  'ASN00006020',
#  'ASN00006023',
#  'ASN00006026',
#  'ASN00006027',
#  'ASN00006030',
#  'ASN00006033',
#  'ASN00006034',
#  'ASN00006038',
#  'ASN00006040',
#  'ASN00006044',
#  'ASN00006045',
#  'ASN00006052',
#  'ASN00006055',
#  'ASN00006058',
#  'ASN00006059',
#  'ASN00006071',
#  'ASN00006072',
#  'ASN00006084',
#  'ASN00006097',
#  'ASN00006099',
#  'ASN00006100',
#  'ASN00006102',
#  'ASN00006105',
#  'ASN00007001',
#  'ASN00007011',
#  'ASN00007017',
#  'ASN00007027',
#  'ASN00007030',
#  'ASN00007034',
#  'ASN00007042',
#  'ASN00007045',
#  'ASN00007048',
#  'ASN00007058',
#  'ASN00007059',
#  'ASN00007065',
#  'ASN00007078',
#  'ASN00007081',
#  'ASN00007083',
#  'ASN00007091',
#  'ASN00007097',
#  'ASN00007103',
#  'ASN00007104',
#  'ASN00007139',
#  'ASN00007152',
#  'ASN00007154',
#  'ASN00007157',
#  'ASN00007159',
#  'ASN00007162',
#  'ASN00007165',
#  'ASN00007176',
#  'ASN00007177',
#  'ASN00007181',
#  'ASN00007185',
#  'ASN00007193',
#  'ASN00007194',
#  'ASN00007195',
#  'ASN00007197',
#  'ASN00007600',
#  'ASN00008004',
#  'ASN00008005',
#  'ASN00008007',
#  'ASN00008009',
#  'ASN00008010',
#  'ASN00008014',
#  'ASN00008017',
#  'ASN00008025',
#  'ASN00008028',
#  'ASN00008037',
#  'ASN00008038',
#  'ASN00008050',
#  'ASN00008051',
#  'ASN00008052',
#  'ASN00008057',
#  'ASN00008060',
#  'ASN00008061',
#  'ASN00008064',
#  'ASN00008065',
#  'ASN00008066',
#  'ASN00008067',
#  'ASN00008072',
#  'ASN00008075',
#  'ASN00008077',
#  'ASN00008078',
#  'ASN00008081',
#  'ASN00008088',
#  'ASN00008095',
#  'ASN00008096',
#  'ASN00008100',
#  'ASN00008104',
#  'ASN00008113',
#  'ASN00008116',
#  'ASN00008121',
#  'ASN00008130',
#  'ASN00008137',
#  'ASN00008141',
#  'ASN00008143',
#  'ASN00008147',
#  'ASN00008157',
#  'ASN00008160',
#  'ASN00008174',
#  'ASN00008179',
#  'ASN00008202',
#  'ASN00008225',
#  'ASN00008230',
#  'ASN00008233',
#  'ASN00008237',
#  'ASN00008240',
#  'ASN00008251',
#  'ASN00008254',
#  'ASN00008264',
#  'ASN00008271',
#  'ASN00008273',
#  'ASN00008274',
#  'ASN00008276',
#  'ASN00008283',
#  'ASN00008285',
#  'ASN00008286',
#  'ASN00008290',
#  'ASN00008292',
#  'ASN00008294',
#  'ASN00008295',
#  'ASN00008296',
#  'ASN00008297',
#  'ASN00008298',
#  'ASN00008299',
#  'ASN00008300',
#  'ASN00008304',
#  'ASN00008305',
#  'ASN00008306',
#  'ASN00008307',
#  'ASN00008308',
#  'ASN00008309',
#  'ASN00008310',
#  'ASN00008313',
#  'ASN00009001',
#  'ASN00009007',
#  'ASN00009009',
#  'ASN00009010',
#  'ASN00009021',
#  'ASN00009023',
#  'ASN00009024',
#  'ASN00009031',
#  'ASN00009033',
#  'ASN00009037',
#  'ASN00009039',
#  'ASN00009040',
#  'ASN00009044',
#  'ASN00009053',
#  'ASN00009054',
#  'ASN00009066',
#  'ASN00009106',
#  'ASN00009111',
#  'ASN00009112',
#  'ASN00009113',
#  'ASN00009114',
#  'ASN00009115',
#  'ASN00009131',
#  'ASN00009144',
#  'ASN00009151',
#  'ASN00009168',
#  'ASN00009169',
#  'ASN00009172',
#  'ASN00009178',
#  'ASN00009181',
#  'ASN00009187',
#  'ASN00009193',
#  'ASN00009194',
#  'ASN00009202',
#  'ASN00009204',
#  'ASN00009206',
#  'ASN00009207',
#  'ASN00009209',
#  'ASN00009211',
#  'ASN00009215',
#  'ASN00009216',
#  'ASN00009225',
#  'ASN00009240',
#  'ASN00009242',
#  'ASN00009248',
#  'ASN00009249',
#  'ASN00009252',
#  'ASN00009253',
#  'ASN00009256',
#  'ASN00009257',
#  'ASN00009258',
#  'ASN00009260',
#  'ASN00009263',
#  'ASN00009264',
#  'ASN00009503',
#  'ASN00009504',
#  'ASN00009505',
#  'ASN00009506',
#  'ASN00009507',
#  'ASN00009509',
#  'ASN00009515',
#  'ASN00009518',
#  'ASN00009519',
#  'ASN00009520',
#  'ASN00009527',
#  'ASN00009530',
#  'ASN00009531',
#  'ASN00009532',
#  'ASN00009534',
#  'ASN00009538',
#  'ASN00009542',
#  'ASN00009547',
#  'ASN00009551',
#  'ASN00009552',
#  'ASN00009556',
#  'ASN00009561',
#  'ASN00009573',
#  'ASN00009574',
#  'ASN00009579',
#  'ASN00009581',
#  'ASN00009584',
#  'ASN00009587',
#  'ASN00009589',
#  'ASN00009590',
#  'ASN00009592',
#  'ASN00009594',
#  'ASN00009599',
#  'ASN00009600',
#  'ASN00009603',
#  'ASN00009605',
#  'ASN00009609',
#  'ASN00009613',
#  'ASN00009615',
#  'ASN00009616',
#  'ASN00009617',
#  'ASN00009621',
#  'ASN00009624',
#  'ASN00009625',
#  'ASN00009626',
#  'ASN00009628',
#  'ASN00009629',
#  'ASN00009631',
#  'ASN00009633',
#  'ASN00009635',
#  'ASN00009636',
#  'ASN00009642',
#  'ASN00009645',
#  'ASN00009647',
#  'ASN00009657',
#  'ASN00009661',
#  'ASN00009666',
#  'ASN00009668',
#  'ASN00009671',
#  'ASN00009678',
#  'ASN00009692',
#  'ASN00009695',
#  'ASN00009714',
#  'ASN00009715',
#  'ASN00009730',
#  'ASN00009738',
#  'ASN00009739',
#  'ASN00009741',
#  'ASN00009744',
#  'ASN00009746',
#  'ASN00009752',
#  'ASN00009754',
#  'ASN00009766',
#  'ASN00009769',
#  'ASN00009771',
#  'ASN00009772',
#  'ASN00009776',
#  'ASN00009784',
#  'ASN00009789',
#  'ASN00009800',
#  'ASN00009801',
#  'ASN00009803',
#  'ASN00009804',
#  'ASN00009805',
#  'ASN00009812',
#  'ASN00009815',
#  'ASN00009822',
#  'ASN00009827',
#  'ASN00009831',
#  'ASN00009832',
#  'ASN00009837',
#  'ASN00009842',
#  'ASN00009843',
#  'ASN00009848',
#  'ASN00009850',
#  'ASN00009851',
#  'ASN00009862',
#  'ASN00009867',
#  'ASN00009868',
#  'ASN00009870',
#  'ASN00009871',
#  'ASN00009875',
#  'ASN00009877',
#  'ASN00009891',
#  'ASN00009893',
#  'ASN00009894',
#  'ASN00009897',
#  'ASN00009899',
#  'ASN00009904',
#  'ASN00009908',
#  'ASN00009909',
#  'ASN00009912',
#  'ASN00009913',
#  'ASN00009914',
#  'ASN00009916',
#  'ASN00009917',
#  'ASN00009921',
#  'ASN00009922',
#  'ASN00009923',
#  'ASN00009924',
#  'ASN00009927',
#  'ASN00009928',
#  'ASN00009936',
#  'ASN00009954',
#  'ASN00009957',
#  'ASN00009958',
#  'ASN00009960',
#  'ASN00009961',
#  'ASN00009964',
#  'ASN00009965',
#  'ASN00009967',
#  'ASN00009971',
#  'ASN00009976',
#  'ASN00009977',
#  'ASN00009978',
#  'ASN00009980',
#  'ASN00009982',
#  'ASN00009985',
#  'ASN00009987',
#  'ASN00009989',
#  'ASN00009990',
#  'ASN00009991',
#  'ASN00009992',
#  'ASN00009994',
#  'ASN00009997',
#  'ASN00009998',
#  'ASN00010000',
#  'ASN00010006',
#  'ASN00010007',
#  'ASN00010009',
#  'ASN00010012',
#  'ASN00010017',
#  'ASN00010019',
#  'ASN00010026',
#  'ASN00010030',
#  'ASN00010032',
#  'ASN00010034',
#  'ASN00010036',
#  'ASN00010040',
#  'ASN00010041',
#  'ASN00010042',
#  'ASN00010043',
#  'ASN00010044',
#  'ASN00010045',
#  'ASN00010052',
#  'ASN00010053',
#  'ASN00010055',
#  'ASN00010058',
#  'ASN00010061',
#  'ASN00010064',
#  'ASN00010070',
#  'ASN00010073',
#  'ASN00010075',
#  'ASN00010076',
#  'ASN00010077',
#  'ASN00010082',
#  'ASN00010084',
#  'ASN00010092',
#  'ASN00010093',
#  'ASN00010097',
#  'ASN00010108',
#  'ASN00010111',
#  'ASN00010112',
#  'ASN00010118',
#  'ASN00010119',
#  'ASN00010121',
#  'ASN00010124',
#  'ASN00010125',
#  'ASN00010126',
#  'ASN00010134',
#  'ASN00010135',
#  'ASN00010136',
#  'ASN00010137',
#  'ASN00010138',
#  'ASN00010140',
#  'ASN00010141',
#  'ASN00010145',
#  'ASN00010149',
#  'ASN00010150',
#  'ASN00010151',
#  'ASN00010155',
#  'ASN00010163',
#  'ASN00010166',
#  'ASN00010192',
#  'ASN00010195',
#  'ASN00010230',
#  'ASN00010250',
#  'ASN00010264',
#  'ASN00010286',
#  'ASN00010294',
#  'ASN00010304',
#  'ASN00010307',
#  'ASN00010308',
#  'ASN00010310',
#  'ASN00010311',
#  'ASN00010502',
#  'ASN00010508',
#  'ASN00010510',
#  'ASN00010513',
#  'ASN00010515',
#  'ASN00010518',
#  'ASN00010519',
#  'ASN00010520',
#  'ASN00010524',
#  'ASN00010525',
#  'ASN00010527',
#  'ASN00010530',
#  'ASN00010531',
#  'ASN00010534',
#  'ASN00010536',
#  'ASN00010537',
#  'ASN00010547',
#  'ASN00010556',
#  'ASN00010558',
#  'ASN00010560',
#  'ASN00010561',
#  'ASN00010564',
#  'ASN00010565',
#  'ASN00010568',
#  'ASN00010571',
#  'ASN00010581',
#  'ASN00010582',
#  'ASN00010584',
#  'ASN00010595',
#  'ASN00010603',
#  'ASN00010606',
#  'ASN00010611',
#  'ASN00010612',
#  'ASN00010614',
#  'ASN00010617',
#  'ASN00010619',
#  'ASN00010622',
#  'ASN00010623',
#  'ASN00010626',
#  'ASN00010628',
#  'ASN00010633',
#  'ASN00010635',
#  'ASN00010638',
#  'ASN00010641',
#  'ASN00010643',
#  'ASN00010644',
#  'ASN00010647',
#  'ASN00010654',
#  'ASN00010658',
#  'ASN00010664',
#  'ASN00010665',
#  'ASN00010666',
#  'ASN00010668',
#  'ASN00010670',
#  'ASN00010691',
#  'ASN00010692',
#  'ASN00010694',
#  'ASN00010696',
#  'ASN00010702',
#  'ASN00010703',
#  'ASN00010704',
#  'ASN00010707',
#  'ASN00010708',
#  'ASN00010725',
#  'ASN00010729',
#  'ASN00010750',
#  'ASN00010779',
#  'ASN00010789',
#  'ASN00010792',
#  'ASN00010795',
#  'ASN00010797',
#  'ASN00010799',
#  'ASN00010802',
#  'ASN00010803',
#  'ASN00010811',
#  'ASN00010823',
#  'ASN00010831',
#  'ASN00010866',
#  'ASN00010869',
#  'ASN00010872',
#  'ASN00010876',
#  'ASN00010878',
#  'ASN00010881',
#  'ASN00010888',
#  'ASN00010893',
#  'ASN00010896',
#  'ASN00010897',
#  'ASN00010898',
#  'ASN00010901',
#  'ASN00010904',
#  'ASN00010905',
#  'ASN00010908',
#  'ASN00010910',
#  'ASN00010911',
#  'ASN00010916',
#  'ASN00010917',
#  'ASN00011003',
#  'ASN00011008',
#  'ASN00011009',
#  'ASN00011010',
#  'ASN00011017',
#  'ASN00011019',
#  'ASN00011022',
#  'ASN00011029',
#  'ASN00011030',
#  'ASN00011031',
#  'ASN00011032',
#  'ASN00011033',
#  'ASN00011034',
#  'ASN00011035',
#  'ASN00011048',
#  'ASN00011050',
#  'ASN00011052',
#  'ASN00011053',
#  'ASN00012007',
#  'ASN00012008',
#  'ASN00012009',
#  'ASN00012011',
#  'ASN00012013',
#  'ASN00012025',
#  'ASN00012027',
#  'ASN00012028',
#  'ASN00012029',
#  'ASN00012038',
#  'ASN00012043',
#  'ASN00012044',
#  'ASN00012045',
#  'ASN00012046',
#  'ASN00012052',
#  'ASN00012054',
#  'ASN00012056',
#  'ASN00012061',
#  'ASN00012064',
#  'ASN00012066',
#  'ASN00012070',
#  'ASN00012071',
#  'ASN00012077',
#  'ASN00012079',
#  'ASN00012083',
#  'ASN00012088',
#  'ASN00012090',
#  'ASN00012092',
#  'ASN00012093',
#  'ASN00012107',
#  'ASN00012108',
#  'ASN00012117',
#  'ASN00012141',
#  'ASN00012152',
#  'ASN00012187',
#  'ASN00012198',
#  'ASN00012201',
#  'ASN00012220',
#  'ASN00012223',
#  'ASN00012239',
#  'ASN00012240',
#  'ASN00012241',
#  'ASN00012262',
#  'ASN00012280',
#  'ASN00012281',
#  'ASN00012283',
#  'ASN00012285',
#  'ASN00012291',
#  'ASN00012297',
#  'ASN00012305',
#  'ASN00012306',
#  'ASN00012308',
#  'ASN00012311',
#  'ASN00012312',
#  'ASN00012314',
#  'ASN00012320',
#  'ASN00013002',
#  'ASN00013006',
#  'ASN00013007',
#  'ASN00013011',
#  'ASN00013012',
#  'ASN00013015',
#  'ASN00013017',
#  'ASN00013018',
#  'ASN00013024',
#  'ASN00013030',
#  'ASN00013039',
#  'ASN00013040',
#  'ASN00013043',
#  'ASN00014009',
#  'ASN00014013',
#  'ASN00014015',
#  'ASN00014022',
#  'ASN00014039',
#  'ASN00014040',
#  'ASN00014041',
#  'ASN00014042',
#  'ASN00014048',
#  'ASN00014049',
#  'ASN00014055',
#  'ASN00014062',
#  'ASN00014070',
#  'ASN00014073',
#  'ASN00014112',
#  'ASN00014113',
#  'ASN00014116',
#  'ASN00014141',
#  'ASN00014142',
#  'ASN00014143',
#  'ASN00014144',
#  'ASN00014149',
#  'ASN00014153',
#  'ASN00014167',
#  'ASN00014183',
#  'ASN00014198',
#  'ASN00014204',
#  'ASN00014205',
#  'ASN00014206',
#  'ASN00014219',
#  'ASN00014222',
#  'ASN00014224',
#  'ASN00014226',
#  'ASN00014227',
#  'ASN00014235',
#  'ASN00014237',
#  'ASN00014239',
#  'ASN00014245',
#  'ASN00014246',
#  'ASN00014251',
#  'ASN00014252',
#  'ASN00014253',
#  'ASN00014254',
#  'ASN00014256',
#  'ASN00014259',
#  'ASN00014261',
#  'ASN00014263',
#  'ASN00014264',
#  'ASN00014272',
#  'ASN00014274',
#  'ASN00014277',
#  'ASN00014279',
#  'ASN00014284',
#  'ASN00014285',
#  'ASN00014289',
#  'ASN00014401',
#  'ASN00014404',
#  'ASN00014405',
#  'ASN00014508',
#  'ASN00014512',
#  'ASN00014515',
#  'ASN00014517',
#  'ASN00014518',
#  'ASN00014600',
#  'ASN00014612',
#  'ASN00014618',
#  'ASN00014621',
#  'ASN00014626',
#  'ASN00014627',
#  'ASN00014638',
#  'ASN00014641',
#  'ASN00014644',
#  'ASN00014648',
#  'ASN00014650',
#  'ASN00014651',
#  'ASN00014652',
#  'ASN00014653',
#  'ASN00014654',
#  'ASN00014702',
#  'ASN00014703',
#  'ASN00014704',
#  'ASN00014705',
#  'ASN00014707',
#  'ASN00014718',
#  'ASN00014723',
#  'ASN00014729',
#  'ASN00014730',
#  'ASN00014802',
#  'ASN00014815',
#  'ASN00014816',
#  'ASN00014817',
#  'ASN00014821',
#  'ASN00014824',
#  'ASN00014825',
#  'ASN00014828',
#  'ASN00014829',
#  'ASN00014831',
#  'ASN00014836',
#  'ASN00014839',
#  'ASN00014847',
#  'ASN00014850',
#  'ASN00014853',
#  'ASN00014854',
#  'ASN00014855',
#  'ASN00014857',
#  'ASN00014858',
#  'ASN00014866',
#  'ASN00014867',
#  'ASN00014901',
#  'ASN00014902',
#  'ASN00014903',
#  'ASN00014906',
#  'ASN00014909',
#  'ASN00014910',
#  'ASN00014913',
#  'ASN00014921',
#  'ASN00014925',
#  'ASN00014927',
#  'ASN00014932',
#  'ASN00014938',
#  'ASN00014940',
#  'ASN00014941',
#  'ASN00014947',
#  'ASN00014948',
#  'ASN00014949',
#  'ASN00014950',
#  'ASN00014954',
#  'ASN00014955',
#  'ASN00014956',
#  'ASN00014959',
#  'ASN00014962',
#  'ASN00014966',
#  'ASN00014967',
#  'ASN00014970',
#  'ASN00015005',
#  'ASN00015027',
#  'ASN00015085',
#  'ASN00015086',
#  'ASN00015088',
#  'ASN00015125',
#  'ASN00015131',
#  'ASN00015135',
#  'ASN00015139',
#  'ASN00015503',
#  'ASN00015511',
#  'ASN00015519',
#  'ASN00015521',
#  'ASN00015528',
#  'ASN00015531',
#  'ASN00015536',
#  'ASN00015547',
#  'ASN00015548',
#  'ASN00015553',
#  'ASN00015554',
#  'ASN00015559',
#  'ASN00015560',
#  'ASN00015564',
#  'ASN00015574',
#  'ASN00015579',
#  'ASN00015584',
#  'ASN00015585',
#  'ASN00015588',
#  'ASN00015590',
#  'ASN00015594',
#  'ASN00015595',
#  'ASN00015602',
#  'ASN00015603',
#  'ASN00015607',
#  'ASN00015608',
#  'ASN00015610',
#  'ASN00015611',
#  'ASN00015617',
#  'ASN00015620',
#  'ASN00015626',
#  'ASN00015628',
#  'ASN00015633',
#  ...]

# %%
len(unique_station_list)
# Out:
# 41554

# %%
day_count_2013 = weather_2013.groupby(["station_id"]).element.count().max()
day_count_2014 = weather_2014.groupby(["station_id"]).element.count().max()
day_count_2015 = weather_2015.groupby(["station_id"]).element.count().max()
day_count_2016 = weather_2016.groupby(["station_id"]).element.count().max()
day_count_2017 = weather_2017.groupby(["station_id"]).element.count().max()
day_count_2018 = weather_2018.groupby(["station_id"]).element.count().max()
day_count_2019 = weather_2019.groupby(["station_id"]).element.count().max()
day_count_2020 = weather_2020.groupby(["station_id"]).element.count().max()
day_count_2021 = weather_2021.groupby(["station_id"]).element.count().max()

total_day_element_count = (day_count_2013 + 
                          day_count_2014 + 
                          day_count_2015 + 
                          day_count_2016 + 
                          day_count_2017 + 
                          day_count_2018 + 
                          day_count_2019 + 
                          day_count_2020 + 
                          day_count_2021)

print(total_day_element_count)
# Out:
# 9765

# %%
# Merge all years into a single dataset

weather = weather_2013.append(weather_2014, ignore_index=True)
print("2013")
print("2014")
weather = weather.append(weather_2015, ignore_index=True)
print("2015")
weather = weather.append(weather_2016, ignore_index=True)
print("2016")
weather = weather.append(weather_2017, ignore_index=True)
print("2017")
weather = weather.append(weather_2018, ignore_index=True)
print("2018")
weather = weather.append(weather_2019, ignore_index=True)
print("2019")
weather = weather.append(weather_2020, ignore_index=True)
print("2020")
weather = weather.append(weather_2021, ignore_index=True)
print("2021")
# Out:
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
weather
# Out:
#             station_id      date element  value measurement_flag quality_flag  \
# 0          AE000041196  20130101    TMAX    250              NaN          NaN
# 1          AEM00041194  20130101    TMAX    241              NaN          NaN
# 2          AEM00041194  20130101    TMIN    157              NaN          NaN
# 3          AEM00041194  20130101    PRCP      0              NaN          NaN
# 4          AEM00041218  20130101    TMAX    255              NaN          NaN
# ...                ...       ...     ...    ...              ...          ...
# 176290647  GQC00914001  20211129    PRCP    203              NaN          NaN
# 176290648  GQC00914275  20211129    PRCP    208              NaN          NaN
# 176290649  RMW00040710  20211129    TMAX    311              NaN          NaN
# 176290650  RMW00040710  20211129    TMIN    261              NaN          NaN
# 176290651  RMW00040710  20211129    PRCP     28              NaN          NaN
#
#           source_flag  time_of_observation
# 0                   S                  NaN
# 1                   S                  NaN
# 2                   S                  NaN
# 3                   S                  NaN
# 4                   S                  NaN
# ...               ...                  ...
# 176290647           H                800.0
# 176290648           H                900.0
# 176290649           H               2400.0
# 176290650           H               2400.0
# 176290651           H               2400.0
#
# [176290652 rows x 8 columns]

# %%
weather["date"] = pd.to_datetime(weather.date, format='%Y%m%d')
weather
# Out:
#             station_id       date element  value measurement_flag  \
# 0          AE000041196 2013-01-01    TMAX    250              NaN
# 1          AEM00041194 2013-01-01    TMAX    241              NaN
# 2          AEM00041194 2013-01-01    TMIN    157              NaN
# 3          AEM00041194 2013-01-01    PRCP      0              NaN
# 4          AEM00041218 2013-01-01    TMAX    255              NaN
# ...                ...        ...     ...    ...              ...
# 176290647  GQC00914001 2021-11-29    PRCP    203              NaN
# 176290648  GQC00914275 2021-11-29    PRCP    208              NaN
# 176290649  RMW00040710 2021-11-29    TMAX    311              NaN
# 176290650  RMW00040710 2021-11-29    TMIN    261              NaN
# 176290651  RMW00040710 2021-11-29    PRCP     28              NaN
#
#           quality_flag source_flag  time_of_observation
# 0                  NaN           S                  NaN
# 1                  NaN           S                  NaN
# 2                  NaN           S                  NaN
# 3                  NaN           S                  NaN
# 4                  NaN           S                  NaN
# ...                ...         ...                  ...
# 176290647          NaN           H                800.0
# 176290648          NaN           H                900.0
# 176290649          NaN           H               2400.0
# 176290650          NaN           H               2400.0
# 176290651          NaN           H               2400.0
#
# [176290652 rows x 8 columns]

# %%
weather_growing_season = weather[weather.date.dt.month.isin(range(5,10))]
weather_growing_season
# Out:
#             station_id       date element  value measurement_flag  \
# 6868521    AE000041196 2013-05-01    TMAX    331              NaN
# 6868522    AE000041196 2013-05-01    TMIN    224              NaN
# 6868523    AEM00041194 2013-05-01    TMAX    317              NaN
# 6868524    AEM00041194 2013-05-01    TMIN    248              NaN
# 6868525    AEM00041194 2013-05-01    PRCP      0              NaN
# ...                ...        ...     ...    ...              ...
# 173850471  WFM00091754 2021-09-30    TMAX    295              NaN
# 173850472  WFM00091754 2021-09-30    TMIN    264              NaN
# 173850473  WIM00060096 2021-09-30    TMIN    225              NaN
# 173850474  WQW00041606 2021-09-30    TMAX    310              NaN
# 173850475  WQW00041606 2021-09-30    TMIN    269              NaN
#
#           quality_flag source_flag  time_of_observation
# 6868521            NaN           S                  NaN
# 6868522            NaN           S                  NaN
# 6868523            NaN           S                  NaN
# 6868524            NaN           S                  NaN
# 6868525            NaN           S                  NaN
# ...                ...         ...                  ...
# 173850471          NaN           S                  NaN
# 173850472          NaN           S                  NaN
# 173850473          NaN           S                  NaN
# 173850474          NaN           S                  NaN
# 173850475          NaN           S                  NaN
#
# [75224695 rows x 8 columns]

# %%
75224695/176290652
# Out:
# 0.4267083600099227

# %%
weather_grouped = weather_growing_season.groupby(["station_id","date"]).element.count().reset_index()
day_element_count = weather_grouped.groupby(["station_id"]).element.sum().max()
day_element_count
# Out:
# 4131

# %%
weather_grouped_2 = weather_grouped.drop(["date"], axis=1).groupby("station_id").sum().reset_index()
weather_grouped_2
# Out:
#         station_id  element
# 0      AE000041196     2287
# 1      AEM00041194     2893
# 2      AEM00041217     1696
# 3      AEM00041218     1593
# 4      AFM00040938      473
# ...            ...      ...
# 58182  ZA000067633        2
# 58183  ZA000067743      229
# 58184  ZI000067775     1493
# 58185  ZI000067975     1401
# 58186  ZI000067983     1077
#
# [58187 rows x 2 columns]

# %%
weather_grouped_2_filtered = weather_grouped_2[weather_grouped_2.element == 4131]
weather_grouped_2_filtered
# Out:
#         station_id  element
# 9653   FMW00040308     4131
# 9654   FMW00040504     4131
# 10401  GQW00041415     4131
# 47262  USC00022782     4131
# 47290  USC00025412     4131
# ...            ...      ...
# 58021  USW00094946     4131
# 58022  USW00094949     4131
# 58023  USW00094950     4131
# 58026  USW00094960     4131
# 58036  USW00094989     4131
#
# [909 rows x 2 columns]

# %%
station_list_complete = list(weather_grouped_2_filtered.station_id.unique())
len(station_list_complete)
# Out:
# 909

# %%
weather_filtered = weather_growing_season[weather_growing_season.station_id.isin(station_list_complete)]
weather_filtered
# Out:
#             station_id       date element  value measurement_flag  \
# 6879861    FMW00040308 2013-05-01    TMAX    338              NaN
# 6879862    FMW00040308 2013-05-01    TMIN    255              NaN
# 6879863    FMW00040308 2013-05-01    PRCP      0              NaN
# 6879864    FMW00040504 2013-05-01    TMAX    299              NaN
# 6879865    FMW00040504 2013-05-01    TMIN    239              NaN
# ...                ...        ...     ...    ...              ...
# 173850280  USW00094960 2021-09-30    TMIN    139              NaN
# 173850281  USW00094960 2021-09-30    PRCP      0              NaN
# 173850309  USW00094989 2021-09-30    TMAX    294              NaN
# 173850310  USW00094989 2021-09-30    TMIN    172              NaN
# 173850311  USW00094989 2021-09-30    PRCP    437              NaN
#
#           quality_flag source_flag  time_of_observation
# 6879861            NaN           W               2400.0
# 6879862            NaN           W               2400.0
# 6879863            NaN           W               2400.0
# 6879864            NaN           W               2400.0
# 6879865            NaN           W               2400.0
# ...                ...         ...                  ...
# 173850280          NaN           W               2400.0
# 173850281          NaN           W               2400.0
# 173850309          NaN           W               2400.0
# 173850310          NaN           W               2400.0
# 173850311          NaN           W               2400.0
#
# [3755079 rows x 8 columns]

# %% [markdown]
# # Import Station Data

# %%
station_list = pd.read_csv('source_data/weather/ghcnd-stations.txt', names=['data'], header=None, error_bad_lines=False)
station_list
# Out:
#                                                      data
# 0       ACW00011604  17.1167  -61.7833   10.1    ST JO...
# 1       ACW00011647  17.1333  -61.7833   19.2    ST JO...
# 2       AE000041196  25.3330   55.5170   34.0    SHARJ...
# 3       AEM00041194  25.2550   55.3640   10.4    DUBAI...
# 4       AEM00041217  24.4330   54.6510   26.8    ABU D...
# ...                                                   ...
# 119498  ZI000067969 -21.0500   29.3670  861.0    WEST ...
# 119499  ZI000067975 -20.0670   30.8670 1095.0    MASVI...
# 119500  ZI000067977 -21.0170   31.5830  430.0    BUFFA...
# 119501  ZI000067983 -20.2000   32.6160 1132.0    CHIPI...
# 119502  ZI000067991 -22.2170   30.0000  457.0    BEITB...
#
# [119503 rows x 1 columns]

# %%
station_list["id"] = station_list.data.str[0:11]
station_list["country"] = station_list.data.str[0:2]
station_list["state"] = station_list.data.str[38:40]
station_list["latitude"] = station_list.data.str[12:20]
station_list["longitude"] = station_list.data.str[21:30]

station_list.head(10)
# Out:
#                                                 data           id country  \
# 0  ACW00011604  17.1167  -61.7833   10.1    ST JO...  ACW00011604      AC
# 1  ACW00011647  17.1333  -61.7833   19.2    ST JO...  ACW00011647      AC
# 2  AE000041196  25.3330   55.5170   34.0    SHARJ...  AE000041196      AE
# 3  AEM00041194  25.2550   55.3640   10.4    DUBAI...  AEM00041194      AE
# 4  AEM00041217  24.4330   54.6510   26.8    ABU D...  AEM00041217      AE
# 5  AEM00041218  24.2620   55.6090  264.9    AL AI...  AEM00041218      AE
# 6  AF000040930  35.3170   69.0170 3366.0    NORTH...  AF000040930      AF
# 7  AFM00040938  34.2100   62.2280  977.2    HERAT...  AFM00040938      AF
# 8  AFM00040948  34.5660   69.2120 1791.3    KABUL...  AFM00040948      AF
# 9  AFM00040990  31.5000   65.8500 1010.0    KANDA...  AFM00040990      AF
#
#   state  latitude  longitude
# 0         17.1167   -61.7833
# 1         17.1333   -61.7833
# 2         25.3330    55.5170
# 3         25.2550    55.3640
# 4         24.4330    54.6510
# 5         24.2620    55.6090
# 6         35.3170    69.0170
# 7         34.2100    62.2280
# 8         34.5660    69.2120
# 9         31.5000    65.8500

# %%
us_stations = station_list[station_list.country == "US"]
us_stations = us_stations.drop(["data","country"], axis=1)
us_stations.index = range(len(us_stations))
us_stations
# Out:
#                 id state  latitude  longitude
# 0      US009052008    SD   43.7333   -96.6333
# 1      US10RMHS145    CO   40.5268  -105.1113
# 2      US10adam001    NE   40.5680   -98.5069
# 3      US10adam002    NE   40.5093   -98.5493
# 4      US10adam003    NE   40.4663   -98.6537
# ...            ...   ...       ...        ...
# 66099  USW00096405    AK   60.4731  -145.3542
# 66100  USW00096406    AK   64.5014  -154.1297
# 66101  USW00096407    AK   66.5620  -159.0036
# 66102  USW00096408    AK   63.4519  -150.8747
# 66103  USW00096409    AK   68.6483  -149.3986
#
# [66104 rows x 4 columns]

# %% [markdown]
# # Filter Station List Against Stations in Weather Data

# %%
stations_filtered = us_stations[us_stations.id.isin(station_list_complete)]
stations_filtered
# Out:
#                 id state  latitude  longitude
# 39909  USC00022782    AZ   33.4192  -111.6444
# 40018  USC00025412    AZ   34.1142  -109.8589
# 40156  USC00027855    AZ   34.2639  -110.0075
# 40272  USC00030130    AR   34.7961   -92.8417
# 40477  USC00034625    AR   34.8808   -92.3486
# ...            ...   ...       ...        ...
# 66075  USW00094946    NE   41.4333   -99.6333
# 66076  USW00094949    NE   40.6044   -98.4272
# 66077  USW00094950    SD   43.7667   -98.0333
# 66080  USW00094960    MN   45.0619   -93.3508
# 66090  USW00094989    IA   41.9922   -93.6217
#
# [906 rows x 4 columns]

# %% [markdown]
# # State Abbbreviations

# %%
state_abbrev = pd.read_csv("source_data/weather/ghcnd-states.txt", header=None, names = ["data"])
state_abbrev["code"] = state_abbrev.data.str[:2]
state_abbrev["state"] = state_abbrev.data.str[3:]
state_abbrev["state"] = state_abbrev["state"].str.title()
state_abbrev.drop('data', axis=1, inplace=True)
state_abbrev.head(20)
# Out:
#    code                 state
# 0    AB               Alberta
# 1    AK                Alaska
# 2    AL               Alabama
# 3    AR              Arkansas
# 4    AS        American Samoa
# 5    AZ               Arizona
# 6    BC      British Columbia
# 7    CA            California
# 8    CO              Colorado
# 9    CT           Connecticut
# 10   DC  District Of Columbia
# 11   DE              Delaware
# 12   FL               Florida
# 13   FM            Micronesia
# 14   GA               Georgia
# 15   GU                  Guam
# 16   HI                Hawaii
# 17   IA                  Iowa
# 18   ID                 Idaho
# 19   IL              Illinois

# %%
print(state_abbrev.state.values)
# Out:
# ['Alberta' 'Alaska' 'Alabama' 'Arkansas' 'American Samoa' 'Arizona'
#  'British Columbia' 'California' 'Colorado' 'Connecticut'
#  'District Of Columbia' 'Delaware' 'Florida' 'Micronesia' 'Georgia' 'Guam'
#  'Hawaii' 'Iowa' 'Idaho' 'Illinois' 'Indiana' 'Kansas' 'Kentucky'
#  'Louisiana' 'Massachusetts' 'Manitoba' 'Maryland' 'Maine'
#  'Marshall Islands' 'Michigan' 'Minnesota' 'Missouri'
#  'Northern Mariana Islands' 'Mississippi' 'Montana' 'New Brunswick'
#  'North Carolina' 'North Dakota' 'Nebraska' 'New Hampshire' 'New Jersey'
#  'Newfoundland And Labrador' 'New Mexico' 'Nova Scotia'
#  'Northwest Territories' 'Nunavut' 'Nevada' 'New York' 'Ohio' 'Oklahoma'
#  'Ontario' 'Oregon' 'Pennsylvania' 'Prince Edward Island'
#  'Pacific Islands' 'Puerto Rico' 'Palau' 'Quebec' 'Rhode Island'
#  'South Carolina' 'South Dakota' 'Saskatchewan' 'Tennessee' 'Texas'
#  'U.S. Minor Outlying Islands' 'Utah' 'Virginia' 'Virgin Islands'
#  'Vermont' 'Washington' 'Wisconsin' 'West Virginia' 'Wyoming'
#  'Yukon Territory']

# %%
state_abbrev_dict = {}
for i in state_abbrev.index:
    state_abbrev_dict[state_abbrev.loc[i].code] = state_abbrev.loc[i].state
    
state_abbrev_dict
# Out:
# {'AB': 'Alberta',
#  'AK': 'Alaska',
#  'AL': 'Alabama',
#  'AR': 'Arkansas',
#  'AS': 'American Samoa',
#  'AZ': 'Arizona',
#  'BC': 'British Columbia',
#  'CA': 'California',
#  'CO': 'Colorado',
#  'CT': 'Connecticut',
#  'DC': 'District Of Columbia',
#  'DE': 'Delaware',
#  'FL': 'Florida',
#  'FM': 'Micronesia',
#  'GA': 'Georgia',
#  'GU': 'Guam',
#  'HI': 'Hawaii',
#  'IA': 'Iowa',
#  'ID': 'Idaho',
#  'IL': 'Illinois',
#  'IN': 'Indiana',
#  'KS': 'Kansas',
#  'KY': 'Kentucky',
#  'LA': 'Louisiana',
#  'MA': 'Massachusetts',
#  'MB': 'Manitoba',
#  'MD': 'Maryland',
#  'ME': 'Maine',
#  'MH': 'Marshall Islands',
#  'MI': 'Michigan',
#  'MN': 'Minnesota',
#  'MO': 'Missouri',
#  'MP': 'Northern Mariana Islands',
#  'MS': 'Mississippi',
#  'MT': 'Montana',
#  'NB': 'New Brunswick',
#  'NC': 'North Carolina',
#  'ND': 'North Dakota',
#  'NE': 'Nebraska',
#  'NH': 'New Hampshire',
#  'NJ': 'New Jersey',
#  'NL': 'Newfoundland And Labrador',
#  'NM': 'New Mexico',
#  'NS': 'Nova Scotia',
#  'NT': 'Northwest Territories',
#  'NU': 'Nunavut',
#  'NV': 'Nevada',
#  'NY': 'New York',
#  'OH': 'Ohio',
#  'OK': 'Oklahoma',
#  'ON': 'Ontario',
#  'OR': 'Oregon',
#  'PA': 'Pennsylvania',
#  'PE': 'Prince Edward Island',
#  'PI': 'Pacific Islands',
#  'PR': 'Puerto Rico',
#  'PW': 'Palau',
#  'QC': 'Quebec',
#  'RI': 'Rhode Island',
#  'SC': 'South Carolina',
#  'SD': 'South Dakota',
#  'SK': 'Saskatchewan',
#  'TN': 'Tennessee',
#  'TX': 'Texas',
#  'UM': 'U.S. Minor Outlying Islands',
#  'UT': 'Utah',
#  'VA': 'Virginia',
#  'VI': 'Virgin Islands',
#  'VT': 'Vermont',
#  'WA': 'Washington',
#  'WI': 'Wisconsin',
#  'WV': 'West Virginia',
#  'WY': 'Wyoming',
#  'YT': 'Yukon Territory'}

# %%
for i in range(len(pumpkins_clean)):
    if pumpkins_clean.loc[i].state in state_abbrev.state.values:
        continue
    else:
        print(pumpkins_clean.loc[i].state)
        break

# %% [markdown]
# # City Latitude/Longitude

# %%
cities = pd.read_csv("source_data/uscities/worldcitiespop.csv")
cities
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Country         City   AccentCity Region  Population   Latitude  \
# 0            ad        aixas        Aixàs      6         NaN  42.483333
# 1            ad   aixirivali   Aixirivali      6         NaN  42.466667
# 2            ad   aixirivall   Aixirivall      6         NaN  42.466667
# 3            ad    aixirvall    Aixirvall      6         NaN  42.466667
# 4            ad     aixovall     Aixovall      6         NaN  42.466667
# ...         ...          ...          ...    ...         ...        ...
# 3173953      zw   zimre park   Zimre Park      4         NaN -17.866111
# 3173954      zw  ziyakamanas  Ziyakamanas      0         NaN -18.216667
# 3173955      zw   zizalisari   Zizalisari      4         NaN -17.758889
# 3173956      zw      zuzumba      Zuzumba      6         NaN -20.033333
# 3173957      zw   zvishavane   Zvishavane      7     79876.0 -20.333333
#
#          Longitude
# 0         1.466667
# 1         1.500000
# 2         1.500000
# 3         1.500000
# 4         1.483333
# ...            ...
# 3173953  31.213611
# 3173954  27.950000
# 3173955  31.010556
# 3173956  27.933333
# 3173957  30.033333
#
# [3173958 rows x 7 columns]

# %%
us_cities = cities[cities.Country == "us"]
us_cities.index = range(len(us_cities))
us_cities
# Out:
#        Country           City     AccentCity Region  Population   Latitude  \
# 0           us         abanda         Abanda     AL         NaN  33.100833
# 1           us      abbeville      Abbeville     AL         NaN  31.571667
# 2           us  abbot springs  Abbot Springs     AL         NaN  33.360833
# 3           us           abel           Abel     AL         NaN  33.548611
# 4           us    abercrombie    Abercrombie     AL         NaN  32.848611
# ...        ...            ...            ...    ...         ...        ...
# 141984      us        wyoming        Wyoming     WY         NaN  41.477500
# 141985      us          wyopo          Wyopo     WY         NaN  42.855556
# 141986      us      y-o ranch      Y-O Ranch     WY         NaN  42.030833
# 141987      us        yanceys        Yanceys     WY         NaN  44.930833
# 141988      us          yoder          Yoder     WY         NaN  41.916944
#
#          Longitude
# 0       -85.529722
# 1       -85.250556
# 2       -86.481667
# 3       -85.712500
# 4       -87.165000
# ...            ...
# 141984 -105.636111
# 141985 -108.688611
# 141986 -104.939444
# 141987 -110.435556
# 141988 -104.295278
#
# [141989 rows x 7 columns]

# %%
us_cities.columns
# Out:
# Index(['Country', 'City', 'AccentCity', 'Region', 'Population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
us_cities.columns = ['delete1', 'delete2', 'city', 'state_code', 'delete3', 'latitude',
       'longitude']
us_cities.drop(['delete1','delete2','delete3'], axis=1, inplace=True)
us_cities = us_cities.merge(state_abbrev, how="left", left_on="state_code", right_on="code").drop(["code"],axis=1)
us_cities
# Out:
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                  city state_code   latitude   longitude    state
# 0              Abanda         AL  33.100833  -85.529722  Alabama
# 1           Abbeville         AL  31.571667  -85.250556  Alabama
# 2       Abbot Springs         AL  33.360833  -86.481667  Alabama
# 3                Abel         AL  33.548611  -85.712500  Alabama
# 4         Abercrombie         AL  32.848611  -87.165000  Alabama
# ...               ...        ...        ...         ...      ...
# 141984        Wyoming         WY  41.477500 -105.636111  Wyoming
# 141985          Wyopo         WY  42.855556 -108.688611  Wyoming
# 141986      Y-O Ranch         WY  42.030833 -104.939444  Wyoming
# 141987        Yanceys         WY  44.930833 -110.435556  Wyoming
# 141988          Yoder         WY  41.916944 -104.295278  Wyoming
#
# [141989 rows x 5 columns]

# %%
pumpkin_coord = pumpkins_clean.merge(us_cities, how="left", left_on=["city","state"], right_on=["city","state"])
pumpkin_coord
# Out:
#       year           type  weight_lbs  est_weight    ott         city  \
# 0     2013  Giant Pumpkin      2032.0      2000.0  475.0         Napa
# 1     2013  Giant Pumpkin      1985.0      1809.0  453.0         Napa
# 2     2013  Giant Pumpkin      1894.0      1745.0  445.0         Napa
# 3     2013  Giant Pumpkin      1874.5      1667.0  436.0         Napa
# 4     2013  Giant Pumpkin      1791.0      1619.0  431.0       Sumner
# ...    ...            ...         ...         ...    ...          ...
# 9037  2021  Giant Pumpkin        45.5         0.0    0.0          NaN
# 9038  2021  Giant Pumpkin        30.0         0.0    0.0          NaN
# 9039  2021  Giant Pumpkin        27.0        29.0  100.0     Laveland
# 9040  2021  Giant Pumpkin        25.0         0.0    0.0   Sacramento
# 9041  2021  Giant Pumpkin         1.0         0.0   39.0  Hodgenville
#
#               state state_code   latitude   longitude
# 0        California         CA  38.297222 -122.284444
# 1        California         CA  38.297222 -122.284444
# 2        California         CA  38.297222 -122.284444
# 3        California         CA  38.297222 -122.284444
# 4        Washington         WA  47.203333 -122.239167
# ...             ...        ...        ...         ...
# 9037  West Virginia        NaN        NaN         NaN
# 9038           Ohio        NaN        NaN         NaN
# 9039       Colorado        NaN        NaN         NaN
# 9040     California         CA  38.581667 -121.493333
# 9041       Kentucky         KY  37.573889  -85.740000
#
# [9042 rows x 10 columns]

# %%
pumpkin_filtered = pumpkin_coord.dropna(subset=['latitude', 'longitude'])
pumpkin_filtered.index = range(len(pumpkin_filtered))
print(f"{len(pumpkin_coord) - len(pumpkin_filtered)} pumpkins omitted due to failure to match city")
# Out:
# 1365 pumpkins omitted due to failure to match city

# %%
pumpkin_filtered
# Out:
#       year           type  weight_lbs  est_weight    ott         city  \
# 0     2013  Giant Pumpkin      2032.0      2000.0  475.0         Napa
# 1     2013  Giant Pumpkin      1985.0      1809.0  453.0         Napa
# 2     2013  Giant Pumpkin      1894.0      1745.0  445.0         Napa
# 3     2013  Giant Pumpkin      1874.5      1667.0  436.0         Napa
# 4     2013  Giant Pumpkin      1791.0      1619.0  431.0       Sumner
# ...    ...            ...         ...         ...    ...          ...
# 7672  2021  Giant Pumpkin        50.0         0.0    0.0  Southington
# 7673  2021  Giant Pumpkin        50.0        59.0  132.0     Loveland
# 7674  2021  Giant Pumpkin        47.0         0.0    0.0     San Jose
# 7675  2021  Giant Pumpkin        25.0         0.0    0.0   Sacramento
# 7676  2021  Giant Pumpkin         1.0         0.0   39.0  Hodgenville
#
#             state state_code   latitude   longitude
# 0      California         CA  38.297222 -122.284444
# 1      California         CA  38.297222 -122.284444
# 2      California         CA  38.297222 -122.284444
# 3      California         CA  38.297222 -122.284444
# 4      Washington         WA  47.203333 -122.239167
# ...           ...        ...        ...         ...
# 7672  Connecticut         CT  41.596389  -72.878056
# 7673     Colorado         CO  40.397778 -105.074444
# 7674   California         CA  37.339444 -121.893889
# 7675   California         CA  38.581667 -121.493333
# 7676     Kentucky         KY  37.573889  -85.740000
#
# [7677 rows x 10 columns]

# %%
pumpkin_filtered.isna().sum()
# Out:
# year          0
# type          0
# weight_lbs    0
# est_weight    1
# ott           0
# city          0
# state         0
# state_code    0
# latitude      0
# longitude     0
# dtype: int64

# %% [markdown]
# # Calculate Nearest Station to Each Pumpkin

# %%
def distance(lat_a, long_a, lat_b, long_b):
    return ((float(lat_b) - float(lat_a))**2 + (float(long_b) - float(long_a))**2)**.5

# %%
stations_filtered.head(5)
# Out:
#                 id state  latitude  longitude
# 39909  USC00022782    AZ   33.4192  -111.6444
# 40018  USC00025412    AZ   34.1142  -109.8589
# 40156  USC00027855    AZ   34.2639  -110.0075
# 40272  USC00030130    AR   34.7961   -92.8417
# 40477  USC00034625    AR   34.8808   -92.3486

# %%
pumpkin_filtered.head(5)
# Out:
#    year           type  weight_lbs  est_weight    ott    city       state  \
# 0  2013  Giant Pumpkin      2032.0      2000.0  475.0    Napa  California
# 1  2013  Giant Pumpkin      1985.0      1809.0  453.0    Napa  California
# 2  2013  Giant Pumpkin      1894.0      1745.0  445.0    Napa  California
# 3  2013  Giant Pumpkin      1874.5      1667.0  436.0    Napa  California
# 4  2013  Giant Pumpkin      1791.0      1619.0  431.0  Sumner  Washington
#
#   state_code   latitude   longitude
# 0         CA  38.297222 -122.284444
# 1         CA  38.297222 -122.284444
# 2         CA  38.297222 -122.284444
# 3         CA  38.297222 -122.284444
# 4         WA  47.203333 -122.239167

# %%
pumpkin_filtered["nearest_station"] = ""
for i in range(len(pumpkin_filtered)):
    
    state_stations = stations_filtered[stations_filtered.state == pumpkin_filtered.loc[i,"state_code"]]
    
    pumpkin_lat = pumpkin_filtered.loc[i,"latitude"]
    pumpkin_long = pumpkin_filtered.loc[i,"longitude"]
    
    closest_distance = 1000000000000000000.0
    nearest_station = ""
    
    for index, row in state_stations.iterrows():
        check = distance(pumpkin_lat, pumpkin_long, row["latitude"], row["longitude"])
        if check < closest_distance:
            closest_distance = check
            nearest_station = row["id"]
    
    pumpkin_filtered.loc[i, "nearest_station"] = nearest_station
    print(pumpkin_filtered.loc[i, "nearest_station"])
    print(closest_distance)
    print(f"{i+1} pumpkins located. {len(pumpkin_filtered) - (i+1)} left. {(i+1)/len(pumpkin_filtered)*100:.0f}% done.\n")
# Out:
# USW00093241
# 0.33665585672048093
# 1 pumpkins located. 7676 left. 0% done.
#
# USW00093241
# 0.33665585672048093
# 2 pumpkins located. 7675 left. 0% done.
# <ipython-input-69-5b81b6a364fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pumpkin_filtered["nearest_station"] = ""
# /Users/ericellestad/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# USW00093241
# 0.33665585672048093
# 3 pumpkins located. 7674 left. 0% done.
#
# USW00093241
# 0.33665585672048093
# 4 pumpkins located. 7673 left. 0% done.
#
# USW00024233
# 0.25238506290544027
# 5 pumpkins located. 7672 left. 0% done.
#
# USC00058022
# 0.36968572392249816
# 6 pumpkins located. 7671 left. 0% done.
#
# USW00014991
# 1.0795419298084712
# 7 pumpkins located. 7670 left. 0% done.
#
# USC00214861
# 0.9140779132884306
# 8 pumpkins located. 7669 left. 0% done.
#
# USW00014740
# 0.27670446636380436
# 9 pumpkins located. 7668 left. 0% done.
#
# USC00193276
# 0.14311146005823203
# 10 pumpkins located. 7667 left. 0% done.
#
# USW00014711
# 0.32227408525074674
# 11 pumpkins located. 7666 left. 0% done.
#
# USW00014926
# 0.4750917744817795
# 12 pumpkins located. 7665 left. 0% done.
#
# USW00014711
# 0.32227408525074674
# 13 pumpkins located. 7664 left. 0% done.
#
# USW00024233
# 0.25238506290544027
# 14 pumpkins located. 7663 left. 0% done.
#
# USC00368361
# 0.29377226917469174
# 15 pumpkins located. 7662 left. 0% done.
#
# USW00093241
# 0.33665585672048093
# 16 pumpkins located. 7661 left. 0% done.
#
# USW00093241
# 0.33665585672048093
# 17 pumpkins located. 7660 left. 0% done.
#
# USC00473058
# 0.06021719535191382
# 18 pumpkins located. 7659 left. 0% done.
#
# USW00093241
# 0.33665585672048093
# 19 pumpkins located. 7658 left. 0% done.
#
# USW00093241
# 0.33665585672048093
# 20 pumpkins located. 7657 left. 0% done.
#
# USC00043578
# 0.15169374357648763
# 21 pumpkins located. 7656 left. 0% done.
#
# USC00451276
# 0.058633016856372344
# 22 pumpkins located. 7655 left. 0% done.
#
# USW00094860
# 0.14155418467939804
# 23 pumpkins located. 7654 left. 0% done.
#
# USC00043578
# 0.15169374357648763
# 24 pumpkins located. 7653 left. 0% done.
#
# USW00004725
# 0.3657781797179567
# 25 pumpkins located. 7652 left. 0% done.
#
# USC00304102
# 0.5390949879671966
# 26 pumpkins located. 7651 left. 0% done.
#
# USW00094846
# 0.49277149638436807
# 27 pumpkins located. 7650 left. 0% done.
#
# USW00014991
# 1.0795419298084712
# 28 pumpkins located. 7649 left. 0% done.
#
# USC00193276
# 0.4019030892751348
# 29 pumpkins located. 7648 left. 0% done.
#
# USC00058022
# 0.36968572392249816
# 30 pumpkins located. 7647 left. 0% done.
#
# USC00331458
# 0.1490026303935672
# 31 pumpkins located. 7646 left. 0% done.
#
# USW00014742
# 0.7712461012621757
# 32 pumpkins located. 7645 left. 0% done.
#
# USW00014991
# 0.20314235875427497
# 33 pumpkins located. 7644 left. 0% done.
#
# USW00014898
# 0.21981309791009385
# 34 pumpkins located. 7643 left. 0% done.
#
# USC00043578
# 0.15169374357648763
# 35 pumpkins located. 7642 left. 0% done.
#
# USW00023272
# 0.4870135046957637
# 36 pumpkins located. 7641 left. 0% done.
#
# USC00304102
# 0.5390949879671966
# 37 pumpkins located. 7640 left. 0% done.
#
# USW00014926
# 0.4750917744817795
# 38 pumpkins located. 7639 left. 0% done.
#
# USW00093241
# 0.33665585672048093
# 39 pumpkins located. 7638 left. 1% done.
#
# USW00094823
# 0.44258225145805813
# 40 pumpkins located. 7637 left. 1% done.
#
# USC00368361
# 0.29377226917469174
# 41 pumpkins located. 7636 left. 1% done.
#
# USC00331458
# 0.1490026303935672
# 42 pumpkins located. 7635 left. 1% done.
#
# USC00331458
# 0.1490026303935672
# 43 pumpkins located. 7634 left. 1% done.
#
# USC00364325
# 0.5251114453675995
# 44 pumpkins located. 7633 left. 1% done.
#
# USC00301625
# 0.4059094580431583
# 45 pumpkins located. 7632 left. 1% done.
#
# USC00058995
# 0.04120353106347237
# 46 pumpkins located. 7631 left. 1% done.
#
# USW00014733
# 0.11689185987143282
# 47 pumpkins located. 7630 left. 1% done.
#
# USC00470265
# 0.1658596257764986
# 48 pumpkins located. 7629 left. 1% done.
#
# USW00093824
# 0.7168638049310733
# 49 pumpkins located. 7628 left. 1% done.
#
# USC00451276
# 0.058633016856372344
# 50 pumpkins located. 7627 left. 1% done.
#
# USC00301625
# 0.4059094580431583
# 51 pumpkins located. 7626 left. 1% done.
#
# USC00043578
# 0.12666211503713315
# 52 pumpkins located. 7625 left. 1% done.
#
# USC00274234
# 0.570646923572902
# 53 pumpkins located. 7624 left. 1% done.
#
# USC00336405
# 0.6963586659445337
# 54 pumpkins located. 7623 left. 1% done.
#
# USW00014926
# 0.4750917744817795
# 55 pumpkins located. 7622 left. 1% done.
#
# USW00024233
# 0.25238506290544027
# 56 pumpkins located. 7621 left. 1% done.
#
# USC00193276
# 0.21188383845347641
# 57 pumpkins located. 7620 left. 1% done.
#
# USW00014852
# 0.6528741616968414
# 58 pumpkins located. 7619 left. 1% done.
#
# USC00362470
# 0.19779341116490703
# 59 pumpkins located. 7618 left. 1% done.
#
# USW00094860
# 0.14155418467939804
# 60 pumpkins located. 7617 left. 1% done.
#
# USW00014765
# 0.2175443993802931
# 61 pumpkins located. 7616 left. 1% done.
#
# USC00360656
# 0.10645045209908159
# 62 pumpkins located. 7615 left. 1% done.
#
# USW00024232
# 0.28764617192261016
# 63 pumpkins located. 7614 left. 1% done.
#
# USW00014852
# 0.3666272875520559
# 64 pumpkins located. 7613 left. 1% done.
#
# USC00336405
# 0.6963586659445337
# 65 pumpkins located. 7612 left. 1% done.
#
# USC00274234
# 0.570646923572902
# 66 pumpkins located. 7611 left. 1% done.
#
# USC00274234
# 0.570646923572902
# 67 pumpkins located. 7610 left. 1% done.
#
# USC00301625
# 0.4059094580431583
# 68 pumpkins located. 7609 left. 1% done.
#
# USW00094860
# 0.14155418467939804
# 69 pumpkins located. 7608 left. 1% done.
#
# USW00014711
# 0.32227408525074674
# 70 pumpkins located. 7607 left. 1% done.
#
# USW00093241
# 0.33665585672048093
# 71 pumpkins located. 7606 left. 1% done.
#
# USW00094823
# 0.44258225145805813
# 72 pumpkins located. 7605 left. 1% done.
#
# USW00014991
# 1.0795419298084712
# 73 pumpkins located. 7604 left. 1% done.
#
# USW00093241
# 0.33665585672048093
# 74 pumpkins located. 7603 left. 1% done.
#
# USW00014826
# 0.40204511520998554
# 75 pumpkins located. 7602 left. 1% done.
#
# USW00093241
# 0.33665585672048093
# 76 pumpkins located. 7601 left. 1% done.
#
# USC00368361
# 0.29377226917469174
# 77 pumpkins located. 7600 left. 1% done.
#
# USW00024232
# 0.05023286428793387
# 78 pumpkins located. 7599 left. 1% done.
#
# USC00043578
# 0.15169374357648763
# 79 pumpkins located. 7598 left. 1% done.
#
# USW00014991
# 1.0795419298084712
# 80 pumpkins located. 7597 left. 1% done.
#
# USW00004725
# 0.3657781797179567
# 81 pumpkins located. 7596 left. 1% done.
#
# USW00014991
# 1.0795419298084712
# 82 pumpkins located. 7595 left. 1% done.
#
# USW00004725
# 1.0680049623481171
# 83 pumpkins located. 7594 left. 1% done.
#
# USW00014742
# 0.7712461012621757
# 84 pumpkins located. 7593 left. 1% done.
#
# USW00024233
# 0.25979750391458917
# 85 pumpkins located. 7592 left. 1% done.
#
# USC00043578
# 0.15169374357648763
# 86 pumpkins located. 7591 left. 1% done.
#
# USC00470265
# 0.12412761464629317
# 87 pumpkins located. 7590 left. 1% done.
#
# USW00014852
# 0.31544055572492846
# 88 pumpkins located. 7589 left. 1% done.
#
# USC00043578
# 0.15169374357648763
# 89 pumpkins located. 7588 left. 1% done.
#
# USW00014895
# 0.14905256380813459
# 90 pumpkins located. 7587 left. 1% done.
#
# USW00014826
# 0.21291190493771395
# 91 pumpkins located. 7586 left. 1% done.
#
# USC00331458
# 0.1490026303935672
# 92 pumpkins located. 7585 left. 1% done.
#
# USC00043578
# 0.15169374357648763
# 93 pumpkins located. 7584 left. 1% done.
#
# USW00014842
# 0.9621178302171329
# 94 pumpkins located. 7583 left. 1% done.
#
# USW00014826
# 0.21291190493771395
# 95 pumpkins located. 7582 left. 1% done.
#
# USW00024232
# 0.28764617192261016
# 96 pumpkins located. 7581 left. 1% done.
#
# USC00470265
# 0.1658596257764986
# 97 pumpkins located. 7580 left. 1% done.
#
# USW00024233
# 0.16203287016171083
# 98 pumpkins located. 7579 left. 1% done.
#
# USC00193276
# 0.21188383845347641
# 99 pumpkins located. 7578 left. 1% done.
#
# USW00014742
# 0.7712461012621757
# 100 pumpkins located. 7577 left. 1% done.
#
# USC00274234
# 0.5838754565248344
# 101 pumpkins located. 7576 left. 1% done.
#
# USC00198757
# 0.07657075768267896
# 102 pumpkins located. 7575 left. 1% done.
#
# USC00360656
# 0.10645045209908159
# 103 pumpkins located. 7574 left. 1% done.
#
# USC00214861
# 0.9140779132884306
# 104 pumpkins located. 7573 left. 1% done.
#
# USC00301625
# 0.7601545248847208
# 105 pumpkins located. 7572 left. 1% done.
#
# USW00094702
# 0.13635445871734617
# 106 pumpkins located. 7571 left. 1% done.
#
# USW00054789
# 0.45397767572621145
# 107 pumpkins located. 7570 left. 1% done.
#
# USW00014742
# 0.1758397026889305
# 108 pumpkins located. 7569 left. 1% done.
#
# USC00356750
# 0.155908235772618
# 109 pumpkins located. 7568 left. 1% done.
#
# USC00333780
# 0.29024797677883196
# 110 pumpkins located. 7567 left. 1% done.
#
# USW00023271
# 0.3282243386187703
# 111 pumpkins located. 7566 left. 1% done.
#
# USW00024232
# 0.28764617192261016
# 112 pumpkins located. 7565 left. 1% done.
#
# USW00014605
# 0.36251367546653057
# 113 pumpkins located. 7564 left. 1% done.
#
# USW00093241
# 0.33665585672048093
# 114 pumpkins located. 7563 left. 1% done.
#
# USC00193276
# 0.21188383845347641
# 115 pumpkins located. 7562 left. 1% done.
#
# USW00014733
# 0.11689185987143282
# 116 pumpkins located. 7561 left. 2% done.
#
# USW00023271
# 0.3282243386187703
# 117 pumpkins located. 7560 left. 2% done.
#
# USC00475120
# 0.3327981256583814
# 118 pumpkins located. 7559 left. 2% done.
#
# USC00458773
# 0.039978815841018346
# 119 pumpkins located. 7558 left. 2% done.
#
# USC00368361
# 0.29377226917469174
# 120 pumpkins located. 7557 left. 2% done.
#
# USW00093241
# 0.33665585672048093
# 121 pumpkins located. 7556 left. 2% done.
#
# USW00024233
# 0.25979750391458917
# 122 pumpkins located. 7555 left. 2% done.
#
# USW00024232
# 0.31506458198318854
# 123 pumpkins located. 7554 left. 2% done.
#
# USC00364325
# 0.584632665030147
# 124 pumpkins located. 7553 left. 2% done.
#
# USC00210075
# 0.3329553199759014
# 125 pumpkins located. 7552 left. 2% done.
#
# USC00301625
# 0.7601545248847208
# 126 pumpkins located. 7551 left. 2% done.
#
# USC00331458
# 0.1490026303935672
# 127 pumpkins located. 7550 left. 2% done.
#
# USW00094847
# 0.5743991018051637
# 128 pumpkins located. 7549 left. 2% done.
#
# USW00014926
# 0.4750917744817795
# 129 pumpkins located. 7548 left. 2% done.
#
# USC00303087
# 0.22282653830466195
# 130 pumpkins located. 7547 left. 2% done.
#
# USW00014925
# 0.27647862636698567
# 131 pumpkins located. 7546 left. 2% done.
#
# USC00060227
# 0.22465775271416516
# 132 pumpkins located. 7545 left. 2% done.
#
# USW00094823
# 0.44258225145805813
# 133 pumpkins located. 7544 left. 2% done.
#
# USW00004725
# 0.3657781797179567
# 134 pumpkins located. 7543 left. 2% done.
#
# USC00274234
# 0.5690664815166002
# 135 pumpkins located. 7542 left. 2% done.
#
# USW00014737
# 0.23503297832485018
# 136 pumpkins located. 7541 left. 2% done.
#
# USW00014852
# 0.17769674431944932
# 137 pumpkins located. 7540 left. 2% done.
#
# USC00043578
# 0.12666211503713315
# 138 pumpkins located. 7539 left. 2% done.
#
# USW00024233
# 0.36058703745112664
# 139 pumpkins located. 7538 left. 2% done.
#
# USW00024227
# 0.06487028119810126
# 140 pumpkins located. 7537 left. 2% done.
#
# USC00331458
# 0.1490026303935672
# 141 pumpkins located. 7536 left. 2% done.
#
# USW00014837
# 0.2574562854237602
# 142 pumpkins located. 7535 left. 2% done.
#
# USC00301625
# 0.2790509237256001
# 143 pumpkins located. 7534 left. 2% done.
#
# USW00014837
# 0.24017125090287392
# 144 pumpkins located. 7533 left. 2% done.
#
# USW00024213
# 0.5665742892156769
# 145 pumpkins located. 7532 left. 2% done.
#
# USC00331458
# 0.1490026303935672
# 146 pumpkins located. 7531 left. 2% done.
#
# USC00200228
# 0.5767944117124634
# 147 pumpkins located. 7530 left. 2% done.
#
# USW00014742
# 0.7783305670088075
# 148 pumpkins located. 7529 left. 2% done.
#
# USW00024127
# 0.11468853135427404
# 149 pumpkins located. 7528 left. 2% done.
# USW00014925
# 0.5898571368053798
# 150 pumpkins located. 7527 left. 2% done.
#
# USW00026491
# 0.07725668452758978
# 151 pumpkins located. 7526 left. 2% done.
#
# USW00014733
# 0.11689185987143282
# 152 pumpkins located. 7525 left. 2% done.
#
# USW00014852
# 0.17769674431944932
# 153 pumpkins located. 7524 left. 2% done.
#
# USW00093241
# 0.33665585672048093
# 154 pumpkins located. 7523 left. 2% done.
#
# USC00193276
# 0.14311146005823203
# 155 pumpkins located. 7522 left. 2% done.
#
# USW00014837
# 0.2574562854237602
# 156 pumpkins located. 7521 left. 2% done.
#
# USC00339220
# 0.6856642710424675
# 157 pumpkins located. 7520 left. 2% done.
#
# USW00024137
# 0.5283611128537353
# 158 pumpkins located. 7519 left. 2% done.
#
# USW00024227
# 0.03452905633462517
# 159 pumpkins located. 7518 left. 2% done.
#
# USS0021B50S
# 0.21032476284118318
# 160 pumpkins located. 7517 left. 2% done.
#
# USC00193276
# 0.21188383845347641
# 161 pumpkins located. 7516 left. 2% done.
#
# USW00024232
# 0.28764617192261016
# 162 pumpkins located. 7515 left. 2% done.
#
# USC00364325
# 0.584632665030147
# 163 pumpkins located. 7514 left. 2% done.
#
# USW00024232
# 0.05023286428793387
# 164 pumpkins located. 7513 left. 2% done.
#
# USC00304174
# 0.12099942774480944
# 165 pumpkins located. 7512 left. 2% done.
#
# USC00214861
# 0.9140779132884306
# 166 pumpkins located. 7511 left. 2% done.
#
# USW00094847
# 0.14049111991357052
# 167 pumpkins located. 7510 left. 2% done.
#
# USC00190190
# 1.2487830807070746
# 168 pumpkins located. 7509 left. 2% done.
#
# USC00437054
# 1.2136124469622571
# 169 pumpkins located. 7508 left. 2% done.
#
# USC00465963
# 0.6092147822454952
# 170 pumpkins located. 7507 left. 2% done.
#
# USC00477113
# 0.29327609733222393
# 171 pumpkins located. 7506 left. 2% done.
#
# USC00473058
# 0.06021719535191382
# 172 pumpkins located. 7505 left. 2% done.
#
# USC00364325
# 0.5251114453675995
# 173 pumpkins located. 7504 left. 2% done.
#
# USW00093819
# 0.5167007780634342
# 174 pumpkins located. 7503 left. 2% done.
#
# USC00301625
# 0.2790509237256001
# 175 pumpkins located. 7502 left. 2% done.
#
# USC00336405
# 0.6963586659445337
# 176 pumpkins located. 7501 left. 2% done.
#
# USS0011H21S
# 0.5260090323005167
# 177 pumpkins located. 7500 left. 2% done.
#
# USC00203823
# 0.5566522367719414
# 178 pumpkins located. 7499 left. 2% done.
#
# USW00023272
# 0.30698948633985856
# 179 pumpkins located. 7498 left. 2% done.
#
# USW00014711
# 0.32227408525074674
# 180 pumpkins located. 7497 left. 2% done.
#
# USW00054789
# 0.45397767572621145
# 181 pumpkins located. 7496 left. 2% done.
#
# USC00304102
# 0.5390949879671966
# 182 pumpkins located. 7495 left. 2% done.
#
# USC00211448
# 0.07099520619533965
# 183 pumpkins located. 7494 left. 2% done.
#
# USW00093241
# 0.33665585672048093
# 184 pumpkins located. 7493 left. 2% done.
#
# USC00173862
# 0.1558591218511122
# 185 pumpkins located. 7492 left. 2% done.
#
# USW00014852
# 0.6528741616968414
# 186 pumpkins located. 7491 left. 2% done.
#
# USC00200228
# 0.2864525917943177
# 187 pumpkins located. 7490 left. 2% done.
#
# USW00094290
# 0.0481192000026066
# 188 pumpkins located. 7489 left. 2% done.
#
# USW00024233
# 0.16203287016171083
# 189 pumpkins located. 7488 left. 2% done.
#
# USS0021B50S
# 0.21032476284118318
# 190 pumpkins located. 7487 left. 2% done.
#
# USW00014740
# 0.7734006534076434
# 191 pumpkins located. 7486 left. 2% done.
#
# USW00093241
# 0.33665585672048093
# 192 pumpkins located. 7485 left. 3% done.
#
# USC00201675
# 0.6214819113152857
# 193 pumpkins located. 7484 left. 3% done.
#
# USC00473058
# 0.06021719535191382
# 194 pumpkins located. 7483 left. 3% done.
#
# USC00274234
# 0.5690664815166002
# 195 pumpkins located. 7482 left. 3% done.
#
# USW00014852
# 0.24541828775217128
# 196 pumpkins located. 7481 left. 3% done.
#
# USW00014737
# 0.23503297832485018
# 197 pumpkins located. 7480 left. 3% done.
#
# USW00014991
# 1.0795419298084712
# 198 pumpkins located. 7479 left. 3% done.
#
# USW00024217
# 0.29074676991507337
# 199 pumpkins located. 7478 left. 3% done.
#
# USC00471604
# 0.43411898401614446
# 200 pumpkins located. 7477 left. 3% done.
#
# USW00014826
# 0.6016371885900785
# 201 pumpkins located. 7476 left. 3% done.
#
# USW00014991
# 1.0795419298084712
# 202 pumpkins located. 7475 left. 3% done.
#
# USC00481676
# 0.017957013472177208
# 203 pumpkins located. 7474 left. 3% done.
#
# USW00023272
# 0.30698948633985856
# 204 pumpkins located. 7473 left. 3% done.
#
# USC00211448
# 0.063960503283265
# 205 pumpkins located. 7472 left. 3% done.
#
# USC00475120
# 0.3327981256583814
# 206 pumpkins located. 7471 left. 3% done.
#
# USC00131635
# 0.09023815043854808
# 207 pumpkins located. 7470 left. 3% done.
#
# USW00014837
# 0.2574562854237602
# 208 pumpkins located. 7469 left. 3% done.
#
# USW00093241
# 0.43698295185973507
# 209 pumpkins located. 7468 left. 3% done.
#
# USC00173570
# 0.2795511769892035
# 210 pumpkins located. 7467 left. 3% done.
#
# USC00301625
# 0.4059094580431583
# 211 pumpkins located. 7466 left. 3% done.
#
# USW00024227
# 0.06487028119810126
# 212 pumpkins located. 7465 left. 3% done.
#
# USW00023271
# 0.20428142728314477
# 213 pumpkins located. 7464 left. 3% done.
#
# USW00023272
# 1.3382630588879678
# 214 pumpkins located. 7463 left. 3% done.
#
# USW00023272
# 0.6855625311629744
# 215 pumpkins located. 7462 left. 3% done.
#
# USW00024232
# 0.28764617192261016
# 216 pumpkins located. 7461 left. 3% done.
#
# USW00014925
# 0.27647862636698567
# 217 pumpkins located. 7460 left. 3% done.
#
# USW00003889
# 0.5465696827306292
# 218 pumpkins located. 7459 left. 3% done.
#
# USC00272800
# 0.572524412267053
# 219 pumpkins located. 7458 left. 3% done.
#
# USW00093241
# 0.33665585672048093
# 220 pumpkins located. 7457 left. 3% done.
#
# USW00024233
# 0.25238506290544027
# 221 pumpkins located. 7456 left. 3% done.
#
# USC00487760
# 0.007536973620760556
# 222 pumpkins located. 7455 left. 3% done.
#
# USC00360868
# 0.09091672210204249
# 223 pumpkins located. 7454 left. 3% done.
#
# USW00093241
# 0.43698295185973507
# 224 pumpkins located. 7453 left. 3% done.
#
# USW00024232
# 0.05023286428793387
# 225 pumpkins located. 7452 left. 3% done.
#
# USW00023272
# 0.6855625311629744
# 226 pumpkins located. 7451 left. 3% done.
#
# USC00364325
# 0.2665598779488422
# 227 pumpkins located. 7450 left. 3% done.
#
# USS0011J21S
# 0.1828657887396083
# 228 pumpkins located. 7449 left. 3% done.
#
# USC00173862
# 0.23097030341958058
# 229 pumpkins located. 7448 left. 3% done.
#
# USS0011J11S
# 0.555522928730827
# 230 pumpkins located. 7447 left. 3% done.
#
# USW00014860
# 0.1089473293005888
# 231 pumpkins located. 7446 left. 3% done.
#
# USC00360868
# 0.09091672210204249
# 232 pumpkins located. 7445 left. 3% done.
#
# USC00470265
# 0.5990954370697442
# 233 pumpkins located. 7444 left. 3% done.
#
# USC00300443
# 0.37426168783716235
# 234 pumpkins located. 7443 left. 3% done.
#
# USC00098740
# 0.6934922739094271
# 235 pumpkins located. 7442 left. 3% done.
#
# USW00014827
# 0.17774634903302627
# 236 pumpkins located. 7441 left. 3% done.
#
# USC00046506
# 0.6848815446163393
# 237 pumpkins located. 7440 left. 3% done.
#
# USS0023G09S
# 0.22238761206506316
# 238 pumpkins located. 7439 left. 3% done.
#
# USW00024232
# 0.38045389210490926
# 239 pumpkins located. 7438 left. 3% done.
#
# USC00274234
# 0.3014944679123243
# 240 pumpkins located. 7437 left. 3% done.
#
# USW00094281
# 0.07855264689728711
# 241 pumpkins located. 7436 left. 3% done.
#
# USC00193624
# 0.2467476919286177
# 242 pumpkins located. 7435 left. 3% done.
#
# USC00135086
# 0.8946590639792565
# 243 pumpkins located. 7434 left. 3% done.
#
# USW00014852
# 0.10427593611231571
# 244 pumpkins located. 7433 left. 3% done.
#
# USW00014826
# 0.6016371885900785
# 245 pumpkins located. 7432 left. 3% done.
#
# USW00003889
# 0.5465696827306292
# 246 pumpkins located. 7431 left. 3% done.
#
# USC00356750
# 0.155908235772618
# 247 pumpkins located. 7430 left. 3% done.
#
# USC00058995
# 0.1419873672358401
# 248 pumpkins located. 7429 left. 3% done.
#
# USC00355681
# 0.20653357270148864
# 249 pumpkins located. 7428 left. 3% done.
#
# USC00473058
# 0.06021719535191382
# 250 pumpkins located. 7427 left. 3% done.
#
# USC00193276
# 0.21188383845347641
# 251 pumpkins located. 7426 left. 3% done.
#
# USW00014852
# 0.24541828775217128
# 252 pumpkins located. 7425 left. 3% done.
#
# USC00200228
# 0.36304425637437915
# 253 pumpkins located. 7424 left. 3% done.
#
# USW00093812
# 0.06990380549527309
# 254 pumpkins located. 7423 left. 3% done.
#
# USW00014735
# 0.6447059765383027
# 255 pumpkins located. 7422 left. 3% done.
#
# USW00024217
# 0.29074676991507337
# 256 pumpkins located. 7421 left. 3% done.
#
# USW00094702
# 0.09624788841423688
# 257 pumpkins located. 7420 left. 3% done.
#
# USW00023232
# 0.31945767537508496
# 258 pumpkins located. 7419 left. 3% done.
#
# USW00023232
# 0.31945767537508496
# 259 pumpkins located. 7418 left. 3% done.
#
# USW00094846
# 0.3808460673439594
# 260 pumpkins located. 7417 left. 3% done.
# USC00355681
# 0.20653357270148864
# 261 pumpkins located. 7416 left. 3% done.
#
# USW00024233
# 0.25979750391458917
# 262 pumpkins located. 7415 left. 3% done.
#
# USC00201675
# 0.6214819113152857
# 263 pumpkins located. 7414 left. 3% done.
#
# USW00014837
# 0.24017125090287392
# 264 pumpkins located. 7413 left. 3% done.
#
# USC00200228
# 0.15679459382529817
# 265 pumpkins located. 7412 left. 3% done.
#
# USC00274234
# 0.5690664815166002
# 266 pumpkins located. 7411 left. 3% done.
#
# USW00014739
# 0.14393000521173444
# 267 pumpkins located. 7410 left. 3% done.
#
# USW00023271
# 0.6178571937108623
# 268 pumpkins located. 7409 left. 3% done.
#
# USW00023271
# 0.6922320234287528
# 269 pumpkins located. 7408 left. 4% done.
#
# USW00023271
# 0.4823411528138342
# 270 pumpkins located. 7407 left. 4% done.
#
# USW00094176
# 0.10639143463272849
# 271 pumpkins located. 7406 left. 4% done.
#
# USW00094176
# 0.10639143463272849
# 272 pumpkins located. 7405 left. 4% done.
#
# USC00244558
# 0.6189477063016193
# 273 pumpkins located. 7404 left. 4% done.
#
# USW00094860
# 0.14155418467939804
# 274 pumpkins located. 7403 left. 4% done.
#
# USW00094908
# 0.3265508554820348
# 275 pumpkins located. 7402 left. 4% done.
#
# USW00004725
# 1.0680049623481171
# 276 pumpkins located. 7401 left. 4% done.
#
# USW00094846
# 0.037739548964560395
# 277 pumpkins located. 7400 left. 4% done.
#
# USC00473058
# 0.015748025782639438
# 278 pumpkins located. 7399 left. 4% done.
#
# USC00301625
# 0.49926265802854813
# 279 pumpkins located. 7398 left. 4% done.
#
# USC00173862
# 0.23097030341958058
# 280 pumpkins located. 7397 left. 4% done.
#
# USC00123078
# 0.7640797840357236
# 281 pumpkins located. 7396 left. 4% done.
#
# USC00203823
# 0.25527124888325997
# 282 pumpkins located. 7395 left. 4% done.
#
# USW00093820
# 0.4222680349999497
# 283 pumpkins located. 7394 left. 4% done.
#
# USC00363417
# 0.23211988574021042
# 284 pumpkins located. 7393 left. 4% done.
#
# USC00044500
# 0.29037971701095394
# 285 pumpkins located. 7392 left. 4% done.
#
# USW00014821
# 0.39626365565689203
# 286 pumpkins located. 7391 left. 4% done.
#
# USC00185934
# 2.622723098534075
# 287 pumpkins located. 7390 left. 4% done.
#
# USC00173862
# 0.23097030341958058
# 288 pumpkins located. 7389 left. 4% done.
#
# USC00215400
# 1.1708454600092186
# 289 pumpkins located. 7388 left. 4% done.
#
# USW00093812
# 0.06990380549527309
# 290 pumpkins located. 7387 left. 4% done.
#
# USC00481676
# 0.017957013472177208
# 291 pumpkins located. 7386 left. 4% done.
#
# USC00458773
# 0.039978815841018346
# 292 pumpkins located. 7385 left. 4% done.
#
# USW00094860
# 0.14155418467939804
# 293 pumpkins located. 7384 left. 4% done.
#
# USW00023272
# 0.6236557362361516
# 294 pumpkins located. 7383 left. 4% done.
#
# USW00094830
# 0.1208431639679345
# 295 pumpkins located. 7382 left. 4% done.
#
# USW00003856
# 0.47268946956331764
# 296 pumpkins located. 7381 left. 4% done.
#
# USW00024233
# 0.16203287016171083
# 297 pumpkins located. 7380 left. 4% done.
#
# USC00331785
# 0.25498785881723984
# 298 pumpkins located. 7379 left. 4% done.
#
# USC00058995
# 0.04120353106347237
# 299 pumpkins located. 7378 left. 4% done.
#
# USW00023232
# 0.5862372947072552
# 300 pumpkins located. 7377 left. 4% done.
#
# USW00094702
# 0.13635445871734617
# 301 pumpkins located. 7376 left. 4% done.
#
# USC00274234
# 0.11392318413392247
# 302 pumpkins located. 7375 left. 4% done.
#
# USW00023271
# 0.3282243386187703
# 303 pumpkins located. 7374 left. 4% done.
#
# USC00131635
# 0.09023815043854808
# 304 pumpkins located. 7373 left. 4% done.
#
# USC00470265
# 0.12412761464629317
# 305 pumpkins located. 7372 left. 4% done.
#
# USW00014860
# 0.1089473293005888
# 306 pumpkins located. 7371 left. 4% done.
#
# USC00118684
# 0.37203437790638966
# 307 pumpkins located. 7370 left. 4% done.
#
# USW00014837
# 0.2574562854237602
# 308 pumpkins located. 7369 left. 4% done.
#
# USC00300443
# 0.37426168783716235
# 309 pumpkins located. 7368 left. 4% done.
#
# USW00024127
# 0.0809843284946405
# 310 pumpkins located. 7367 left. 4% done.
#
# USC00170409
# 0.6222997581083719
# 311 pumpkins located. 7366 left. 4% done.
#
# USC00185934
# 2.622723098534075
# 312 pumpkins located. 7365 left. 4% done.
#
# USC00366111
# 0.41649780112946344
# 313 pumpkins located. 7364 left. 4% done.
#
# USW00094847
# 0.7581004882469361
# 314 pumpkins located. 7363 left. 4% done.
#
# USW00093241
# 0.4059705391913919
# 315 pumpkins located. 7362 left. 4% done.
#
# USW00014742
# 0.2162669458463062
# 316 pumpkins located. 7361 left. 4% done.
#
# USC00203823
# 0.5566522367719414
# 317 pumpkins located. 7360 left. 4% done.
#
# USW00014771
# 0.745670900904723
# 318 pumpkins located. 7359 left. 4% done.
#
# USC00043578
# 0.15169374357648763
# 319 pumpkins located. 7358 left. 4% done.
#
# USW00024232
# 0.31506458198318854
# 320 pumpkins located. 7357 left. 4% done.
#
# USW00014898
# 0.5366932394693624
# 321 pumpkins located. 7356 left. 4% done.
#
# USC00135086
# 0.40123507088600147
# 322 pumpkins located. 7355 left. 4% done.
#
# USC00244558
# 0.6189477063016193
# 323 pumpkins located. 7354 left. 4% done.
#
# USC00352632
# 0.49016205801778945
# 324 pumpkins located. 7353 left. 4% done.
#
# USC00470265
# 0.5990954370697442
# 325 pumpkins located. 7352 left. 4% done.
#
# USC00214861
# 3.469747434418259
# 326 pumpkins located. 7351 left. 4% done.
#
# USC00200228
# 0.15679459382529817
# 327 pumpkins located. 7350 left. 4% done.
#
# USC00058995
# 0.07899225292224177
# 328 pumpkins located. 7349 left. 4% done.
#
# USC00058995
# 0.19051121817913727
# 329 pumpkins located. 7348 left. 4% done.
#
# USW00014991
# 0.3449959318024685
# 330 pumpkins located. 7347 left. 4% done.
#
# USW00094290
# 0.13564977479425563
# 331 pumpkins located. 7346 left. 4% done.
#
# USW00023271
# 0.4823411528138342
# 332 pumpkins located. 7345 left. 4% done.
#
# USC00193276
# 0.21188383845347641
# 333 pumpkins located. 7344 left. 4% done.
#
# USC00356750
# 0.155908235772618
# 334 pumpkins located. 7343 left. 4% done.
#
# USC00122620
# 1.1396676027404027
# 335 pumpkins located. 7342 left. 4% done.
#
# USW00014845
# 0.1810957853256736
# 336 pumpkins located. 7341 left. 4% done.
#
# USW00093824
# 0.38184695890588644
# 337 pumpkins located. 7340 left. 4% done.
#
# USS0020L02S
# 0.603559936901132
# 338 pumpkins located. 7339 left. 4% done.
#
# USC00301625
# 0.4059094580431583
# 339 pumpkins located. 7338 left. 4% done.
#
# USW00024227
# 0.06487028119810126
# 340 pumpkins located. 7337 left. 4% done.
#
# USW00014916
# 1.2247539253832755
# 341 pumpkins located. 7336 left. 4% done.
#
# USW00014827
# 0.3854624708862461
# 342 pumpkins located. 7335 left. 4% done.
#
# USC00215400
# 0.7203520829429505
# 343 pumpkins located. 7334 left. 4% done.
#
# USC00471568
# 0.016352407652988718
# 344 pumpkins located. 7333 left. 4% done.
#
# USW00014742
# 0.15605662592332165
# 345 pumpkins located. 7332 left. 4% done.
#
# USW00003810
# 0.806127051112948
# 346 pumpkins located. 7331 left. 5% done.
#
# USW00014933
# 0.07998493842324576
# 347 pumpkins located. 7330 left. 5% done.
#
# USW00094846
# 0.2160107162956689
# 348 pumpkins located. 7329 left. 5% done.
#
# USW00023272
# 0.4924173493378304
# 349 pumpkins located. 7328 left. 5% done.
#
# USC00058995
# 0.19051121817913727
# 350 pumpkins located. 7327 left. 5% done.
#
# USC00360132
# 0.12593279806662466
# 351 pumpkins located. 7326 left. 5% done.
#
# USW00094281
# 0.07855264689728711
# 352 pumpkins located. 7325 left. 5% done.
#
# USW00024127
# 0.09178318953779793
# 353 pumpkins located. 7324 left. 5% done.
#
# USC00046506
# 0.6848815446163393
# 354 pumpkins located. 7323 left. 5% done.
#
# USW00014742
# 0.15605662592332165
# 355 pumpkins located. 7322 left. 5% done.
#
# USC00331785
# 0.5242767346684098
# 356 pumpkins located. 7321 left. 5% done.
#
# USW00013722
# 0.40517738767142675
# 357 pumpkins located. 7320 left. 5% done.
#
# USC00470265
# 0.20100513757454241
# 358 pumpkins located. 7319 left. 5% done.
#
# USW00024232
# 0.31506458198318854
# 359 pumpkins located. 7318 left. 5% done.
#
# USW00094860
# 0.46570434492627766
# 360 pumpkins located. 7317 left. 5% done.
#
# USC00058995
# 0.19051121817913727
# 361 pumpkins located. 7316 left. 5% done.
#
# USC00366111
# 0.29054345481282146
# 362 pumpkins located. 7315 left. 5% done.
#
# USC00198757
# 0.24060539513670112
# 363 pumpkins located. 7314 left. 5% done.
#
# USW00094281
# 0.07855264689728711
# 364 pumpkins located. 7313 left. 5% done.
#
# USW00024232
# 0.31506458198318854
# 365 pumpkins located. 7312 left. 5% done.
#
# USW00054789
# 0.8341326598023152
# 366 pumpkins located. 7311 left. 5% done.
#
# USW00014991
# 0.05601045913131129
# 367 pumpkins located. 7310 left. 5% done.
#
# USC00060227
# 0.42691657833185276
# 368 pumpkins located. 7309 left. 5% done.
#
# USC00135086
# 0.8946590639792565
# 369 pumpkins located. 7308 left. 5% done.
#
# USS0023G09S
# 0.3083063907247569
# 370 pumpkins located. 7307 left. 5% done.
#
# USW00054789
# 0.45397767572621145
# 371 pumpkins located. 7306 left. 5% done.
#
# USC00200230
# 0.07637334439821711
# 372 pumpkins located. 7305 left. 5% done.
#
# USW00014733
# 0.35170869620002093
# 373 pumpkins located. 7304 left. 5% done.
#
# USW00014826
# 0.6016371885900785
# 374 pumpkins located. 7303 left. 5% done.
#
# USW00014897
# 0.6261735936432129
# 375 pumpkins located. 7302 left. 5% done.
#
# USW00094281
# 0.07855264689728711
# 376 pumpkins located. 7301 left. 5% done.
#
# USS0021B50S
# 0.21032476284118318
# 377 pumpkins located. 7300 left. 5% done.
#
# USW00094908
# 0.15587665105525686
# 378 pumpkins located. 7299 left. 5% done.
#
# USS0011J11S
# 0.16589872315868961
# 379 pumpkins located. 7298 left. 5% done.
#
# USC00300443
# 0.29183601171096
# 380 pumpkins located. 7297 left. 5% done.
#
# USS0021B50S
# 0.21032476284118318
# 381 pumpkins located. 7296 left. 5% done.
#
# USW00014895
# 0.11218967691555398
# 382 pumpkins located. 7295 left. 5% done.
#
# USW00014933
# 0.07998493842324576
# 383 pumpkins located. 7294 left. 5% done.
#
# USC00200228
# 0.15679459382529817
# 384 pumpkins located. 7293 left. 5% done.
#
# USW00063858
# 0.9878083566361706
# 385 pumpkins located. 7292 left. 5% done.
#
# USC00214861
# 3.469747434418259
# 386 pumpkins located. 7291 left. 5% done.
#
# USW00093819
# 1.081995664511999
# 387 pumpkins located. 7290 left. 5% done.
#
# USC00058995
# 0.04120353106347237
# 388 pumpkins located. 7289 left. 5% done.
#
# USW00014712
# 0.17792001011690312
# 389 pumpkins located. 7288 left. 5% done.
# USW00014739
# 0.14393000521173444
# 390 pumpkins located. 7287 left. 5% done.
#
# USW00014898
# 0.07088266936318022
# 391 pumpkins located. 7286 left. 5% done.
#
# USW00093241
# 0.4059705391913919
# 392 pumpkins located. 7285 left. 5% done.
#
# USC00481676
# 0.017957013472177208
# 393 pumpkins located. 7284 left. 5% done.
#
# USC00058995
# 0.19051121817913727
# 394 pumpkins located. 7283 left. 5% done.
#
# USW00024233
# 0.1768599787339674
# 395 pumpkins located. 7282 left. 5% done.
#
# USC00200228
# 0.36304425637437915
# 396 pumpkins located. 7281 left. 5% done.
#
# USW00054789
# 0.8341326598023152
# 397 pumpkins located. 7280 left. 5% done.
#
# USC00360868
# 0.09091672210204249
# 398 pumpkins located. 7279 left. 5% done.
#
# USW00023232
# 0.5862372947072552
# 399 pumpkins located. 7278 left. 5% done.
#
# USW00014991
# 0.9765210442505606
# 400 pumpkins located. 7277 left. 5% done.
#
# USW00014778
# 0.07971895675699384
# 401 pumpkins located. 7276 left. 5% done.
#
# USS0011J21S
# 0.13232957677287882
# 402 pumpkins located. 7275 left. 5% done.
#
# USW00014827
# 0.17774634903302627
# 403 pumpkins located. 7274 left. 5% done.
#
# USC00304102
# 0.5598381358216379
# 404 pumpkins located. 7273 left. 5% done.
#
# USC00193276
# 0.29493350837137106
# 405 pumpkins located. 7272 left. 5% done.
#
# USW00054789
# 0.45397767572621145
# 406 pumpkins located. 7271 left. 5% done.
#
# USC00475120
# 0.16891999968061772
# 407 pumpkins located. 7270 left. 5% done.
#
# USS0021B50S
# 0.21032476284118318
# 408 pumpkins located. 7269 left. 5% done.
#
# USC00058995
# 0.19051121817913727
# 409 pumpkins located. 7268 left. 5% done.
#
# USW00014846
# 0.17053482533735237
# 410 pumpkins located. 7267 left. 5% done.
#
# USW00014735
# 0.7439517736387631
# 411 pumpkins located. 7266 left. 5% done.
#
# USW00014897
# 0.1536894456451677
# 412 pumpkins located. 7265 left. 5% done.
#
# USC00204502
# 0.6557454204297423
# 413 pumpkins located. 7264 left. 5% done.
#
# USW00024227
# 0.06487028119810126
# 414 pumpkins located. 7263 left. 5% done.
#
# USW00014740
# 0.27670446636380436
# 415 pumpkins located. 7262 left. 5% done.
#
# USW00023271
# 0.23195434671876297
# 416 pumpkins located. 7261 left. 5% done.
#
# USS0023D02S
# 0.1908178102047948
# 417 pumpkins located. 7260 left. 5% done.
#
# USW00014765
# 0.35177022758410026
# 418 pumpkins located. 7259 left. 5% done.
#
# USW00014733
# 0.3684908111365879
# 419 pumpkins located. 7258 left. 5% done.
#
# USW00014895
# 0.05117350065111961
# 420 pumpkins located. 7257 left. 5% done.
#
# USW00014742
# 0.2421451467234576
# 421 pumpkins located. 7256 left. 5% done.
#
# USW00024229
# 0.14926503654429443
# 422 pumpkins located. 7255 left. 5% done.
#
# USC00455110
# 0.3874871548271555
# 423 pumpkins located. 7254 left. 6% done.
#
# USC00058995
# 0.04085271281323469
# 424 pumpkins located. 7253 left. 6% done.
#
# USC00470265
# 0.5990954370697442
# 425 pumpkins located. 7252 left. 6% done.
#
# USS0011J21S
# 0.1828657887396083
# 426 pumpkins located. 7251 left. 6% done.
#
# USS0011J21S
# 0.1828657887396083
# 427 pumpkins located. 7250 left. 6% done.
#
# USW00014946
# 0.03507379569136852
# 428 pumpkins located. 7249 left. 6% done.
#
# USC00214861
# 1.8101767452379447
# 429 pumpkins located. 7248 left. 6% done.
#
# USS0022G12S
# 0.4982221077906543
# 430 pumpkins located. 7247 left. 6% done.
#
# USW00014925
# 0.11950501789350987
# 431 pumpkins located. 7246 left. 6% done.
#
# USS0011J11S
# 0.27882060430089506
# 432 pumpkins located. 7245 left. 6% done.
#
# USW00024153
# 0.6040799190010028
# 433 pumpkins located. 7244 left. 6% done.
#
# USW00023272
# 0.49696227746602384
# 434 pumpkins located. 7243 left. 6% done.
#
# USS0021B50S
# 0.24827806906823613
# 435 pumpkins located. 7242 left. 6% done.
#
# USC00210190
# 0.10929722203332305
# 436 pumpkins located. 7241 left. 6% done.
#
# USC00058995
# 0.19051121817913727
# 437 pumpkins located. 7240 left. 6% done.
#
# USC00058022
# 0.28406721604596563
# 438 pumpkins located. 7239 left. 6% done.
#
# USW00014737
# 0.2606632516826614
# 439 pumpkins located. 7238 left. 6% done.
#
# USW00094846
# 0.1464832089547543
# 440 pumpkins located. 7237 left. 6% done.
#
# USW00014740
# 0.6459015029677949
# 441 pumpkins located. 7236 left. 6% done.
#
# USW00023271
# 0.38700146496070253
# 442 pumpkins located. 7235 left. 6% done.
#
# USW00023272
# 0.3500682460345883
# 443 pumpkins located. 7234 left. 6% done.
#
# USC00274234
# 0.11392318413392247
# 444 pumpkins located. 7233 left. 6% done.
#
# USW00023271
# 0.3282243386187703
# 445 pumpkins located. 7232 left. 6% done.
#
# USW00094702
# 0.09624788841423688
# 446 pumpkins located. 7231 left. 6% done.
#
# USC00478540
# 0.09665428575377548
# 447 pumpkins located. 7230 left. 6% done.
#
# USW00093824
# 0.43545977313187656
# 448 pumpkins located. 7229 left. 6% done.
#
# USW00094281
# 0.18974917678899456
# 449 pumpkins located. 7228 left. 6% done.
#
# USW00094281
# 0.07855264689728711
# 450 pumpkins located. 7227 left. 6% done.
#
# USW00013891
# 0.39229910556004693
# 451 pumpkins located. 7226 left. 6% done.
#
# USC00473058
# 0.06021719535191382
# 452 pumpkins located. 7225 left. 6% done.
#
# USW00014933
# 0.07998493842324576
# 453 pumpkins located. 7224 left. 6% done.
#
# USW00023271
# 0.2046737276119446
# 454 pumpkins located. 7223 left. 6% done.
#
# USC00360132
# 0.12593279806662466
# 455 pumpkins located. 7222 left. 6% done.
#
# USW00013723
# 0.41331348817382474
# 456 pumpkins located. 7221 left. 6% done.
#
# USW00014821
# 0.39626365565689203
# 457 pumpkins located. 7220 left. 6% done.
#
# USW00013741
# 0.8218313720233207
# 458 pumpkins located. 7219 left. 6% done.
#
# USW00014742
# 0.7783305670088075
# 459 pumpkins located. 7218 left. 6% done.
#
# USW00094702
# 0.4290953856661713
# 460 pumpkins located. 7217 left. 6% done.
#
# USW00014897
# 0.6261735936432129
# 461 pumpkins located. 7216 left. 6% done.
#
# USC00357127
# 0.19694991561371555
# 462 pumpkins located. 7215 left. 6% done.
#
# USW00023232
# 0.5862372947072552
# 463 pumpkins located. 7214 left. 6% done.
#
# USW00014845
# 0.1810957853256736
# 464 pumpkins located. 7213 left. 6% done.
#
# USW00014778
# 0.07971895675699384
# 465 pumpkins located. 7212 left. 6% done.
#
# USS0011J21S
# 0.40132356987170087
# 466 pumpkins located. 7211 left. 6% done.
#
# USW00024233
# 0.36058703745112664
# 467 pumpkins located. 7210 left. 6% done.
#
# USC00214861
# 3.469747434418259
# 468 pumpkins located. 7209 left. 6% done.
#
# USW00013723
# 0.5422918541134368
# 469 pumpkins located. 7208 left. 6% done.
#
# USC00200230
# 0.22426833452830824
# 470 pumpkins located. 7207 left. 6% done.
#
# USW00023271
# 0.23195434671876297
# 471 pumpkins located. 7206 left. 6% done.
#
# USC00437054
# 0.5321084576393779
# 472 pumpkins located. 7205 left. 6% done.
#
# USC00458773
# 0.38260897207475064
# 473 pumpkins located. 7204 left. 6% done.
#
# USC00058995
# 0.1374851058034133
# 474 pumpkins located. 7203 left. 6% done.
#
# USW00014991
# 0.6635375048722706
# 475 pumpkins located. 7202 left. 6% done.
#
# USW00014742
# 0.23379948217580673
# 476 pumpkins located. 7201 left. 6% done.
#
# USW00024232
# 0.28764617192261016
# 477 pumpkins located. 7200 left. 6% done.
#
# USW00053868
# 0.427527898989742
# 478 pumpkins located. 7199 left. 6% done.
#
# USC00200230
# 0.07637334439821711
# 479 pumpkins located. 7198 left. 6% done.
#
# USW00014991
# 0.20314235875427497
# 480 pumpkins located. 7197 left. 6% done.
#
# USW00093820
# 0.5127718483249346
# 481 pumpkins located. 7196 left. 6% done.
#
# USC00123078
# 0.7640797840357236
# 482 pumpkins located. 7195 left. 6% done.
#
# USW00014826
# 0.6068203921887114
# 483 pumpkins located. 7194 left. 6% done.
#
# USW00014737
# 0.2311564295279451
# 484 pumpkins located. 7193 left. 6% done.
#
# USW00094281
# 0.07855264689728711
# 485 pumpkins located. 7192 left. 6% done.
#
# USW00013891
# 0.39229910556004693
# 486 pumpkins located. 7191 left. 6% done.
#
# USW00014991
# 0.5346547871800803
# 487 pumpkins located. 7190 left. 6% done.
#
# USC00478540
# 0.3732510049574306
# 488 pumpkins located. 7189 left. 6% done.
#
# USW00014898
# 0.21981309791009385
# 489 pumpkins located. 7188 left. 6% done.
#
# USC00059213
# 0.19209131930438467
# 490 pumpkins located. 7187 left. 6% done.
#
# USC00058995
# 0.19051121817913727
# 491 pumpkins located. 7186 left. 6% done.
#
# USW00093824
# 0.7168638049310733
# 492 pumpkins located. 7185 left. 6% done.
#
# USC00173862
# 0.09169615821886953
# 493 pumpkins located. 7184 left. 6% done.
#
# USC00458773
# 0.2447417084717719
# 494 pumpkins located. 7183 left. 6% done.
#
# USW00024225
# 0.04336572351580571
# 495 pumpkins located. 7182 left. 6% done.
#
# USW00023272
# 1.3382630588879678
# 496 pumpkins located. 7181 left. 6% done.
#
# USC00363417
# 0.3372043577252545
# 497 pumpkins located. 7180 left. 6% done.
#
# USC00331785
# 0.5242767346684098
# 498 pumpkins located. 7179 left. 6% done.
#
# USW00024127
# 0.09178318953779793
# 499 pumpkins located. 7178 left. 6% done.
#
# USW00023271
# 0.15385691493907191
# 500 pumpkins located. 7177 left. 7% done.
#
# USW00023272
# 1.3382630588879678
# 501 pumpkins located. 7176 left. 7% done.
#
# USW00014778
# 0.07971895675699384
# 502 pumpkins located. 7175 left. 7% done.
#
# USW00093815
# 0.21436923753188766
# 503 pumpkins located. 7174 left. 7% done.
#
# USC00363417
# 0.36208273548262765
# 504 pumpkins located. 7173 left. 7% done.
#
# USW00024232
# 0.31506458198318854
# 505 pumpkins located. 7172 left. 7% done.
#
# USW00024127
# 0.09178318953779793
# 506 pumpkins located. 7171 left. 7% done.
#
# USW00014839
# 0.08391247384281422
# 507 pumpkins located. 7170 left. 7% done.
#
# USC00458773
# 0.2447417084717719
# 508 pumpkins located. 7169 left. 7% done.
#
# USS0011J21S
# 0.40132356987170087
# 509 pumpkins located. 7168 left. 7% done.
#
# USW00094290
# 0.2734241349187251
# 510 pumpkins located. 7167 left. 7% done.
#
# USW00014733
# 0.35170869620002093
# 511 pumpkins located. 7166 left. 7% done.
#
# USW00024127
# 0.0809843284946405
# 512 pumpkins located. 7165 left. 7% done.
#
# USS0021B50S
# 0.21032476284118318
# 513 pumpkins located. 7164 left. 7% done.
#
# USC00123078
# 0.7640797840357236
# 514 pumpkins located. 7163 left. 7% done.
#
# USW00023232
# 0.5862372947072552
# 515 pumpkins located. 7162 left. 7% done.
#
# USW00014837
# 0.3985244239444463
# 516 pumpkins located. 7161 left. 7% done.
#
# USW00024229
# 0.10047108182561591
# 517 pumpkins located. 7160 left. 7% done.
#
# USW00014740
# 0.45643406066789144
# 518 pumpkins located. 7159 left. 7% done.
#
# USW00094746
# 1.5411873813182482
# 519 pumpkins located. 7158 left. 7% done.
#
# USC00059213
# 0.29048482787263713
# 520 pumpkins located. 7157 left. 7% done.
#
# USC00475120
# 0.4005995870802807
# 521 pumpkins located. 7156 left. 7% done.
#
# USW00094908
# 0.15587665105525686
# 522 pumpkins located. 7155 left. 7% done.
#
# USC00058022
# 0.27243470877294496
# 523 pumpkins located. 7154 left. 7% done.
#
# USW00014852
# 0.39813900050139056
# 524 pumpkins located. 7153 left. 7% done.
#
# USC00135086
# 0.40123507088600147
# 525 pumpkins located. 7152 left. 7% done.
#
# USW00014826
# 0.21291190493771395
# 526 pumpkins located. 7151 left. 7% done.
#
# USC00058995
# 0.04085271281323469
# 527 pumpkins located. 7150 left. 7% done.
#
# USS0011H21S
# 0.7796212722086564
# 528 pumpkins located. 7149 left. 7% done.
#
# USC00363417
# 0.3372043577252545
# 529 pumpkins located. 7148 left. 7% done.
#
# USW00094823
# 0.2104630999052605
# 530 pumpkins located. 7147 left. 7% done.
#
# USC00058995
# 0.07899225292224177
# 531 pumpkins located. 7146 left. 7% done.
#
# USW00023272
# 1.0040230442177394
# 532 pumpkins located. 7145 left. 7% done.
#
# USW00014897
# 0.1536894456451677
# 533 pumpkins located. 7144 left. 7% done.
# USC00058995
# 0.19051121817913727
# 534 pumpkins located. 7143 left. 7% done.
#
# USC00173862
# 0.1558591218511122
# 535 pumpkins located. 7142 left. 7% done.
#
# USC00193276
# 0.29493350837137106
# 536 pumpkins located. 7141 left. 7% done.
#
# USW00014926
# 0.41136147853526667
# 537 pumpkins located. 7140 left. 7% done.
#
# USW00003810
# 0.041597426778215235
# 538 pumpkins located. 7139 left. 7% done.
#
# USC00123078
# 0.7640797840357236
# 539 pumpkins located. 7138 left. 7% done.
#
# USS0011J21S
# 0.1828657887396083
# 540 pumpkins located. 7137 left. 7% done.
#
# USC00058995
# 0.19051121817913727
# 541 pumpkins located. 7136 left. 7% done.
#
# USS0011H21S
# 0.6121125520948755
# 542 pumpkins located. 7135 left. 7% done.
#
# USW00054789
# 0.5326132169333707
# 543 pumpkins located. 7134 left. 7% done.
#
# USW00014826
# 0.6016371885900785
# 544 pumpkins located. 7133 left. 7% done.
#
# USS0021B50S
# 0.21032476284118318
# 545 pumpkins located. 7132 left. 7% done.
#
# USW00014846
# 0.17053482533735237
# 546 pumpkins located. 7131 left. 7% done.
#
# USW00014852
# 0.17769674431944932
# 547 pumpkins located. 7130 left. 7% done.
#
# USC00060227
# 0.28444801837251776
# 548 pumpkins located. 7129 left. 7% done.
#
# USC00339220
# 0.6416882301025084
# 549 pumpkins located. 7128 left. 7% done.
#
# USC00198757
# 0.24060539513670112
# 550 pumpkins located. 7127 left. 7% done.
#
# USW00024127
# 0.17121981013227203
# 551 pumpkins located. 7126 left. 7% done.
#
# USS0012M14S
# 0.18836055036046856
# 552 pumpkins located. 7125 left. 7% done.
#
# USS0023G09S
# 0.3140390578641536
# 553 pumpkins located. 7124 left. 7% done.
#
# USC00306314
# 0.026595639148740295
# 554 pumpkins located. 7123 left. 7% done.
#
# USW00054789
# 0.5326132169333707
# 555 pumpkins located. 7122 left. 7% done.
#
# USW00014742
# 0.8582786266150274
# 556 pumpkins located. 7121 left. 7% done.
#
# USS0012G17S
# 0.1168418170692776
# 557 pumpkins located. 7120 left. 7% done.
#
# USC00304102
# 0.5598381358216379
# 558 pumpkins located. 7119 left. 7% done.
#
# USW00023272
# 1.0040230442177394
# 559 pumpkins located. 7118 left. 7% done.
#
# USW00024127
# 0.09178318953779793
# 560 pumpkins located. 7117 left. 7% done.
#
# USC00193276
# 0.4298271838748364
# 561 pumpkins located. 7116 left. 7% done.
#
# USC00470265
# 0.2084363503427429
# 562 pumpkins located. 7115 left. 7% done.
#
# USW00014991
# 0.2338792064636164
# 563 pumpkins located. 7114 left. 7% done.
#
# USW00023272
# 0.49696227746602384
# 564 pumpkins located. 7113 left. 7% done.
#
# USW00014742
# 0.8582786266150274
# 565 pumpkins located. 7112 left. 7% done.
#
# USW00014740
# 0.7734006534076434
# 566 pumpkins located. 7111 left. 7% done.
#
# USW00023271
# 0.23568781789519946
# 567 pumpkins located. 7110 left. 7% done.
#
# USW00014837
# 0.8350077495741488
# 568 pumpkins located. 7109 left. 7% done.
#
# USC00135086
# 0.45041014414875624
# 569 pumpkins located. 7108 left. 7% done.
#
# USW00023271
# 0.15385691493907191
# 570 pumpkins located. 7107 left. 7% done.
#
# USC00478540
# 0.3732510049574306
# 571 pumpkins located. 7106 left. 7% done.
#
# USW00094702
# 0.3896628988836416
# 572 pumpkins located. 7105 left. 7% done.
#
# USW00013723
# 0.41331348817382474
# 573 pumpkins located. 7104 left. 7% done.
#
# USC00200230
# 0.2589672252316903
# 574 pumpkins located. 7103 left. 7% done.
#
# USW00014740
# 0.7847694520432522
# 575 pumpkins located. 7102 left. 7% done.
#
# USW00054789
# 0.5326132169333707
# 576 pumpkins located. 7101 left. 8% done.
#
# USW00093820
# 0.13825109394160567
# 577 pumpkins located. 7100 left. 8% done.
#
# USC00301625
# 0.24559597752114187
# 578 pumpkins located. 7099 left. 8% done.
#
# USW00014837
# 0.7552283143611889
# 579 pumpkins located. 7098 left. 8% done.
#
# USC00458773
# 0.039978815841018346
# 580 pumpkins located. 7097 left. 8% done.
#
# USS0023D02S
# 0.1908178102047948
# 581 pumpkins located. 7096 left. 8% done.
#
# USC00306314
# 0.026595639148740295
# 582 pumpkins located. 7095 left. 8% done.
#
# USC00058995
# 0.19051121817913727
# 583 pumpkins located. 7094 left. 8% done.
#
# USS0011J11S
# 0.555522928730827
# 584 pumpkins located. 7093 left. 8% done.
#
# USW00023271
# 0.2046737276119446
# 585 pumpkins located. 7092 left. 8% done.
#
# USC00170409
# 0.2412560955832064
# 586 pumpkins located. 7091 left. 8% done.
#
# USW00014891
# 0.2052338344233388
# 587 pumpkins located. 7090 left. 8% done.
#
# USW00023272
# 0.4924173493378304
# 588 pumpkins located. 7089 left. 8% done.
#
# USC00369823
# 0.549619720682598
# 589 pumpkins located. 7088 left. 8% done.
#
# USC00300443
# 0.37426168783716235
# 590 pumpkins located. 7087 left. 8% done.
#
# USW00013883
# 0.12226748106682002
# 591 pumpkins located. 7086 left. 8% done.
#
# USC00058022
# 0.28406721604596563
# 592 pumpkins located. 7085 left. 8% done.
#
# USW00023232
# 0.5862372947072552
# 593 pumpkins located. 7084 left. 8% done.
#
# USC00470265
# 0.12412761464629317
# 594 pumpkins located. 7083 left. 8% done.
#
# USW00014827
# 0.595329984281153
# 595 pumpkins located. 7082 left. 8% done.
#
# USW00003812
# 0.040055283697662064
# 596 pumpkins located. 7081 left. 8% done.
#
# USW00093824
# 0.7168638049310733
# 597 pumpkins located. 7080 left. 8% done.
#
# USW00014740
# 0.45643406066789144
# 598 pumpkins located. 7079 left. 8% done.
#
# USS0011J21S
# 0.15077675116329456
# 599 pumpkins located. 7078 left. 8% done.
#
# USC00130200
# 0.3793568649893877
# 600 pumpkins located. 7077 left. 8% done.
#
# USW00014922
# 0.2441372482259865
# 601 pumpkins located. 7076 left. 8% done.
#
# USW00093721
# 0.4179223639867237
# 602 pumpkins located. 7075 left. 8% done.
#
# USW00014845
# 0.3404165906991207
# 603 pumpkins located. 7074 left. 8% done.
#
# USS0011J11S
# 0.26781068048204865
# 604 pumpkins located. 7073 left. 8% done.
#
# USW00014740
# 0.558189341007663
# 605 pumpkins located. 7072 left. 8% done.
#
# USC00058995
# 0.1374851058034133
# 606 pumpkins located. 7071 left. 8% done.
#
# USC00203823
# 0.25527124888325997
# 607 pumpkins located. 7070 left. 8% done.
#
# USW00024127
# 0.2196460192128454
# 608 pumpkins located. 7069 left. 8% done.
#
# USS0011J21S
# 0.23317255818145738
# 609 pumpkins located. 7068 left. 8% done.
#
# USC00170409
# 0.22901300708058706
# 610 pumpkins located. 7067 left. 8% done.
#
# USW00014891
# 0.2052338344233388
# 611 pumpkins located. 7066 left. 8% done.
#
# USW00014826
# 0.6016371885900785
# 612 pumpkins located. 7065 left. 8% done.
#
# USC00306314
# 0.026595639148740295
# 613 pumpkins located. 7064 left. 8% done.
#
# USW00094846
# 0.49277149638436807
# 614 pumpkins located. 7063 left. 8% done.
#
# USW00054789
# 0.45397767572621145
# 615 pumpkins located. 7062 left. 8% done.
#
# USW00053868
# 0.427527898989742
# 616 pumpkins located. 7061 left. 8% done.
#
# USS0012J09S
# 0.2454439444439559
# 617 pumpkins located. 7060 left. 8% done.
#
# USW00023272
# 1.3382630588879678
# 618 pumpkins located. 7059 left. 8% done.
#
# USC00316853
# 1.0182041676324993
# 619 pumpkins located. 7058 left. 8% done.
#
# USC00058022
# 0.12209849999787681
# 620 pumpkins located. 7057 left. 8% done.
#
# USW00003856
# 0.24428908178984995
# 621 pumpkins located. 7056 left. 8% done.
#
# USW00023271
# 0.312416609318036
# 622 pumpkins located. 7055 left. 8% done.
#
# USW00024232
# 0.31506458198318854
# 623 pumpkins located. 7054 left. 8% done.
#
# USW00014733
# 0.11689185987143282
# 624 pumpkins located. 7053 left. 8% done.
#
# USC00309049
# 0.43603702215848794
# 625 pumpkins located. 7052 left. 8% done.
#
# USC00058995
# 0.19051121817913727
# 626 pumpkins located. 7051 left. 8% done.
#
# USW00023272
# 1.0040230442177394
# 627 pumpkins located. 7050 left. 8% done.
#
# USW00014943
# 1.0543446673956707
# 628 pumpkins located. 7049 left. 8% done.
#
# USW00023272
# 0.23145588768210748
# 629 pumpkins located. 7048 left. 8% done.
#
# USC00231801
# 1.0052630799944882
# 630 pumpkins located. 7047 left. 8% done.
#
# USW00003810
# 0.49152815029541286
# 631 pumpkins located. 7046 left. 8% done.
#
# USW00023271
# 0.15385691493907191
# 632 pumpkins located. 7045 left. 8% done.
#
# USC00475120
# 0.40768334436919373
# 633 pumpkins located. 7044 left. 8% done.
#
# USC00058995
# 0.1374851058034133
# 634 pumpkins located. 7043 left. 8% done.
#
# USW00024232
# 0.19208856919289152
# 635 pumpkins located. 7042 left. 8% done.
#
# USC00201675
# ...
# 7465 pumpkins located. 212 left. 97% done.
#
# USW00014733
# 0.33909161160409185
# 7466 pumpkins located. 211 left. 97% done.
#
# USC00201675
# 0.6214819113152857
# 7467 pumpkins located. 210 left. 97% done.
#
# USW00014837
# 0.4508670765333794
# 7468 pumpkins located. 209 left. 97% done.
#
# USW00014837
# 0.4508670765333794
# 7469 pumpkins located. 208 left. 97% done.
#
# USC00475120
# 0.20212738384555962
# 7470 pumpkins located. 207 left. 97% done.
#
# USC00200230
# 0.32394965190921693
# 7471 pumpkins located. 206 left. 97% done.
#
# USW00014740
# 0.45643406066789144
# 7472 pumpkins located. 205 left. 97% done.
#
# USW00024232
# 0.31506458198318854
# 7473 pumpkins located. 204 left. 97% done.
#
# USC00279278
# 0.022904045127667094
# 7474 pumpkins located. 203 left. 97% done.
#
# USW00053902
# 0.09465506698365457
# 7475 pumpkins located. 202 left. 97% done.
#
# USW00013810
# 0.21388786980306412
# 7476 pumpkins located. 201 left. 97% done.
#
# USC00366111
# 0.24556497372436698
# 7477 pumpkins located. 200 left. 97% done.
#
# USC00356750
# 0.16395732830733745
# 7478 pumpkins located. 199 left. 97% done.
#
# USW00014837
# 0.7651780511750216
# 7479 pumpkins located. 198 left. 97% done.
#
# USW00023272
# 0.4924173493378304
# 7480 pumpkins located. 197 left. 97% done.
#
# USW00094290
# 0.11061515850956398
# 7481 pumpkins located. 196 left. 97% done.
#
# USW00014845
# 0.6048644222568551
# 7482 pumpkins located. 195 left. 97% done.
#
# USC00173295
# 0.21858045457050723
# 7483 pumpkins located. 194 left. 97% done.
#
# USC00201468
# 0.008907885284958415
# 7484 pumpkins located. 193 left. 97% done.
#
# USC00173862
# 0.26629330461025386
# 7485 pumpkins located. 192 left. 97% done.
#
# USC00448800
# 0.2745453976523605
# 7486 pumpkins located. 191 left. 98% done.
#
# USC00343820
# 0.46353581953512324
# 7487 pumpkins located. 190 left. 98% done.
#
# USW00023272
# 0.7080496181145094
# 7488 pumpkins located. 189 left. 98% done.
#
# USC00060227
# 0.42691657833185276
# 7489 pumpkins located. 188 left. 98% done.
#
# USW00094290
# 0.1728598124264277
# 7490 pumpkins located. 187 left. 98% done.
#
# USW00093822
# 0.5744593395986481
# 7491 pumpkins located. 186 left. 98% done.
#
# USW00093184
# 0.19893414373656132
# 7492 pumpkins located. 185 left. 98% done.
#
# USW00014942
# 0.06433220331381466
# 7493 pumpkins located. 184 left. 98% done.
#
# USW00023272
# 1.1506146293358757
# 7494 pumpkins located. 183 left. 98% done.
#
# USW00024232
# 0.31506458198318854
# 7495 pumpkins located. 182 left. 98% done.
#
# USC00309000
# 0.4824942061017027
# 7496 pumpkins located. 181 left. 98% done.
#
# USC00058995
# 0.3638218838564342
# 7497 pumpkins located. 180 left. 98% done.
#
# USC00300443
# 0.20000648274555852
# 7498 pumpkins located. 179 left. 98% done.
#
# USW00014839
# 0.6229193706253263
# 7499 pumpkins located. 178 left. 98% done.
#
# USW00014821
# 0.22360143112243736
# 7500 pumpkins located. 177 left. 98% done.
#
# USW00024227
# 0.12729738143516653
# 7501 pumpkins located. 176 left. 98% done.
#
# USC00210190
# 0.46075861723311523
# 7502 pumpkins located. 175 left. 98% done.
#
# USW00003847
# 0.4082022739183174
# 7503 pumpkins located. 174 left. 98% done.
#
# USC00118684
# 0.3252159375124449
# 7504 pumpkins located. 173 left. 98% done.
#
# USC00455110
# 0.25976508813031224
# 7505 pumpkins located. 172 left. 98% done.
# USW00094822
# 0.4879688845737092
# 7506 pumpkins located. 171 left. 98% done.
#
# USW00094910
# 0.2442353225891961
# 7507 pumpkins located. 170 left. 98% done.
#
# USC00210190
# 0.10929722203332305
# 7508 pumpkins located. 169 left. 98% done.
#
# USC00333780
# 0.2085394114180119
# 7509 pumpkins located. 168 left. 98% done.
#
# USC00366111
# 0.5119584103507768
# 7510 pumpkins located. 167 left. 98% done.
#
# USW00003810
# 0.6839544371053152
# 7511 pumpkins located. 166 left. 98% done.
#
# USC00173295
# 0.07589540555395662
# 7512 pumpkins located. 165 left. 98% done.
#
# USW00014991
# 0.9027932928785094
# 7513 pumpkins located. 164 left. 98% done.
#
# USW00023271
# 0.15385691493907191
# 7514 pumpkins located. 163 left. 98% done.
#
# USC00336405
# 0.2493066010615046
# 7515 pumpkins located. 162 left. 98% done.
#
# USW00024229
# 0.18349285315851668
# 7516 pumpkins located. 161 left. 98% done.
#
# USC00195984
# 0.12883041121786865
# 7517 pumpkins located. 160 left. 98% done.
#
# USC00210190
# 0.10919304676457785
# 7518 pumpkins located. 159 left. 98% done.
#
# USW00014742
# 0.16886755929346112
# 7519 pumpkins located. 158 left. 98% done.
#
# USW00093819
# 0.36845494049183247
# 7520 pumpkins located. 157 left. 98% done.
#
# USC00201675
# 0.6214819113152857
# 7521 pumpkins located. 156 left. 98% done.
#
# USC00060227
# 0.3592677468218174
# 7522 pumpkins located. 155 left. 98% done.
#
# USW00094823
# 0.1509444495464824
# 7523 pumpkins located. 154 left. 98% done.
#
# USC00331785
# 0.4006300873075475
# 7524 pumpkins located. 153 left. 98% done.
#
# USW00093184
# 0.27205480459679204
# 7525 pumpkins located. 152 left. 98% done.
#
# USC00113106
# 0.44645806843295827
# 7526 pumpkins located. 151 left. 98% done.
#
# USC00173295
# 0.07589540555395662
# 7527 pumpkins located. 150 left. 98% done.
#
# USW00023232
# 0.5862372947072552
# 7528 pumpkins located. 149 left. 98% done.
#
# USC00200230
# 0.32394965190921693
# 7529 pumpkins located. 148 left. 98% done.
#
# USW00014933
# 1.1685917907362
# 7530 pumpkins located. 147 left. 98% done.
#
# USC00155694
# 0.11136666063831904
# 7531 pumpkins located. 146 left. 98% done.
#
# USC00458715
# 0.12439927126539352
# 7532 pumpkins located. 145 left. 98% done.
#
# USW00014733
# 0.15610756578259527
# 7533 pumpkins located. 144 left. 98% done.
#
# USW00003102
# 0.1700149602291659
# 7534 pumpkins located. 143 left. 98% done.
#
# USW00023232
# 0.8507162507662543
# 7535 pumpkins located. 142 left. 98% done.
#
# USW00094847
# 0.12250160318628465
# 7536 pumpkins located. 141 left. 98% done.
#
# USC00137844
# 0.466885841663333
# 7537 pumpkins located. 140 left. 98% done.
#
# USW00024229
# 0.18349285315851668
# 7538 pumpkins located. 139 left. 98% done.
#
# USC00237263
# 0.8573856586344936
# 7539 pumpkins located. 138 left. 98% done.
#
# USW00014735
# 0.5754733141823818
# 7540 pumpkins located. 137 left. 98% done.
#
# USC00134963
# 0.2587234350702834
# 7541 pumpkins located. 136 left. 98% done.
#
# USW00093820
# 0.3660978820776327
# 7542 pumpkins located. 135 left. 98% done.
#
# USW00094290
# 0.5658217748854962
# 7543 pumpkins located. 134 left. 98% done.
#
# USC00053005
# 0.09887807596439149
# 7544 pumpkins located. 133 left. 98% done.
#
# USW00094846
# 0.6554416019406862
# 7545 pumpkins located. 132 left. 98% done.
#
# USC00440735
# 0.39875773364999584
# 7546 pumpkins located. 131 left. 98% done.
#
# USW00013723
# 0.1325681470642756
# 7547 pumpkins located. 130 left. 98% done.
#
# USC00134963
# 0.7610727535761919
# 7548 pumpkins located. 129 left. 98% done.
#
# USC00440735
# 0.39875773364999584
# 7549 pumpkins located. 128 left. 98% done.
#
# USC00135086
# 0.40123507088600147
# 7550 pumpkins located. 127 left. 98% done.
#
# USC00488858
# 0.6243320005127058
# 7551 pumpkins located. 126 left. 98% done.
#
# USC00210190
# 0.10929722203332305
# 7552 pumpkins located. 125 left. 98% done.
#
# USW00014991
# 0.07619850618089369
# 7553 pumpkins located. 124 left. 98% done.
#
# USW00023271
# 0.15385691493907191
# 7554 pumpkins located. 123 left. 98% done.
#
# USC00488858
# 0.6243320005127058
# 7555 pumpkins located. 122 left. 98% done.
#
# USC00481676
# 0.4989547408134785
# 7556 pumpkins located. 121 left. 98% done.
#
# USC00440735
# 0.39875773364999584
# 7557 pumpkins located. 120 left. 98% done.
#
# USC00058995
# 0.19051121817913727
# 7558 pumpkins located. 119 left. 98% done.
#
# USW00093824
# 0.8225540855871175
# 7559 pumpkins located. 118 left. 98% done.
#
# USW00093819
# 0.1365444386280516
# 7560 pumpkins located. 117 left. 98% done.
#
# USW00014735
# 0.41305383994653705
# 7561 pumpkins located. 116 left. 98% done.
#
# USC00488858
# 0.6243320005127058
# 7562 pumpkins located. 115 left. 99% done.
#
# USW00094960
# 0.10529053011243626
# 7563 pumpkins located. 114 left. 99% done.
#
# USC00058995
# 0.19051121817913727
# 7564 pumpkins located. 113 left. 99% done.
#
# USC00060227
# 0.28444801837251776
# 7565 pumpkins located. 112 left. 99% done.
#
# USW00014845
# 0.5347235669256574
# 7566 pumpkins located. 111 left. 99% done.
#
# USW00093824
# 0.8263191712302939
# 7567 pumpkins located. 110 left. 99% done.
#
# USC00058022
# 0.28406721604596563
# 7568 pumpkins located. 109 left. 99% done.
#
# USC00193276
# 0.14311146005823203
# 7569 pumpkins located. 108 left. 99% done.
#
# USW00014839
# 0.46353785450010876
# 7570 pumpkins located. 107 left. 99% done.
#
# USW00014765
# 0.11067083877233008
# 7571 pumpkins located. 106 left. 99% done.
#
# USW00014991
# 0.1183458105054766
# 7572 pumpkins located. 105 left. 99% done.
#
# USW00023271
# 0.4823411528138342
# 7573 pumpkins located. 104 left. 99% done.
#
# USW00093815
# 0.2398161052407407
# 7574 pumpkins located. 103 left. 99% done.
#
# USC00274234
# 0.48465495585220264
# 7575 pumpkins located. 102 left. 99% done.
#
# USW00023232
# 0.8507162507662543
# 7576 pumpkins located. 101 left. 99% done.
#
# USW00093184
# 0.19893414373656132
# 7577 pumpkins located. 100 left. 99% done.
#
# USW00014897
# 0.3636750440183266
# 7578 pumpkins located. 99 left. 99% done.
#
# USC00173862
# 0.17665006109939932
# 7579 pumpkins located. 98 left. 99% done.
#
# USC00210190
# 0.17594563076820377
# 7580 pumpkins located. 97 left. 99% done.
#
# USW00093815
# 0.49442879989107835
# 7581 pumpkins located. 96 left. 99% done.
#
# USC00049378
# 0.4514774263380614
# 7582 pumpkins located. 95 left. 99% done.
#
# USW00014897
# 0.6261735936432129
# 7583 pumpkins located. 94 left. 99% done.
#
# USC00458773
# 0.039978815841018346
# 7584 pumpkins located. 93 left. 99% done.
#
# USC00366111
# 0.1499034969580388
# 7585 pumpkins located. 92 left. 99% done.
#
# USW00093184
# 0.27205480459679204
# 7586 pumpkins located. 91 left. 99% done.
#
# USW00014820
# 0.42750093912712356
# 7587 pumpkins located. 90 left. 99% done.
#
# USC00058995
# 0.1419873672358401
# 7588 pumpkins located. 89 left. 99% done.
#
# USW00094290
# 0.13564977479425563
# 7589 pumpkins located. 88 left. 99% done.
#
# USW00023271
# 0.4823411528138342
# 7590 pumpkins located. 87 left. 99% done.
#
# USC00049378
# 0.4514774263380614
# 7591 pumpkins located. 86 left. 99% done.
#
# USC00190736
# 0.09779008191902686
# 7592 pumpkins located. 85 left. 99% done.
#
# USW00003102
# 0.22933620979193745
# 7593 pumpkins located. 84 left. 99% done.
#
# USC00042706
# 0.034077439483177555
# 7594 pumpkins located. 83 left. 99% done.
#
# USW00093821
# 0.46723776462800704
# 7595 pumpkins located. 82 left. 99% done.
#
# USC00193276
# 0.38885847439509996
# 7596 pumpkins located. 81 left. 99% done.
#
# USW00014839
# 0.4217361746069462
# 7597 pumpkins located. 80 left. 99% done.
#
# USC00475120
# 0.20212738384555962
# 7598 pumpkins located. 79 left. 99% done.
#
# USC00368449
# 0.28488705216778576
# 7599 pumpkins located. 78 left. 99% done.
#
# USW00094847
# 0.15338969422542725
# 7600 pumpkins located. 77 left. 99% done.
#
# USW00094846
# 0.4709895101720375
# 7601 pumpkins located. 76 left. 99% done.
#
# USC00331785
# 0.06975968224138276
# 7602 pumpkins located. 75 left. 99% done.
#
# USC00053005
# 0.14932384724005343
# 7603 pumpkins located. 74 left. 99% done.
#
# USC00053005
# 0.14932384724005343
# 7604 pumpkins located. 73 left. 99% done.
#
# USW00094290
# 0.39303305229464874
# 7605 pumpkins located. 72 left. 99% done.
#
# USC00053005
# 0.009081169310722729
# 7606 pumpkins located. 71 left. 99% done.
#
# USS0010J10S
# 0.534460963385301
# 7607 pumpkins located. 70 left. 99% done.
#
# USW00014933
# 1.480093889526209
# 7608 pumpkins located. 69 left. 99% done.
#
# USC00470265
# 0.1658596257764986
# 7609 pumpkins located. 68 left. 99% done.
#
# USW00023271
# 0.4823411528138342
# 7610 pumpkins located. 67 left. 99% done.
#
# USC00272800
# 0.17638884107157826
# 7611 pumpkins located. 66 left. 99% done.
#
# USC00237263
# 0.8573856586344936
# 7612 pumpkins located. 65 left. 99% done.
#
# USW00094290
# 0.38053499556919046
# 7613 pumpkins located. 64 left. 99% done.
#
# USW00094950
# 0.057385271479010166
# 7614 pumpkins located. 63 left. 99% done.
#
# USC00331785
# 0.06975968224138276
# 7615 pumpkins located. 62 left. 99% done.
#
# USC00237263
# 0.8573856586344936
# 7616 pumpkins located. 61 left. 99% done.
#
# USC00053005
# 0.009081169310722729
# 7617 pumpkins located. 60 left. 99% done.
#
# USW00003102
# 0.050223606291166296
# 7618 pumpkins located. 59 left. 99% done.
#
# USW00013968
# 0.5557197412943017
# 7619 pumpkins located. 58 left. 99% done.
#
# USW00023272
# 0.2710082086611601
# 7620 pumpkins located. 57 left. 99% done.
#
# USW00093241
# 0.33665585672048093
# 7621 pumpkins located. 56 left. 99% done.
#
# USW00024233
# 0.25979750391458917
# 7622 pumpkins located. 55 left. 99% done.
#
# USW00093821
# 0.07581937997801187
# 7623 pumpkins located. 54 left. 99% done.
#
# USC00058995
# 0.19051121817913727
# 7624 pumpkins located. 53 left. 99% done.
#
# USW00014933
# 1.4647417899280815
# 7625 pumpkins located. 52 left. 99% done.
#
# USW00023272
# 0.30698948633985856
# 7626 pumpkins located. 51 left. 99% done.
#
# USW00013743
# 0.06547240200419954
# 7627 pumpkins located. 50 left. 99% done.
# USW00023271
# 0.4823411528138342
# 7628 pumpkins located. 49 left. 99% done.
#
# USC00135086
# 0.40123507088600147
# 7629 pumpkins located. 48 left. 99% done.
#
# USW00094950
# 0.057385271479010166
# 7630 pumpkins located. 47 left. 99% done.
#
# USC00058995
# 0.10119369702595592
# 7631 pumpkins located. 46 left. 99% done.
#
# USW00023272
# 0.30698948633985856
# 7632 pumpkins located. 45 left. 99% done.
#
# USW00013741
# 0.8963901150682683
# 7633 pumpkins located. 44 left. 99% done.
#
# USC00030130
# 0.3445378079692498
# 7634 pumpkins located. 43 left. 99% done.
#
# USW00014898
# 0.5366932394693624
# 7635 pumpkins located. 42 left. 99% done.
#
# USC00279278
# 0.12246776650245951
# 7636 pumpkins located. 41 left. 99% done.
#
# USW00013891
# 0.4716722760258114
# 7637 pumpkins located. 40 left. 99% done.
#
# USC00135086
# 0.4609040609082717
# 7638 pumpkins located. 39 left. 99% done.
#
# USC00154958
# 0.5494912033356042
# 7639 pumpkins located. 38 left. 100% done.
#
# USW00094702
# 0.4234817271592421
# 7640 pumpkins located. 37 left. 100% done.
#
# USC00475120
# 0.40768334436919373
# 7641 pumpkins located. 36 left. 100% done.
#
# USC00058995
# 0.1374851058034133
# 7642 pumpkins located. 35 left. 100% done.
#
# USC00357127
# 0.2147184567121369
# 7643 pumpkins located. 34 left. 100% done.
#
# USW00023271
# 0.13892306584297304
# 7644 pumpkins located. 33 left. 100% done.
#
# USW00014765
# 0.2255065943663654
# 7645 pumpkins located. 32 left. 100% done.
#
# USW00093241
# 0.45273687009476393
# 7646 pumpkins located. 31 left. 100% done.
#
# USW00013891
# 0.15657033588854374
# 7647 pumpkins located. 30 left. 100% done.
#
# USW00013866
# 0.9379393809304823
# 7648 pumpkins located. 29 left. 100% done.
#
# USC00135086
# 0.4609040609082717
# 7649 pumpkins located. 28 left. 100% done.
#
# USC00475120
# 0.40768334436919373
# 7650 pumpkins located. 27 left. 100% done.
#
# USC00341404
# 0.4344150176044263
# 7651 pumpkins located. 26 left. 100% done.
#
# USS0009E10S
# 0.834355079346973
# 7652 pumpkins located. 25 left. 100% done.
#
# USC00488858
# 0.6243320005127058
# 7653 pumpkins located. 24 left. 100% done.
#
# USW00094281
# 0.18279660001227985
# 7654 pumpkins located. 23 left. 100% done.
#
# USC00053005
# 0.38325758585391956
# 7655 pumpkins located. 22 left. 100% done.
#
# USC00053005
# 0.38325758585391956
# 7656 pumpkins located. 21 left. 100% done.
#
# USC00279278
# 0.12246776650245951
# 7657 pumpkins located. 20 left. 100% done.
#
# USW00014742
# 0.06295236777826534
# 7658 pumpkins located. 19 left. 100% done.
#
# USW00025331
# 0.021386771277593277
# 7659 pumpkins located. 18 left. 100% done.
#
# USC00272800
# 0.17722033458974723
# 7660 pumpkins located. 17 left. 100% done.
#
# USC00487760
# 0.007536973620760556
# 7661 pumpkins located. 16 left. 100% done.
#
# USW00094281
# 0.18279660001227985
# 7662 pumpkins located. 15 left. 100% done.
#
# USS0019K04S
# 0.1336676834033671
# 7663 pumpkins located. 14 left. 100% done.
#
# USW00014922
# 0.19441882065704605
# 7664 pumpkins located. 13 left. 100% done.
#
# USC00344250
# 0.5019456810797156
# 7665 pumpkins located. 12 left. 100% done.
#
# USS0009E10S
# 0.834355079346973
# 7666 pumpkins located. 11 left. 100% done.
#
# USW00014898
# 0.5366932394693624
# 7667 pumpkins located. 10 left. 100% done.
#
# USW00094290
# 0.0910203513995072
# 7668 pumpkins located. 9 left. 100% done.
#
# USS0010J10S
# 0.534460963385301
# 7669 pumpkins located. 8 left. 100% done.
#
# USW00014944
# 0.15964207645407652
# 7670 pumpkins located. 7 left. 100% done.
#
# USW00023271
# 0.23568781789519946
# 7671 pumpkins located. 6 left. 100% done.
#
# USW00014898
# 0.5366932394693624
# 7672 pumpkins located. 5 left. 100% done.
#
# USC00060227
# 0.27788374575453734
# 7673 pumpkins located. 4 left. 100% done.
#
# USC00055236
# 0.03868995818296576
# 7674 pumpkins located. 3 left. 100% done.
#
# USW00023272
# 0.6855625311629744
# 7675 pumpkins located. 2 left. 100% done.
#
# USW00023232
# 0.07478527473894632
# 7676 pumpkins located. 1 left. 100% done.
#
# USC00154958
# 0.5494912033356042
# 7677 pumpkins located. 0 left. 100% done.

# %%
len(pumpkin_filtered.nearest_station.unique())
# Out:
# 349

# %%
nearest_station_list = list(pumpkin_filtered.nearest_station.unique())
nearest_station_list
# Out:
# ['USW00093241',
#  'USW00024233',
#  'USC00058022',
#  'USW00014991',
#  'USC00214861',
#  'USW00014740',
#  'USC00193276',
#  'USW00014711',
#  'USW00014926',
#  'USC00368361',
#  'USC00473058',
#  'USC00043578',
#  'USC00451276',
#  'USW00094860',
#  'USW00004725',
#  'USC00304102',
#  'USW00094846',
#  'USC00331458',
#  'USW00014742',
#  'USW00014898',
#  'USW00023272',
#  'USW00094823',
#  'USC00364325',
#  'USC00301625',
#  'USC00058995',
#  'USW00014733',
#  'USC00470265',
#  'USW00093824',
#  'USC00274234',
#  'USC00336405',
#  'USW00014852',
#  'USC00362470',
#  'USW00014765',
#  'USC00360656',
#  'USW00024232',
#  'USW00014826',
#  'USW00014895',
#  'USW00014842',
#  'USC00198757',
#  'USW00094702',
#  'USW00054789',
#  'USC00356750',
#  'USC00333780',
#  'USW00023271',
#  'USW00014605',
#  'USC00475120',
#  'USC00458773',
#  'USC00210075',
#  'USW00094847',
#  'USC00303087',
#  'USW00014925',
#  'USC00060227',
#  'USW00014737',
#  'USW00024227',
#  'USW00014837',
#  'USW00024213',
#  'USC00200228',
#  'USW00024127',
#  'USW00026491',
#  'USC00339220',
#  'USW00024137',
#  'USS0021B50S',
#  'USC00304174',
#  'USC00190190',
#  'USC00437054',
#  'USC00465963',
#  'USC00477113',
#  'USW00093819',
#  'USS0011H21S',
#  'USC00203823',
#  'USC00211448',
#  'USC00173862',
#  'USW00094290',
#  'USC00201675',
#  'USW00024217',
#  'USC00471604',
#  'USC00481676',
#  'USC00131635',
#  'USC00173570',
#  'USW00003889',
#  'USC00272800',
#  'USC00487760',
#  'USC00360868',
#  'USS0011J21S',
#  'USS0011J11S',
#  'USW00014860',
#  'USC00300443',
#  'USC00098740',
#  'USW00014827',
#  'USC00046506',
#  'USS0023G09S',
#  'USW00094281',
#  'USC00193624',
#  'USC00135086',
#  'USC00355681',
#  'USW00093812',
#  'USW00014735',
#  'USW00023232',
#  'USW00014739',
#  'USW00094176',
#  'USC00244558',
#  'USW00094908',
#  'USC00123078',
#  'USW00093820',
#  'USC00363417',
#  'USC00044500',
#  'USW00014821',
#  'USC00185934',
#  'USC00215400',
#  'USW00094830',
#  'USW00003856',
#  'USC00331785',
#  'USC00118684',
#  'USC00170409',
#  'USC00366111',
#  'USW00014771',
#  'USC00352632',
#  'USC00122620',
#  'USW00014845',
#  'USS0020L02S',
#  'USW00014916',
#  'USC00471568',
#  'USW00003810',
#  'USW00014933',
#  'USC00360132',
#  'USW00013722',
#  'USC00200230',
#  'USW00014897',
#  'USW00063858',
#  'USW00014712',
#  'USW00014778',
#  'USW00014846',
#  'USC00204502',
#  'USS0023D02S',
#  'USW00024229',
#  'USC00455110',
#  'USW00014946',
#  'USS0022G12S',
#  'USW00024153',
#  'USC00210190',
#  'USC00478540',
#  'USW00013891',
#  'USW00013723',
#  'USW00013741',
#  'USC00357127',
#  'USW00053868',
#  'USC00059213',
#  'USW00024225',
#  'USW00093815',
#  'USW00014839',
#  'USW00094746',
#  'USS0012M14S',
#  'USC00306314',
#  'USS0012G17S',
#  'USW00014891',
#  'USC00369823',
#  'USW00013883',
#  'USW00003812',
#  'USC00130200',
#  'USW00014922',
#  'USW00093721',
#  'USS0012J09S',
#  'USC00316853',
#  'USC00309049',
#  'USW00014943',
#  'USC00231801',
#  'USW00094960',
#  'USC00368868',
#  'USC00154958',
#  'USC00332974',
#  'USC00126420',
#  'USC00049742',
#  'USC00195984',
#  'USC00311975',
#  'USC00300321',
#  'USW00093037',
#  'USW00013739',
#  'USC00050848',
#  'USW00014607',
#  'USC00055236',
#  'USW00093821',
#  'USW00014764',
#  'USW00013995',
#  'USW00014944',
#  'USC00304996',
#  'USC00351897',
#  'USW00093822',
#  'USC00472842',
#  'USW00024221',
#  'USW00003847',
#  'USW00014942',
#  'USC00279278',
#  'USC00406493',
#  'USC00303955',
#  'USC00474373',
#  'USC00445050',
#  'USW00093808',
#  'USC00127482',
#  'USW00094052',
#  'USW00014792',
#  'USC00332791',
#  'USC00448062',
#  'USC00134963',
#  'USS0020K03S',
#  'USW00013781',
#  'USC00282805',
#  'USC00452007',
#  'USS0010J10S',
#  'USC00213303',
#  'USW00024090',
#  'USW00014606',
#  'USC00258465',
#  'USW00013994',
#  'USC00106152',
#  'USW00003947',
#  'USS0021D04S',
#  'USW00014820',
#  'USC00367477',
#  'USW00094910',
#  'USC00405882',
#  'USC00173295',
#  'USC00396712',
#  'USW00013996',
#  'USC00190736',
#  'USW00023185',
#  'USC00397277',
#  'USC00171131',
#  'USW00094273',
#  'USC00325638',
#  'USW00014920',
#  'USC00395360',
#  'USC00201468',
#  'USC00053005',
#  'USC00200758',
#  'USC00108937',
#  'USC00364976',
#  'USW00014929',
#  'USS0020K31S',
#  'USC00123418',
#  'USC00368449',
#  'USC00369408',
#  'USC00440735',
#  'USC00038052',
#  'USS0020B02S',
#  'USC00216211',
#  'USC00050109',
#  'USC00132171',
#  'USC00250435',
#  'USW00003167',
#  'USC00367409',
#  'USW00094725',
#  'USC00309000',
#  'USC00042706',
#  'USC00420819',
#  'USW00013736',
#  'USC00450482',
#  'USC00361810',
#  'USC00363226',
#  'USW00024131',
#  'USW00094239',
#  'USW00024028',
#  'USC00360140',
#  'USC00155694',
#  'USC00237263',
#  'USW00093184',
#  'USW00014755',
#  'USC00381770',
#  'USW00093134',
#  'USS0012J02S',
#  'USC00368905',
#  'USS0016A08S',
#  'USW00026411',
#  'USC00311420',
#  'USC00368073',
#  'USW00093814',
#  'USW00014847',
#  'USC00462211',
#  'USC00115961',
#  'USC00056765',
#  'USS0012D09S',
#  'USW00003102',
#  'USS0011J65S',
#  'USC00396596',
#  'USW00013964',
#  'USC00141761',
#  'USC00049378',
#  'USW00025331',
#  'USW00013866',
#  'USW00013729',
#  'USW00014732',
#  'USC00448800',
#  'USC00202382',
#  'USC00051294',
#  'USC00488858',
#  'USW00013968',
#  'USC00449151',
#  'USW00093736',
#  'USW00094950',
#  'USC00120852',
#  'USC00252595',
#  'USC00478267',
#  'USW00023160',
#  'USC00446147',
#  'USW00094989',
#  'USW00014814',
#  'USW00023136',
#  'USW00013740',
#  'USC00361920',
#  'USW00094849',
#  'USC00314996',
#  'USW00023183',
#  'USW00023129',
#  'USC00253605',
#  'USW00014734',
#  'USC00207364',
#  'USC00022782',
#  'USC00253050',
#  'USC00349101',
#  'USW00024216',
#  'USS0019L05S',
#  'USW00094055',
#  'USC00341404',
#  'USS0012J07S',
#  'USW00013899',
#  'USC00409866',
#  'USW00024163',
#  'USC00253660',
#  'USC00407184',
#  'USW00093193',
#  'USC00137844',
#  'USW00014768',
#  'USC00051743',
#  'USC00390043',
#  'USC00343820',
#  'USW00023066',
#  'USW00024033',
#  'USC00118293',
#  'USW00014913',
#  'USW00094822',
#  'USW00004781',
#  'USW00053902',
#  'USW00013810',
#  'USC00113106',
#  'USC00458715',
#  'USW00013743',
#  'USC00030130',
#  'USS0009E10S',
#  'USS0019K04S',
#  'USC00344250']

# %%
weather_filtered = weather_filtered[weather_filtered.station_id.isin(nearest_station_list)]
weather_filtered
# Out:
#             station_id       date element  value measurement_flag  \
# 6901156    USC00022782 2013-05-01    TMAX    361              NaN
# 6901157    USC00022782 2013-05-01    TMIN    161              NaN
# 6901158    USC00022782 2013-05-01    PRCP      0              NaN
# 6901427    USC00030130 2013-05-01    TMAX    278              NaN
# 6901428    USC00030130 2013-05-01    TMIN    117              NaN
# ...                ...        ...     ...    ...              ...
# 173850280  USW00094960 2021-09-30    TMIN    139              NaN
# 173850281  USW00094960 2021-09-30    PRCP      0              NaN
# 173850309  USW00094989 2021-09-30    TMAX    294              NaN
# 173850310  USW00094989 2021-09-30    TMIN    172              NaN
# 173850311  USW00094989 2021-09-30    PRCP    437              NaN
#
#           quality_flag source_flag  time_of_observation
# 6901156            NaN           7               1700.0
# 6901157            NaN           7               1700.0
# 6901158            NaN           7               1700.0
# 6901427            NaN           7                700.0
# 6901428            NaN           7                700.0
# ...                ...         ...                  ...
# 173850280          NaN           W               2400.0
# 173850281          NaN           W               2400.0
# 173850309          NaN           W               2400.0
# 173850310          NaN           W               2400.0
# 173850311          NaN           W               2400.0
#
# [1441719 rows x 8 columns]

# %%
len(weather_filtered.station_id.unique())
# Out:
# 349

# %%
weather_filtered.groupby(["station_id","date"]).count().max()
# Out:
# element                3
# value                  3
# measurement_flag       1
# quality_flag           2
# source_flag            3
# time_of_observation    3
# dtype: int64

# %% [markdown]
# # Export Cleaned and Filtered Datasets

# %%
# Export Weather Dataset
weather_filtered.to_csv(r'weather.csv', index = False)

# %%
# Export Pumpkin Dataset
pumpkin_filtered.to_csv(r'pumpkin.csv', index = False)
